# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
import matplotlib.pyplot as plt
from environment import TrackingEnv

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

MAX_MEMORY = 4000
NUM_NEURONS = 256
LR_CRITIC = 0.0001  #0.0005
LR_ACTOR = 0.0005   #0.001
GAMMA = 0.99
LAMBDA = 0.95
CLIP_EPS = 0.2
K_EPOCH = 10
EARLY_STOPPING_EPISODES = 30
ENTROPY_COEFF = 0.01

def compute_advantages(rewards, values, dones, gamma=GAMMA, lam=LAMBDA):
    advantages = []
    gae = 0
    values = torch.cat([values, torch.tensor([0], dtype=values.dtype, device=values.device)])  # Append a 0 for the last state
    for t in reversed(range(len(rewards))):
        delta = rewards[t] + gamma * values[t + 1] * (1 - dones[t]) - values[t]
        gae = delta + gamma * lam * (1 - dones[t]) * gae
        advantages.insert(0, gae)
    return torch.tensor(advantages, dtype=torch.float)

def compute_returns(rewards, dones, gamma=0.99):
    returns = []
    G = 0
    for reward, done in zip(reversed(rewards), reversed(dones)):
        G = reward + gamma * G * (1 - done)  # Reset if episode ended
        returns.insert(0, G)
    return returns

class PolicyNet(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(PolicyNet, self).__init__()

        self.noise_std = 0.02
        
        self.fc1 = nn.Linear(state_dim, NUM_NEURONS)
        self.fc2 = nn.Linear(NUM_NEURONS, NUM_NEURONS)
        
        # Output per la media (mu)
        self.mu_layer = nn.Linear(NUM_NEURONS, action_dim)
        
        # Output per la deviazione standard (log_sigma)
        self.log_sigma_layer = nn.Linear(NUM_NEURONS, action_dim)

    def add_noise_to_target(self, state):
        state = state.clone()
        if state.dim() == 1:
            state[2:4] += torch.normal(0.0, self.noise_std, size=(2,), device=state.device)
        else:
            state[:, 2:4] += torch.normal(0.0, self.noise_std, size=state[:, 2:4].shape, device=state.device)
        return state


    def forward(self, state):#, exploration_term):

        #state = self.add_noise_to_target(state)

        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        
        # Media delle azioni
        mu = self.mu_layer(x)
        mu = 5.0*torch.tanh(mu)    # azioni in [-5, 5]
        
        # Deviazione standard (softplus per garantire positività)
        log_sigma = self.log_sigma_layer(x)
        sigma = F.softplus(log_sigma) + 1e-5 # 1e-5 per evitare log(0)
        #sigma = F.softplus(log_sigma) + exploration_term + 1e-5 # 1e-5 per evitare log(0)

        return mu, sigma

class ValueNet(nn.Module):
    def __init__(self, num_inputs):
        super(ValueNet, self).__init__()
        self.fc1 = nn.Linear(num_inputs, NUM_NEURONS)
        self.fc2 = nn.Linear(NUM_NEURONS, NUM_NEURONS)
        self.fc3 = nn.Linear(NUM_NEURONS, 1)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class PPOAgent(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(PPOAgent, self).__init__()
        self.actor = PolicyNet(num_inputs, num_actions)
        self.critic = ValueNet(num_inputs)
        self.optimizer_actor = optim.Adam(self.actor.parameters(), lr=LR_ACTOR)
        self.optimizer_critic = optim.Adam(self.critic.parameters(), lr=LR_CRITIC)
        self.buffer = []
    
    def get_action(self, state):
        mu, sigma = self.actor.forward(state)#, exploration_term)
        dist = torch.distributions.Normal(mu, sigma)
        action = dist.rsample()  # Usa reparametrization trick per il backprop
        log_prob = dist.log_prob(action).sum(dim=-1)  # Somma log-prob per dimensione azione
        return action.detach(), log_prob

    def store_transition(self, transition):
        self.buffer.append(transition)



    # def reward_function(self, state, action, next_state, step, tolerance, rimbalzato):

    #     pos = state[:2]
    #     target = state[2:4]
    #     next_pos = next_state[:2]
    #     #next_pos = torch.tensor(next_pos, dtype=torch.float32)

        # to_target = F.normalize(target - pos, dim=0)          # direzione ideale
        # action_dir = F.normalize(action, dim=0)               # direzione dell’azione
        # direction_reward = torch.dot(action_dir, to_target)   # massimo = 1, minimo = -1

        # # Distanze
        # dist_before = torch.norm(pos - target)
        # dist_after = torch.norm(next_pos - target)
        # progress = dist_before - dist_after
        
        # step_penalty = 0.01 * step # 0.01

        # #Se raggiunge il target
        # if dist_after < tolerance:
        #    reward = 500 - 5 * step #if step > 100 else 500
        #    #reward = 500
        # else:
        #    #reward = "quanto mi avvicino" + "quanto vado nella direzione giusta"
        #    reward = 2 * progress + 5 * direction_reward  # pesi da tarare 2 5

        # if rimbalzato:
        #    reward += -5

        # return reward - step_penalty
    

    # def reward_function(self, state, action, next_state, step, tolerance, rimbalzato, attached_counter):
    #     pos = state[:2]
    #     target = state[2:4]              # target(t)
    #     next_pos = next_state[:2]        # agent(t+1)

    #     to_target = F.normalize(target - pos, dim=0)
    #     action_dir = F.normalize(action, dim=0)
    #     direction_reward = torch.dot(action_dir, to_target)

    #     dist_before = torch.norm(pos - target)
    #     dist_after = torch.norm(next_pos - target)  # sempre verso target(t)
    #     progress = dist_before - dist_after

    #     step_penalty = 0.018 * step
    #     reward = 0

    #     # Calcola la distanza rispetto al target precedente
    #     dist_to_target = torch.norm(next_pos - target)

    #     if dist_to_target < tolerance:
    #         # Raggiunto o mantenuto nella soglia rispetto al target precedente
    #         reward += 2                         # base reward
    #         reward += 0.5 * attached_counter    # più tempo resta vicino → più reward
    #     else:
    #         # Fase di inseguimento
    #         reward += 2 * progress + 4 * direction_reward

    #         if progress < 0:
    #             reward += 3 * progress  # penalizzazione per allontanamento

    #     if rimbalzato:
    #         reward -= 5

    #     return reward - step_penalty

    def reward_function(self, state, action, next_state, step, tolerance, rimbalzato, attached_counter):
        #reward = - torch.norm(next_state[:2] - state[2:4]) -1
        pos = state[:2]
        target = state[2:4]              # target(t)
        next_pos = next_state[:2]        # agent(t+1)

        to_target = F.normalize(target - pos, dim=0)
        action_dir = F.normalize(action, dim=0)
        direction_reward = torch.dot(action_dir, to_target)
        direction_penalty = 1.0 - direction_reward

        dist_before = torch.norm(pos - target)
        dist_after = torch.norm(next_pos - target)  # sempre verso target(t)
        progress = dist_before - dist_after

        reward = - direction_penalty #+ progress

        if torch.norm(next_state[:2] - state[2:4]) < tolerance:
            reward += 50
        
        if rimbalzato:
            reward -= 5

        return reward - 1
        
    
    def update(self):
        torch.autograd.set_detect_anomaly(True)
        states, actions, rewards, dones, old_log_probs = zip(*self.buffer)
        old_log_probs = torch.stack(old_log_probs)
        states = torch.stack(states)
        actions = torch.stack(actions).float()
        rewards = torch.tensor(rewards, dtype=torch.float32)
        dones = torch.tensor(dones, dtype=torch.float32)
        values = self.critic(states).squeeze()
        advantages = compute_advantages(rewards, values.detach(), dones)
        returns = compute_returns(rewards, dones)  # Compute Monte Carlo returns
        returns = torch.tensor(returns, dtype=torch.float32)
        
        for _ in range(K_EPOCH):
            means, stds = self.actor(states)
            dist = torch.distributions.Normal(means, stds)
            entropy = dist.entropy().sum(dim=-1).mean()  # media sull’intero batch
            new_log_probs = dist.log_prob(actions).sum(dim=-1)
            ratio = torch.exp(new_log_probs - old_log_probs.detach())
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1-CLIP_EPS, 1+CLIP_EPS) * advantages
            policy_loss = -torch.min(surr1, surr2).mean() - ENTROPY_COEFF * entropy
            values_pred =self.critic(states).squeeze()
            value_loss = F.mse_loss(values_pred, returns)

            total_loss = policy_loss + value_loss

            self.optimizer_actor.zero_grad()
            self.optimizer_critic.zero_grad()
            #policy_loss.backward()
            #value_loss.backward()
            total_loss.backward()
            self.optimizer_actor.step()
            self.optimizer_critic.step()
        
        self.buffer.clear()

def train_ppo(env=None, num_episodes=6001):
    if env is None:
        env = TrackingEnv()
    num_inputs = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]
    agent = PPOAgent(num_inputs, num_actions)
    reward_history = []
    success_history = []
    counter = 0
    tolerance = 0.02 #0.05
    
    for episode in range(num_episodes):
        #target = np.random.uniform(-0.05, 0.05, size=(2,))    # -0.5, 0.5 non convergeva in 4000 episodi
        #target = torch.tensor(target, dtype=torch.float32)
        state, _ = env.reset()#(target=target)
        done = False
        total_reward = 0
        state = torch.tensor(state, dtype=torch.float32)
        trajectory = []
        target_trajectory = []
        step = 0
        attached_counter = 0
        
        while not done:
            step += 1
            trajectory.append(state[:2].detach().numpy())
            target_trajectory.append(state[2:4].detach().numpy())
            action, log_prob = agent.get_action(state)
            
            # if step == 50:
            #     print(action)
            next_state, _, done, truncated, _, rimbalzato = env.step(action)
            next_state = torch.tensor(next_state, dtype=torch.float32)
            if torch.norm(next_state[:2] - next_state[2:4])<tolerance or truncated:
               done = True
            # if torch.norm(next_state[:2] - target_trajectory[-1])<tolerance:
            #     attached_counter += 1
            
            reward = agent.reward_function(state, action, next_state, step, tolerance, rimbalzato, attached_counter)

            #if truncated or (torch.norm(next_state[:2]-target_trajectory[-1])>tolerance and attached_counter > 0):
            #    done = True

            #done = done or truncated

            agent.store_transition((state, action, reward, done, log_prob))
            state = next_state
            total_reward += reward
        
        if torch.norm(next_state[:2] - next_state[2:4])<tolerance:
        #if attached_counter > 10:
            counter += 1
            success_history.append(1)
            # PLOTTING TRAIETTORIA A SUCCESSO
            trajectory = np.array(trajectory)
            target_trajectory = np.array(target_trajectory)
            if counter % 20 == 0:
                print(f"SUCCESSO Episode: {episode}, Step: {step}, Counter: {counter}, Attached_counter: {attached_counter}, Total reward: {total_reward}, final state: {state}")
            if counter % 100 == 0:
                
                plt.figure(figsize=(5, 5))
                plt.plot(trajectory[:, 0], trajectory[:, 1], label="Agente", color='blue')
                plt.plot(target_trajectory[:, 0], target_trajectory[:, 1], label="Target", color='red')
                plt.scatter(*trajectory[0], color='green', label='Start agente', s=100)
                plt.scatter(*target_trajectory[0], color='yellow', label='Start target', s=100)
                plt.scatter(*target_trajectory[-1], color='red', label='End agente', s=100)
                # Stampa gli ultimi 5 punti della traiettoria del target
                plt.scatter(target_trajectory[-5:, 0], target_trajectory[-5:, 1], color='orange', label='Ultimi punti target', s=10)
                # Stampa l'ultimo punto della traiettoria dell'agente
                plt.scatter(trajectory[-5:, 0], trajectory[-5:, 1], color='purple', label='Ultimi punti agente', s=10)
                plt.title(f"Traiettoria episodio {episode}, SUCCESSO")
                plt.xlabel("X")
                plt.ylabel("Y")
                plt.legend()
                plt.grid()
                plt.axis('equal')
                plt.show()

        else:
            success_history.append(0)

        reward_history.append(total_reward)

        if episode % 100 == 0:
            print(f"Episode: {episode}, Step: {step}, Counter: {counter}, Attached_counter: {attached_counter}, Total reward: {total_reward}, final state: {state}, ")

        #if attached_counter > 10:
            # print(f"Episode: {episode}, Step: {step}, Counter: {counter}, Attached_counter: {attached_counter}, Total reward: {total_reward}, final state: {state}, ")

        # if episode % 100 == 0:
        #     trajectory = np.array(trajectory)
        #     #target = next_state[2:4].detach().numpy()  # x_target, y_target
        #     target_trajectory = np.array(target_trajectory)

        #     plt.figure(figsize=(5, 5))
        #     plt.plot(trajectory[:, 0], trajectory[:, 1], label="Agente", color='blue')
        #     plt.plot(target_trajectory[:, 0], target_trajectory[:, 1], linestyle='-', label="Target", color='red')
        #     plt.scatter(*trajectory[0], color='green', label='Start agente', s=100)
        #     plt.scatter(*target_trajectory[0], color='orange', label='Start target', s=100)
        #     # Stampa gli ultimi 5 punti della traiettoria del target
        #     plt.scatter(target_trajectory[-5:, 0], target_trajectory[-5:, 1], color='orange', label='Ultimi punti target', s=10)
        #         # Stampa l'ultimo punto della traiettoria dell'agente
        #     plt.scatter(trajectory[-5:, 0], trajectory[-5:, 1], color='purple', label='Ultimi punti agente', s=10)
        #     plt.title(f"Traiettoria episodio {episode}")
        #     plt.xlabel("X")
        #     plt.ylabel("Y")
        #     plt.legend()
        #     plt.grid()
        #     plt.axis('equal')
        #     plt.show()

        
        #if len(reward_history)>EARLY_STOPPING_EPISODES and all(s == 1 for s in success_history[-EARLY_STOPPING_EPISODES:]):
        #    break
        
        #if len(reward_history) > EARLY_STOPPING_EPISODES and np.mean(reward_history[-EARLY_STOPPING_EPISODES:]) > -30:
        #    print(f"Early stopping at episode {episode}")
        #    break

        if len(agent.buffer) >= MAX_MEMORY:
            agent.update()
    
    env.close()

    plt.plot(reward_history)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Training Progress')
    plt.show()


    return agent

if __name__ == "__main__":
    trained_agent = train_ppo()
# Out:
# Episode: 0, Step: 400, Counter: 0, Attached_counter: 0, Total reward: -801.363525390625, final state: tensor([-0.0123, -0.4058,  0.2784,  0.1184]),
# Episode: 100, Step: 400, Counter: 3, Attached_counter: 0, Total reward: -769.6500244140625, final state: tensor([0.0753, 0.2937, 0.0063, 0.3917]),
# Episode: 200, Step: 400, Counter: 11, Attached_counter: 0, Total reward: -1003.4873046875, final state: tensor([ 1.7720, -1.9257,  0.0915,  0.1281]),
# SUCCESSO Episode: 268, Step: 240, Counter: 20, Attached_counter: 0, Total reward: -386.8446960449219, final state: tensor([ 0.5840, -0.0733,  0.5853, -0.0867])
# Episode: 300, Step: 400, Counter: 24, Attached_counter: 0, Total reward: -776.4625244140625, final state: tensor([-0.5823, -0.5163, -0.5735, -0.2117]),
# SUCCESSO Episode: 366, Step: 12, Counter: 40, Attached_counter: 0, Total reward: 33.37601089477539, final state: tensor([ 0.5647, -0.1040,  0.5726, -0.1117])
# Episode: 400, Step: 400, Counter: 59, Attached_counter: 0, Total reward: -794.57568359375, final state: tensor([-0.7049, -0.4956, -0.3280, -0.1740]),
# SUCCESSO Episode: 402, Step: 282, Counter: 60, Attached_counter: 0, Total reward: -481.9241943359375, final state: tensor([0.4507, 0.1822, 0.4561, 0.1811])
# SUCCESSO Episode: 445, Step: 209, Counter: 80, Attached_counter: 0, Total reward: -346.54168701171875, final state: tensor([-0.0568,  0.1816, -0.0462,  0.1646])
# SUCCESSO Episode: 481, Step: 53, Counter: 100, Attached_counter: 0, Total reward: -41.77812194824219, final state: tensor([ 0.1007, -0.0134,  0.1058, -0.0228])
# Episode: 500, Step: 400, Counter: 107, Attached_counter: 0, Total reward: -770.0706176757812, final state: tensor([ 0.3639, -0.0770,  0.4875, -0.3005]),
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 383
#     380     return agent
#     382 if __name__ == "__main__":
# --> 383     trained_agent = train_ppo()
#
# Cell In[1], line 276, in train_ppo(env, num_episodes)
#     274 trajectory.append(state[:2].detach().numpy())
#     275 target_trajectory.append(state[2:4].detach().numpy())
# --> 276 action, log_prob = agent.get_action(state)
#     278 # if step == 50:
#     279 #     print(action)
#     280 next_state, _, done, truncated, _, rimbalzato = env.step(action)
#
# Cell In[1], line 111, in PPOAgent.get_action(self, state)
#     109 dist = torch.distributions.Normal(mu, sigma)
#     110 action = dist.rsample()  # Usa reparametrization trick per il backprop
# --> 111 log_prob = dist.log_prob(action).sum(dim=-1)  # Somma log-prob per dimensione azione
#     112 return action.detach(), log_prob
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/site-packages/torch/distributions/normal.py:86, in Normal.log_prob(self, value)
#      81 var = self.scale**2
#      82 log_scale = (
#      83     math.log(self.scale) if isinstance(self.scale, Real) else self.scale.log()
#      84 )
#      85 return (
# ---> 86     -((value - self.loc) ** 2) / (2 * var)
#      87     - log_scale
#      88     - math.log(math.sqrt(2 * math.pi))
#      89 )
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/site-packages/torch/_tensor.py:40, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      38     if has_torch_function(args):
#      39         return handle_torch_function(wrapped, args, *args, **kwargs)
# ---> 40     return f(*args, **kwargs)
#      41 except TypeError:
#      42     return NotImplemented
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/site-packages/torch/fx/traceback.py:68, in format_stack()
#      65     return [current_meta.get("stack_trace", "")]
#      66 else:
#      67     # fallback to traceback.format_stack()
# ---> 68     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/traceback.py:211, in extract_stack(f, limit)
#     209 if f is None:
#     210     f = sys._getframe().f_back
# --> 211 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212 stack.reverse()
#     213 return stack
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/traceback.py:366, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     364 if lookup_lines:
#     365     for f in result:
# --> 366         f.line
#     367 return result
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/traceback.py:288, in FrameSummary.line(self)
#     285 @property
#     286 def line(self):
#     287     if self._line is None:
# --> 288         self._line = linecache.getline(self.filename, self.lineno).strip()
#     289     return self._line
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/linecache.py:43, in getlines(filename, module_globals)
#      41     entry = cache[filename]
#      42     if len(entry) != 1:
# ---> 43         return cache[filename][2]
#      45 try:
#      46     return updatecache(filename, module_globals)
#
# KeyboardInterrupt:

# %%
# Per salvare solo i pesi
torch.save(trained_agent.actor.state_dict(), "ppo_policy.pt")
torch.save(trained_agent.critic.state_dict(), "ppo_critic.pt")

# %%
def test_agent_with_random_targets(agent, env=None, num_episodes=100, target_sampler=None, tolerance=0.02):
    if env is None:
        env = TrackingEnv()

    agent.eval()

    final_distances = []
    success_counter = 0

    for ep in range(num_episodes):
        # # Genera un target casuale (es. all’interno di uno spazio 2D limitato)
        # if target_sampler:
        #     target = target_sampler()
        #     target = torch.tensor(target, dtype=torch.float32)
        # else:
        #     target = np.random.uniform(low=-0.5, high=0.5, size=(2,))  # Default sampler
        #     target = torch.tensor(target, dtype=torch.float32)

        state, _ = env.reset()#target=target)
        state = torch.tensor(state, dtype=torch.float32)

        done = False
        step = 0
        trajectory = []

        while not done:
            trajectory.append(state.detach().numpy())
            action, _ = agent.get_action(state)
            next_state, _, done, truncated, _, rimbalzato = env.step(action)
            next_state = torch.tensor(next_state, dtype=torch.float32)
            if torch.norm(next_state[:2] - next_state[2:4]) < tolerance or truncated:
                done = True
            state = next_state
            step += 1

        trajectory = np.array(trajectory)
        final_dist = np.linalg.norm(state[:2] - state[2:4])
        final_distances.append(final_dist)
        print(f"[Episode {ep}] Steps: {step}, Final distance: {final_dist:.4f}")

        success = False

        if final_dist < tolerance:
            success = True
            success_counter += 1


        #if success and ep % 10 == 0:
        plt.figure(figsize=(5, 5))
        plt.plot(trajectory[:, 0], trajectory[:, 1], marker='o', label="Traiettoria")
        plt.scatter(*state[2:4], color='red', label='Target', s=100)
        plt.scatter(trajectory[0, 0], trajectory[0, 1], color='green', label='Start', s=100)
        plt.title(f"Test con target casuale – episodio {ep}, successo: {success}")
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.legend()
        plt.grid()
        plt.axis('equal')
        plt.show()

    env.close()

    print(f"Media delle distanze finali: {np.mean(final_distances):.4f}, numero di successi: {success_counter}")

def target_sampler():
    # Genera target in un quadrato [-1, 1] x [-1, 1]
    return np.random.uniform(low=-0.5, high=0.5, size=(2,))


test_agent_with_random_targets(trained_agent)#, target_sampler=target_sampler)

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from environment import TrackingEnv
from ppo import PPOAgent, PolicyNet, ValueNet  # Cambia 'your_ppo_file' con il nome del file corretto


def load_ppo_agent(checkpoint_path, state_dim, action_dim):
    agent = PPOAgent(state_dim, action_dim)
    checkpoint = torch.load(checkpoint_path, map_location=torch.device('cpu'))
    agent.actor.load_state_dict(checkpoint['actor_state_dict'])
    agent.critic.load_state_dict(checkpoint['critic_state_dict'])
    agent.eval()
    return agent


def test_ppo_agent(agent, env=None, num_episodes=1001, tolerance=0.02, save_dir="ppo_test_results"):
    if env is None:
        env = TrackingEnv()
    success_count = 0
    final_distances = []

    for ep in range(num_episodes):
        state, _ = env.reset()
        state = torch.tensor(state, dtype=torch.float32)
        done = False
        trajectory = []
        target_trajectory = []

        while not done:
            trajectory.append(state[:2].detach().numpy())
            target_trajectory.append(state[2:4].detach().numpy())
            with torch.no_grad():
                mu, sigma = agent.actor(state)
                dist = torch.distributions.Normal(mu, sigma)
                action = dist.mean  # greedy action
            next_state, _, done, truncated, _, _ = env.step(action.numpy())
            next_state = torch.tensor(next_state, dtype=torch.float32)
            if torch.norm(next_state[:2] - next_state[2:4]) < tolerance or truncated:
                done = True
            state = next_state

        final_distance = torch.norm(state[:2] - state[2:4]).item()
        final_distances.append(final_distance)
        success = final_distance < tolerance
        if success:
            success_count += 1

        print(f"Episode {ep} | Final distance: {final_distance:.4f} | Success: {success}")

        if ep % 100 == 0:
            trajectory = np.array(trajectory)
            target_trajectory = np.array(target_trajectory)
            plt.figure(figsize=(5, 5))
            plt.plot(trajectory[:, 0], trajectory[:, 1], label="Agent", color='blue')
            plt.plot(target_trajectory[:, 0], target_trajectory[:, 1], label="Target", color='red')
            plt.scatter(*trajectory[0], color='green', label='Start', s=100)
            plt.scatter(*target_trajectory[-1], color='red', label='Target End', s=100)
            plt.axis('equal')
            plt.title(f"Episode {ep} | Success: {success}")
            plt.legend()
            plt.grid()
            plt.show()

    env.close()
    print(f"Success rate: {success_count}/{num_episodes} | Avg final distance: {np.mean(final_distances):.4f}")


if __name__ == "__main__":
    checkpoint_path = "runs/ppo_run_20250412_153252/checkpoint_ep10000.pth"
    env = TrackingEnv()
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]

    agent = load_ppo_agent(checkpoint_path, state_dim, action_dim)
    test_ppo_agent(agent)
# Out:
# Episode 0 | Final distance: 0.0240 | Success: False
# Episode 1 | Final distance: 0.0168 | Success: True
# Episode 2 | Final distance: 0.0160 | Success: True
# Episode 3 | Final distance: 0.0295 | Success: False
# Episode 4 | Final distance: 0.0079 | Success: True
# Episode 5 | Final distance: 0.0189 | Success: True
# Episode 6 | Final distance: 0.0191 | Success: True
# Episode 7 | Final distance: 0.0109 | Success: True
# Episode 8 | Final distance: 0.0156 | Success: True
# Episode 9 | Final distance: 0.0163 | Success: True
# Episode 10 | Final distance: 0.0117 | Success: True
# Episode 11 | Final distance: 0.0148 | Success: True
# Episode 12 | Final distance: 0.0174 | Success: True
# Episode 13 | Final distance: 0.0081 | Success: True
# Episode 14 | Final distance: 0.0169 | Success: True
# Episode 15 | Final distance: 0.0160 | Success: True
# Episode 16 | Final distance: 0.0133 | Success: True
# Episode 17 | Final distance: 0.0193 | Success: True
# Episode 18 | Final distance: 0.0031 | Success: True
# Episode 19 | Final distance: 0.0156 | Success: True
# Episode 20 | Final distance: 0.0060 | Success: True
# Episode 21 | Final distance: 0.0148 | Success: True
# Episode 22 | Final distance: 0.0151 | Success: True
# Episode 23 | Final distance: 0.0173 | Success: True
# Episode 24 | Final distance: 0.0166 | Success: True
# Episode 25 | Final distance: 0.0115 | Success: True
# Episode 26 | Final distance: 0.0191 | Success: True
# Episode 27 | Final distance: 0.0143 | Success: True
# Episode 28 | Final distance: 0.0195 | Success: True
# Episode 29 | Final distance: 0.0179 | Success: True
# Episode 30 | Final distance: 0.0088 | Success: True
# Episode 31 | Final distance: 0.0177 | Success: True
# Episode 32 | Final distance: 0.0178 | Success: True
# Episode 33 | Final distance: 0.0169 | Success: True
# Episode 34 | Final distance: 0.0146 | Success: True
# Episode 35 | Final distance: 0.0144 | Success: True
# Episode 36 | Final distance: 0.0105 | Success: True
# Episode 37 | Final distance: 0.0163 | Success: True
# Episode 38 | Final distance: 0.0183 | Success: True
# Episode 39 | Final distance: 0.0123 | Success: True
# Episode 40 | Final distance: 0.0190 | Success: True
# Episode 41 | Final distance: 0.0138 | Success: True
# Episode 42 | Final distance: 0.0182 | Success: True
# Episode 43 | Final distance: 0.0089 | Success: True
# Episode 44 | Final distance: 0.0082 | Success: True
# Episode 45 | Final distance: 0.0181 | Success: True
# Episode 46 | Final distance: 0.0169 | Success: True
# Episode 47 | Final distance: 0.0113 | Success: True
# Episode 48 | Final distance: 0.0151 | Success: True
# Episode 49 | Final distance: 0.0183 | Success: True
# Episode 50 | Final distance: 0.0155 | Success: True
# Episode 51 | Final distance: 0.0087 | Success: True
# Episode 52 | Final distance: 0.0173 | Success: True
# Episode 53 | Final distance: 0.0153 | Success: True
# Episode 54 | Final distance: 0.0168 | Success: True
# Episode 55 | Final distance: 0.0170 | Success: True
# Episode 56 | Final distance: 0.0064 | Success: True
# Episode 57 | Final distance: 0.0115 | Success: True
# Episode 58 | Final distance: 0.0190 | Success: True
# Episode 59 | Final distance: 0.0105 | Success: True
# Episode 60 | Final distance: 0.0191 | Success: True
# Episode 61 | Final distance: 0.0122 | Success: True
# Episode 62 | Final distance: 0.0118 | Success: True
# Episode 63 | Final distance: 0.0125 | Success: True
# Episode 64 | Final distance: 0.0165 | Success: True
# Episode 65 | Final distance: 0.0177 | Success: True
# Episode 66 | Final distance: 0.0142 | Success: True
# Episode 67 | Final distance: 0.0144 | Success: True
# Episode 68 | Final distance: 0.0125 | Success: True
# Episode 69 | Final distance: 0.0142 | Success: True
# Episode 70 | Final distance: 0.0125 | Success: True
# Episode 71 | Final distance: 0.0191 | Success: True
# Episode 72 | Final distance: 0.0157 | Success: True
# Episode 73 | Final distance: 0.0115 | Success: True
# Episode 74 | Final distance: 0.0088 | Success: True
# Episode 75 | Final distance: 0.0197 | Success: True
# Episode 76 | Final distance: 0.0141 | Success: True
# Episode 77 | Final distance: 0.0181 | Success: True
# Episode 78 | Final distance: 0.0126 | Success: True
# Episode 79 | Final distance: 0.0159 | Success: True
# Episode 80 | Final distance: 0.0177 | Success: True
# Episode 81 | Final distance: 0.0199 | Success: True
# Episode 82 | Final distance: 0.0160 | Success: True
# Episode 83 | Final distance: 0.0159 | Success: True
# Episode 84 | Final distance: 0.0077 | Success: True
# Episode 85 | Final distance: 0.0174 | Success: True
# Episode 86 | Final distance: 0.0178 | Success: True
# Episode 87 | Final distance: 0.0140 | Success: True
# Episode 88 | Final distance: 0.0103 | Success: True
# Episode 89 | Final distance: 0.0160 | Success: True
# Episode 90 | Final distance: 0.0076 | Success: True
# Episode 91 | Final distance: 0.0126 | Success: True
# Episode 92 | Final distance: 0.0131 | Success: True
# Episode 93 | Final distance: 0.0169 | Success: True
# Episode 94 | Final distance: 0.0150 | Success: True
# Episode 95 | Final distance: 0.0195 | Success: True
# Episode 96 | Final distance: 0.0050 | Success: True
# Episode 97 | Final distance: 0.0157 | Success: True
# Episode 98 | Final distance: 0.0152 | Success: True
# Episode 99 | Final distance: 0.0135 | Success: True
# Episode 100 | Final distance: 0.0182 | Success: True
# Episode 101 | Final distance: 0.0163 | Success: True
# Episode 102 | Final distance: 0.0061 | Success: True
# Episode 103 | Final distance: 0.0114 | Success: True
# Episode 104 | Final distance: 0.0167 | Success: True
# Episode 105 | Final distance: 0.0168 | Success: True
# Episode 106 | Final distance: 0.0132 | Success: True
# Episode 107 | Final distance: 0.0187 | Success: True
# Episode 108 | Final distance: 0.0074 | Success: True
# Episode 109 | Final distance: 0.0165 | Success: True
# Episode 110 | Final distance: 0.0191 | Success: True
# Episode 111 | Final distance: 0.0190 | Success: True
# Episode 112 | Final distance: 0.0114 | Success: True
# Episode 113 | Final distance: 0.0169 | Success: True
# Episode 114 | Final distance: 0.0183 | Success: True
# Episode 115 | Final distance: 0.0199 | Success: True
# Episode 116 | Final distance: 0.0155 | Success: True
# Episode 117 | Final distance: 0.0185 | Success: True
# Episode 118 | Final distance: 0.0138 | Success: True
# Episode 119 | Final distance: 0.0146 | Success: True
# Episode 120 | Final distance: 0.0102 | Success: True
# Episode 121 | Final distance: 0.0182 | Success: True
# Episode 122 | Final distance: 0.0167 | Success: True
# Episode 123 | Final distance: 0.0196 | Success: True
# Episode 124 | Final distance: 0.0156 | Success: True
# Episode 125 | Final distance: 0.0189 | Success: True
# Episode 126 | Final distance: 0.0113 | Success: True
# Episode 127 | Final distance: 0.0170 | Success: True
# Episode 128 | Final distance: 0.0162 | Success: True
# Episode 129 | Final distance: 0.0198 | Success: True
# Episode 130 | Final distance: 0.0123 | Success: True
# Episode 131 | Final distance: 0.0133 | Success: True
# Episode 132 | Final distance: 0.0190 | Success: True
# Episode 133 | Final distance: 0.0157 | Success: True
# Episode 134 | Final distance: 0.0182 | Success: True
# Episode 135 | Final distance: 0.0199 | Success: True
# Episode 136 | Final distance: 0.0107 | Success: True
# Episode 137 | Final distance: 0.0151 | Success: True
# Episode 138 | Final distance: 0.0176 | Success: True
# Episode 139 | Final distance: 0.0199 | Success: True
# Episode 140 | Final distance: 0.0115 | Success: True
# Episode 141 | Final distance: 0.0139 | Success: True
# Episode 142 | Final distance: 0.0132 | Success: True
# Episode 143 | Final distance: 0.0172 | Success: True
# Episode 144 | Final distance: 0.0116 | Success: True
# Episode 145 | Final distance: 0.0103 | Success: True
# Episode 146 | Final distance: 0.0078 | Success: True
# Episode 147 | Final distance: 0.0169 | Success: True
# Episode 148 | Final distance: 0.0113 | Success: True
# Episode 149 | Final distance: 0.0198 | Success: True
# Episode 150 | Final distance: 0.0141 | Success: True
# Episode 151 | Final distance: 0.0137 | Success: True
# Episode 152 | Final distance: 0.0194 | Success: True
# Episode 153 | Final distance: 0.0196 | Success: True
# Episode 154 | Final distance: 0.0134 | Success: True
# Episode 155 | Final distance: 0.0285 | Success: False
# Episode 156 | Final distance: 0.0160 | Success: True
# Episode 157 | Final distance: 0.0144 | Success: True
# Episode 158 | Final distance: 0.0143 | Success: True
# Episode 159 | Final distance: 0.0191 | Success: True
# Episode 160 | Final distance: 0.0106 | Success: True
# Episode 161 | Final distance: 0.0090 | Success: True
# Episode 162 | Final distance: 0.0199 | Success: True
# Episode 163 | Final distance: 0.0140 | Success: True
# Episode 164 | Final distance: 0.0161 | Success: True
# Episode 165 | Final distance: 0.0138 | Success: True
# Episode 166 | Final distance: 0.0129 | Success: True
# Episode 167 | Final distance: 0.0146 | Success: True
# Episode 168 | Final distance: 0.0247 | Success: False
# Episode 169 | Final distance: 0.0310 | Success: False
# Episode 170 | Final distance: 0.0159 | Success: True
# Episode 171 | Final distance: 0.0193 | Success: True
# Episode 172 | Final distance: 0.0155 | Success: True
# Episode 173 | Final distance: 0.0188 | Success: True
# Episode 174 | Final distance: 0.0081 | Success: True
# Episode 175 | Final distance: 0.0085 | Success: True
# Episode 176 | Final distance: 0.0077 | Success: True
# Episode 177 | Final distance: 0.0178 | Success: True
# Episode 178 | Final distance: 0.0208 | Success: False
# Episode 179 | Final distance: 0.0194 | Success: True
# Episode 180 | Final distance: 0.0177 | Success: True
# Episode 181 | Final distance: 0.0179 | Success: True
# Episode 182 | Final distance: 0.0170 | Success: True
# Episode 183 | Final distance: 0.0174 | Success: True
# Episode 184 | Final distance: 0.0135 | Success: True
# Episode 185 | Final distance: 0.0143 | Success: True
# Episode 186 | Final distance: 0.0189 | Success: True
# Episode 187 | Final distance: 0.0193 | Success: True
# Episode 188 | Final distance: 0.0200 | Success: True
# Episode 189 | Final distance: 0.0089 | Success: True
# Episode 190 | Final distance: 0.0155 | Success: True
# Episode 191 | Final distance: 0.0192 | Success: True
# Episode 192 | Final distance: 0.0182 | Success: True
# Episode 193 | Final distance: 0.0193 | Success: True
# Episode 194 | Final distance: 0.0156 | Success: True
# Episode 195 | Final distance: 0.0196 | Success: True
# Episode 196 | Final distance: 0.0107 | Success: True
# Episode 197 | Final distance: 0.0187 | Success: True
# Episode 198 | Final distance: 0.0148 | Success: True
# Episode 199 | Final distance: 0.0153 | Success: True
# Episode 200 | Final distance: 0.0194 | Success: True
# Episode 201 | Final distance: 0.0182 | Success: True
# Episode 202 | Final distance: 0.0147 | Success: True
# Episode 203 | Final distance: 0.0131 | Success: True
# Episode 204 | Final distance: 0.0143 | Success: True
# Episode 205 | Final distance: 0.0190 | Success: True
# Episode 206 | Final distance: 0.0196 | Success: True
# Episode 207 | Final distance: 0.0189 | Success: True
# Episode 208 | Final distance: 0.0189 | Success: True
# Episode 209 | Final distance: 0.0152 | Success: True
# Episode 210 | Final distance: 0.0139 | Success: True
# Episode 211 | Final distance: 0.0112 | Success: True
# Episode 212 | Final distance: 0.0073 | Success: True
# Episode 213 | Final distance: 0.0301 | Success: False
# Episode 214 | Final distance: 0.0133 | Success: True
# Episode 215 | Final distance: 0.0315 | Success: False
# Episode 216 | Final distance: 0.0192 | Success: True
# Episode 217 | Final distance: 0.0140 | Success: True
# Episode 218 | Final distance: 0.0227 | Success: False
# Episode 219 | Final distance: 0.0138 | Success: True
# Episode 220 | Final distance: 0.0195 | Success: True
# Episode 221 | Final distance: 0.0091 | Success: True
# Episode 222 | Final distance: 0.0195 | Success: True
# Episode 223 | Final distance: 0.0171 | Success: True
# Episode 224 | Final distance: 0.0167 | Success: True
# Episode 225 | Final distance: 0.0124 | Success: True
# Episode 226 | Final distance: 0.0139 | Success: True
# Episode 227 | Final distance: 0.0180 | Success: True
# Episode 228 | Final distance: 0.0167 | Success: True
# Episode 229 | Final distance: 0.0224 | Success: False
# Episode 230 | Final distance: 0.0059 | Success: True
# Episode 231 | Final distance: 0.0108 | Success: True
# Episode 232 | Final distance: 0.0178 | Success: True
# Episode 233 | Final distance: 0.0191 | Success: True
# Episode 234 | Final distance: 0.0180 | Success: True
# Episode 235 | Final distance: 0.0086 | Success: True
# Episode 236 | Final distance: 0.0076 | Success: True
# Episode 237 | Final distance: 0.0134 | Success: True
# Episode 238 | Final distance: 0.0171 | Success: True
# Episode 239 | Final distance: 0.0198 | Success: True
# Episode 240 | Final distance: 0.0151 | Success: True
# Episode 241 | Final distance: 0.0163 | Success: True
# Episode 242 | Final distance: 0.0182 | Success: True
# Episode 243 | Final distance: 0.0232 | Success: False
# Episode 244 | Final distance: 0.0049 | Success: True
# Episode 245 | Final distance: 0.0115 | Success: True
# Episode 246 | Final distance: 0.0172 | Success: True
# Episode 247 | Final distance: 0.0108 | Success: True
# Episode 248 | Final distance: 0.0073 | Success: True
# Episode 249 | Final distance: 0.0154 | Success: True
# Episode 250 | Final distance: 0.0198 | Success: True
# Episode 251 | Final distance: 0.0132 | Success: True
# Episode 252 | Final distance: 0.0109 | Success: True
# Episode 253 | Final distance: 0.0165 | Success: True
# Episode 254 | Final distance: 0.0045 | Success: True
# Episode 255 | Final distance: 0.0161 | Success: True
# Episode 256 | Final distance: 0.0140 | Success: True
# Episode 257 | Final distance: 0.0089 | Success: True
# Episode 258 | Final distance: 0.0194 | Success: True
# Episode 259 | Final distance: 0.0121 | Success: True
# Episode 260 | Final distance: 0.0121 | Success: True
# Episode 261 | Final distance: 0.0133 | Success: True
# Episode 262 | Final distance: 0.0172 | Success: True
# Episode 263 | Final distance: 0.0139 | Success: True
# Episode 264 | Final distance: 0.0102 | Success: True
# Episode 265 | Final distance: 0.0174 | Success: True
# Episode 266 | Final distance: 0.0186 | Success: True
# Episode 267 | Final distance: 0.0119 | Success: True
# Episode 268 | Final distance: 0.0198 | Success: True
# Episode 269 | Final distance: 0.0167 | Success: True
# Episode 270 | Final distance: 0.0120 | Success: True
# Episode 271 | Final distance: 0.0136 | Success: True
# Episode 272 | Final distance: 0.0299 | Success: False
# Episode 273 | Final distance: 0.0172 | Success: True
# Episode 274 | Final distance: 0.0164 | Success: True
# Episode 275 | Final distance: 0.0210 | Success: False
# Episode 276 | Final distance: 0.0185 | Success: True
# Episode 277 | Final distance: 0.0158 | Success: True
# Episode 278 | Final distance: 0.0180 | Success: True
# Episode 279 | Final distance: 0.0079 | Success: True
# Episode 280 | Final distance: 0.0152 | Success: True
# Episode 281 | Final distance: 0.0192 | Success: True
# Episode 282 | Final distance: 0.0114 | Success: True
# Episode 283 | Final distance: 0.0180 | Success: True
# Episode 284 | Final distance: 0.0163 | Success: True
# Episode 285 | Final distance: 0.0158 | Success: True
# Episode 286 | Final distance: 0.0168 | Success: True
# Episode 287 | Final distance: 0.0166 | Success: True
# Episode 288 | Final distance: 0.0193 | Success: True
# Episode 289 | Final distance: 0.0192 | Success: True
# Episode 290 | Final distance: 0.0135 | Success: True
# Episode 291 | Final distance: 0.0182 | Success: True
# Episode 292 | Final distance: 0.0231 | Success: False
# Episode 293 | Final distance: 0.0177 | Success: True
# Episode 294 | Final distance: 0.0135 | Success: True
# Episode 295 | Final distance: 0.0111 | Success: True
# Episode 296 | Final distance: 0.0134 | Success: True
# Episode 297 | Final distance: 0.0167 | Success: True
# Episode 298 | Final distance: 0.0162 | Success: True
# Episode 299 | Final distance: 0.0096 | Success: True
# Episode 300 | Final distance: 0.0160 | Success: True
# Episode 301 | Final distance: 0.0128 | Success: True
# Episode 302 | Final distance: 0.0178 | Success: True
# Episode 303 | Final distance: 0.0162 | Success: True
# Episode 304 | Final distance: 0.0137 | Success: True
# Episode 305 | Final distance: 0.0164 | Success: True
# Episode 306 | Final distance: 0.0144 | Success: True
# Episode 307 | Final distance: 0.0129 | Success: True
# Episode 308 | Final distance: 0.0177 | Success: True
# Episode 309 | Final distance: 0.0132 | Success: True
# Episode 310 | Final distance: 0.0190 | Success: True
# Episode 311 | Final distance: 0.0084 | Success: True
# Episode 312 | Final distance: 0.0149 | Success: True
# Episode 313 | Final distance: 0.0108 | Success: True
# Episode 314 | Final distance: 0.0325 | Success: False
# Episode 315 | Final distance: 0.0157 | Success: True
# Episode 316 | Final distance: 0.0165 | Success: True
# Episode 317 | Final distance: 0.0175 | Success: True
# Episode 318 | Final distance: 0.0197 | Success: True
# Episode 319 | Final distance: 0.0181 | Success: True
# Episode 320 | Final distance: 0.0136 | Success: True
# Episode 321 | Final distance: 0.0106 | Success: True
# Episode 322 | Final distance: 0.0169 | Success: True
# Episode 323 | Final distance: 0.0177 | Success: True
# Episode 324 | Final distance: 0.0211 | Success: False
# Episode 325 | Final distance: 0.0147 | Success: True
# Episode 326 | Final distance: 0.0135 | Success: True
# Episode 327 | Final distance: 0.0146 | Success: True
# Episode 328 | Final distance: 0.0148 | Success: True
# Episode 329 | Final distance: 0.0140 | Success: True
# Episode 330 | Final distance: 0.0127 | Success: True
# Episode 331 | Final distance: 0.0199 | Success: True
# Episode 332 | Final distance: 0.0125 | Success: True
# Episode 333 | Final distance: 0.0099 | Success: True
# Episode 334 | Final distance: 0.0169 | Success: True
# Episode 335 | Final distance: 0.0120 | Success: True
# Episode 336 | Final distance: 0.0159 | Success: True
# Episode 337 | Final distance: 0.0188 | Success: True
# Episode 338 | Final distance: 0.0136 | Success: True
# Episode 339 | Final distance: 0.0043 | Success: True
# Episode 340 | Final distance: 0.0180 | Success: True
# Episode 341 | Final distance: 0.0168 | Success: True
# Episode 342 | Final distance: 0.0187 | Success: True
# Episode 343 | Final distance: 0.0178 | Success: True
# Episode 344 | Final distance: 0.0149 | Success: True
# Episode 345 | Final distance: 0.0163 | Success: True
# Episode 346 | Final distance: 0.0144 | Success: True
# Episode 347 | Final distance: 0.0175 | Success: True
# Episode 348 | Final distance: 0.0081 | Success: True
# Episode 349 | Final distance: 0.0203 | Success: False
# Episode 350 | Final distance: 0.0189 | Success: True
# Episode 351 | Final distance: 0.0189 | Success: True
# Episode 352 | Final distance: 0.0187 | Success: True
# Episode 353 | Final distance: 0.0185 | Success: True
# Episode 354 | Final distance: 0.0102 | Success: True
# Episode 355 | Final distance: 0.0146 | Success: True
# Episode 356 | Final distance: 0.0169 | Success: True
# Episode 357 | Final distance: 0.0133 | Success: True
# Episode 358 | Final distance: 0.0168 | Success: True
# Episode 359 | Final distance: 0.0188 | Success: True
# Episode 360 | Final distance: 0.0101 | Success: True
# Episode 361 | Final distance: 0.0130 | Success: True
# Episode 362 | Final distance: 0.0167 | Success: True
# Episode 363 | Final distance: 0.0183 | Success: True
# Episode 364 | Final distance: 0.0196 | Success: True
# Episode 365 | Final distance: 0.0111 | Success: True
# Episode 366 | Final distance: 0.0096 | Success: True
# Episode 367 | Final distance: 0.0196 | Success: True
# Episode 368 | Final distance: 0.0184 | Success: True
# Episode 369 | Final distance: 0.0319 | Success: False
# Episode 370 | Final distance: 0.0171 | Success: True
# Episode 371 | Final distance: 0.0142 | Success: True
# Episode 372 | Final distance: 0.0162 | Success: True
# Episode 373 | Final distance: 0.0178 | Success: True
# Episode 374 | Final distance: 0.0179 | Success: True
# Episode 375 | Final distance: 0.0191 | Success: True
# Episode 376 | Final distance: 0.0158 | Success: True
# Episode 377 | Final distance: 0.0134 | Success: True
# Episode 378 | Final distance: 0.0187 | Success: True
# Episode 379 | Final distance: 0.0130 | Success: True
# Episode 380 | Final distance: 0.0089 | Success: True
# Episode 381 | Final distance: 0.0122 | Success: True
# Episode 382 | Final distance: 0.0047 | Success: True
# Episode 383 | Final distance: 0.0079 | Success: True
# Episode 384 | Final distance: 0.0153 | Success: True
# Episode 385 | Final distance: 0.0148 | Success: True
# Episode 386 | Final distance: 0.0189 | Success: True
# Episode 387 | Final distance: 0.0175 | Success: True
# Episode 388 | Final distance: 0.0117 | Success: True
# Episode 389 | Final distance: 0.0121 | Success: True
# Episode 390 | Final distance: 0.0118 | Success: True
# Episode 391 | Final distance: 0.0169 | Success: True
# Episode 392 | Final distance: 0.0175 | Success: True
# Episode 393 | Final distance: 0.0180 | Success: True
# Episode 394 | Final distance: 0.0152 | Success: True
# Episode 395 | Final distance: 0.0154 | Success: True
# Episode 396 | Final distance: 0.0175 | Success: True
# Episode 397 | Final distance: 0.0167 | Success: True
# Episode 398 | Final distance: 0.0159 | Success: True
# Episode 399 | Final distance: 0.0167 | Success: True
# Episode 400 | Final distance: 0.0164 | Success: True
# Episode 401 | Final distance: 0.0101 | Success: True
# Episode 402 | Final distance: 0.0200 | Success: True
# Episode 403 | Final distance: 0.0194 | Success: True
# Episode 404 | Final distance: 0.0130 | Success: True
# Episode 405 | Final distance: 0.0190 | Success: True
# Episode 406 | Final distance: 0.0151 | Success: True
# Episode 407 | Final distance: 0.0153 | Success: True
# Episode 408 | Final distance: 0.0087 | Success: True
# Episode 409 | Final distance: 0.0199 | Success: True
# Episode 410 | Final distance: 0.0118 | Success: True
# Episode 411 | Final distance: 0.0240 | Success: False
# Episode 412 | Final distance: 0.0174 | Success: True
# Episode 413 | Final distance: 0.0119 | Success: True
# Episode 414 | Final distance: 0.0170 | Success: True
# Episode 415 | Final distance: 0.0159 | Success: True
# Episode 416 | Final distance: 0.0144 | Success: True
# Episode 417 | Final distance: 0.0173 | Success: True
# Episode 418 | Final distance: 0.0118 | Success: True
# Episode 419 | Final distance: 0.0190 | Success: True
# Episode 420 | Final distance: 0.0186 | Success: True
# Episode 421 | Final distance: 0.0150 | Success: True
# Episode 422 | Final distance: 0.0082 | Success: True
# Episode 423 | Final distance: 0.0197 | Success: True
# Episode 424 | Final distance: 0.0186 | Success: True
# Episode 425 | Final distance: 0.0172 | Success: True
# Episode 426 | Final distance: 0.0094 | Success: True
# Episode 427 | Final distance: 0.0108 | Success: True
# Episode 428 | Final distance: 0.0123 | Success: True
# Episode 429 | Final distance: 0.0046 | Success: True
# Episode 430 | Final distance: 0.0091 | Success: True
# Episode 431 | Final distance: 0.0121 | Success: True
# Episode 432 | Final distance: 0.0090 | Success: True
# Episode 433 | Final distance: 0.0118 | Success: True
# Episode 434 | Final distance: 0.0191 | Success: True
# Episode 435 | Final distance: 0.0149 | Success: True
# Episode 436 | Final distance: 0.0196 | Success: True
# Episode 437 | Final distance: 0.0182 | Success: True
# Episode 438 | Final distance: 0.0153 | Success: True
# Episode 439 | Final distance: 0.0143 | Success: True
# Episode 440 | Final distance: 0.0180 | Success: True
# Episode 441 | Final distance: 0.0187 | Success: True
# Episode 442 | Final distance: 0.0156 | Success: True
# Episode 443 | Final distance: 0.0095 | Success: True
# Episode 444 | Final distance: 0.0197 | Success: True
# Episode 445 | Final distance: 0.0103 | Success: True
# Episode 446 | Final distance: 0.0183 | Success: True
# Episode 447 | Final distance: 0.0189 | Success: True
# Episode 448 | Final distance: 0.0145 | Success: True
# Episode 449 | Final distance: 0.0180 | Success: True
# Episode 450 | Final distance: 0.0144 | Success: True
# Episode 451 | Final distance: 0.0191 | Success: True
# Episode 452 | Final distance: 0.0197 | Success: True
# Episode 453 | Final distance: 0.0163 | Success: True
# Episode 454 | Final distance: 0.0159 | Success: True
# Episode 455 | Final distance: 0.0096 | Success: True
# Episode 456 | Final distance: 0.0191 | Success: True
# Episode 457 | Final distance: 0.0169 | Success: True
# Episode 458 | Final distance: 0.0167 | Success: True
# Episode 459 | Final distance: 0.0144 | Success: True
# Episode 460 | Final distance: 0.0240 | Success: False
# Episode 461 | Final distance: 0.0182 | Success: True
# Episode 462 | Final distance: 0.0174 | Success: True
# Episode 463 | Final distance: 0.0110 | Success: True
# Episode 464 | Final distance: 0.0187 | Success: True
# Episode 465 | Final distance: 0.0184 | Success: True
# Episode 466 | Final distance: 0.0161 | Success: True
# Episode 467 | Final distance: 0.0195 | Success: True
# Episode 468 | Final distance: 0.0136 | Success: True
# Episode 469 | Final distance: 0.0185 | Success: True
# Episode 470 | Final distance: 0.0179 | Success: True
# Episode 471 | Final distance: 0.0181 | Success: True
# Episode 472 | Final distance: 0.0119 | Success: True
# Episode 473 | Final distance: 0.0161 | Success: True
# Episode 474 | Final distance: 0.0182 | Success: True
# Episode 475 | Final distance: 0.0183 | Success: True
# Episode 476 | Final distance: 0.0077 | Success: True
# Episode 477 | Final distance: 0.0074 | Success: True
# Episode 478 | Final distance: 0.0168 | Success: True
# Episode 479 | Final distance: 0.0139 | Success: True
# Episode 480 | Final distance: 0.0193 | Success: True
# Episode 481 | Final distance: 0.0183 | Success: True
# Episode 482 | Final distance: 0.0131 | Success: True
# Episode 483 | Final distance: 0.0129 | Success: True
# Episode 484 | Final distance: 0.0136 | Success: True
# Episode 485 | Final distance: 0.0163 | Success: True
# Episode 486 | Final distance: 0.0139 | Success: True
# Episode 487 | Final distance: 0.0189 | Success: True
# Episode 488 | Final distance: 0.0185 | Success: True
# Episode 489 | Final distance: 0.0194 | Success: True
# Episode 490 | Final distance: 0.0188 | Success: True
# Episode 491 | Final distance: 0.0183 | Success: True
# Episode 492 | Final distance: 0.0171 | Success: True
# Episode 493 | Final distance: 0.0109 | Success: True
# Episode 494 | Final distance: 0.0188 | Success: True
# Episode 495 | Final distance: 0.0197 | Success: True
# Episode 496 | Final distance: 0.0156 | Success: True
# Episode 497 | Final distance: 0.0138 | Success: True
# Episode 498 | Final distance: 0.0161 | Success: True
# Episode 499 | Final distance: 0.0166 | Success: True
# Episode 500 | Final distance: 0.0164 | Success: True
# Episode 501 | Final distance: 0.0284 | Success: False
# Episode 502 | Final distance: 0.0106 | Success: True
# Episode 503 | Final distance: 0.0105 | Success: True
# Episode 504 | Final distance: 0.0082 | Success: True
# Episode 505 | Final distance: 0.0098 | Success: True
# Episode 506 | Final distance: 0.0178 | Success: True
# Episode 507 | Final distance: 0.0147 | Success: True
# Episode 508 | Final distance: 0.0181 | Success: True
# Episode 509 | Final distance: 0.0180 | Success: True
# Episode 510 | Final distance: 0.0193 | Success: True
# Episode 511 | Final distance: 0.0098 | Success: True
# Episode 512 | Final distance: 0.0191 | Success: True
# Episode 513 | Final distance: 0.0129 | Success: True
# Episode 514 | Final distance: 0.0296 | Success: False
# Episode 515 | Final distance: 0.0099 | Success: True
# Episode 516 | Final distance: 0.0189 | Success: True
# Episode 517 | Final distance: 0.0177 | Success: True
# Episode 518 | Final distance: 0.0160 | Success: True
# Episode 519 | Final distance: 0.0165 | Success: True
# Episode 520 | Final distance: 0.0184 | Success: True
# Episode 521 | Final distance: 0.0181 | Success: True
# Episode 522 | Final distance: 0.0187 | Success: True
# Episode 523 | Final distance: 0.0179 | Success: True
# Episode 524 | Final distance: 0.0191 | Success: True
# Episode 525 | Final distance: 0.0060 | Success: True
# Episode 526 | Final distance: 0.0128 | Success: True
# Episode 527 | Final distance: 0.0174 | Success: True
# Episode 528 | Final distance: 0.0186 | Success: True
# Episode 529 | Final distance: 0.0188 | Success: True
# Episode 530 | Final distance: 0.0194 | Success: True
# Episode 531 | Final distance: 0.0194 | Success: True
# Episode 532 | Final distance: 0.0114 | Success: True
# Episode 533 | Final distance: 0.0189 | Success: True
# Episode 534 | Final distance: 0.0083 | Success: True
# Episode 535 | Final distance: 0.0152 | Success: True
# Episode 536 | Final distance: 0.0196 | Success: True
# Episode 537 | Final distance: 0.0161 | Success: True
# Episode 538 | Final distance: 0.0153 | Success: True
# Episode 539 | Final distance: 0.0166 | Success: True
# Episode 540 | Final distance: 0.0106 | Success: True
# Episode 541 | Final distance: 0.0185 | Success: True
# Episode 542 | Final distance: 0.0074 | Success: True
# Episode 543 | Final distance: 0.0177 | Success: True
# Episode 544 | Final distance: 0.0192 | Success: True
# Episode 545 | Final distance: 0.0196 | Success: True
# Episode 546 | Final distance: 0.0193 | Success: True
# Episode 547 | Final distance: 0.0185 | Success: True
# Episode 548 | Final distance: 0.0169 | Success: True
# Episode 549 | Final distance: 0.0192 | Success: True
# Episode 550 | Final distance: 0.0156 | Success: True
# Episode 551 | Final distance: 0.0158 | Success: True
# Episode 552 | Final distance: 0.0195 | Success: True
# Episode 553 | Final distance: 0.0199 | Success: True
# Episode 554 | Final distance: 0.0154 | Success: True
# Episode 555 | Final distance: 0.0082 | Success: True
# Episode 556 | Final distance: 0.0151 | Success: True
# Episode 557 | Final distance: 0.0069 | Success: True
# Episode 558 | Final distance: 0.0142 | Success: True
# Episode 559 | Final distance: 0.0082 | Success: True
# Episode 560 | Final distance: 0.0176 | Success: True
# Episode 561 | Final distance: 0.0167 | Success: True
# Episode 562 | Final distance: 0.0181 | Success: True
# Episode 563 | Final distance: 0.0074 | Success: True
# Episode 564 | Final distance: 0.0150 | Success: True
# Episode 565 | Final distance: 0.0194 | Success: True
# Episode 566 | Final distance: 0.0186 | Success: True
# Episode 567 | Final distance: 0.0135 | Success: True
# Episode 568 | Final distance: 0.0194 | Success: True
# Episode 569 | Final distance: 0.0091 | Success: True
# Episode 570 | Final distance: 0.0149 | Success: True
# Episode 571 | Final distance: 0.0178 | Success: True
# Episode 572 | Final distance: 0.0115 | Success: True
# Episode 573 | Final distance: 0.0189 | Success: True
# Episode 574 | Final distance: 0.0068 | Success: True
# Episode 575 | Final distance: 0.0172 | Success: True
# Episode 576 | Final distance: 0.0131 | Success: True
# Episode 577 | Final distance: 0.0185 | Success: True
# Episode 578 | Final distance: 0.0118 | Success: True
# Episode 579 | Final distance: 0.0155 | Success: True
# Episode 580 | Final distance: 0.0173 | Success: True
# Episode 581 | Final distance: 0.0106 | Success: True
# Episode 582 | Final distance: 0.0183 | Success: True
# Episode 583 | Final distance: 0.0134 | Success: True
# Episode 584 | Final distance: 0.0195 | Success: True
# Episode 585 | Final distance: 0.0193 | Success: True
# Episode 586 | Final distance: 0.0205 | Success: False
# Episode 587 | Final distance: 0.0179 | Success: True
# Episode 588 | Final distance: 0.0159 | Success: True
# Episode 589 | Final distance: 0.0153 | Success: True
# Episode 590 | Final distance: 0.0261 | Success: False
# Episode 591 | Final distance: 0.0175 | Success: True
# Episode 592 | Final distance: 0.0134 | Success: True
# Episode 593 | Final distance: 0.0175 | Success: True
# Episode 594 | Final distance: 0.0039 | Success: True
# Episode 595 | Final distance: 0.0168 | Success: True
# Episode 596 | Final distance: 0.0160 | Success: True
# Episode 597 | Final distance: 0.0199 | Success: True
# Episode 598 | Final distance: 0.0192 | Success: True
# Episode 599 | Final distance: 0.0145 | Success: True
# Episode 600 | Final distance: 0.0169 | Success: True
# Episode 601 | Final distance: 0.0155 | Success: True
# Episode 602 | Final distance: 0.0058 | Success: True
# Episode 603 | Final distance: 0.0145 | Success: True
# Episode 604 | Final distance: 0.0145 | Success: True
# Episode 605 | Final distance: 0.0049 | Success: True
# Episode 606 | Final distance: 0.0190 | Success: True
# Episode 607 | Final distance: 0.0199 | Success: True
# Episode 608 | Final distance: 0.0119 | Success: True
# Episode 609 | Final distance: 0.0175 | Success: True
# Episode 610 | Final distance: 0.0187 | Success: True
# Episode 611 | Final distance: 0.0183 | Success: True
# Episode 612 | Final distance: 0.0174 | Success: True
# Episode 613 | Final distance: 0.0150 | Success: True
# Episode 614 | Final distance: 0.0195 | Success: True
# Episode 615 | Final distance: 0.0185 | Success: True
# Episode 616 | Final distance: 0.0167 | Success: True
# Episode 617 | Final distance: 0.0077 | Success: True
# Episode 618 | Final distance: 0.0132 | Success: True
# Episode 619 | Final distance: 0.0146 | Success: True
# Episode 620 | Final distance: 0.0195 | Success: True
# Episode 621 | Final distance: 0.0185 | Success: True
# Episode 622 | Final distance: 0.0163 | Success: True
# Episode 623 | Final distance: 0.0171 | Success: True
# Episode 624 | Final distance: 0.0215 | Success: False
# Episode 625 | Final distance: 0.0125 | Success: True
# Episode 626 | Final distance: 0.0144 | Success: True
# Episode 627 | Final distance: 0.0145 | Success: True
# Episode 628 | Final distance: 0.0175 | Success: True
# Episode 629 | Final distance: 0.0151 | Success: True
# Episode 630 | Final distance: 0.0177 | Success: True
# Episode 631 | Final distance: 0.0061 | Success: True
# Episode 632 | Final distance: 0.0185 | Success: True
# Episode 633 | Final distance: 0.0198 | Success: True
# Episode 634 | Final distance: 0.0191 | Success: True
# Episode 635 | Final distance: 0.0162 | Success: True
# Episode 636 | Final distance: 0.0136 | Success: True
# Episode 637 | Final distance: 0.0182 | Success: True
# Episode 638 | Final distance: 0.0167 | Success: True
# Episode 639 | Final distance: 0.0160 | Success: True
# Episode 640 | Final distance: 0.0244 | Success: False
# Episode 641 | Final distance: 0.0067 | Success: True
# Episode 642 | Final distance: 0.0136 | Success: True
# Episode 643 | Final distance: 0.0179 | Success: True
# Episode 644 | Final distance: 0.0157 | Success: True
# Episode 645 | Final distance: 0.0140 | Success: True
# Episode 646 | Final distance: 0.0060 | Success: True
# Episode 647 | Final distance: 0.0198 | Success: True
# Episode 648 | Final distance: 0.0181 | Success: True
# Episode 649 | Final distance: 0.0188 | Success: True
# Episode 650 | Final distance: 0.0177 | Success: True
# Episode 651 | Final distance: 0.0189 | Success: True
# Episode 652 | Final distance: 0.0178 | Success: True
# Episode 653 | Final distance: 0.0184 | Success: True
# Episode 654 | Final distance: 0.0100 | Success: True
# Episode 655 | Final distance: 0.0060 | Success: True
# Episode 656 | Final distance: 0.0194 | Success: True
# Episode 657 | Final distance: 0.0210 | Success: False
# Episode 658 | Final distance: 0.0184 | Success: True
# Episode 659 | Final distance: 0.0129 | Success: True
# Episode 660 | Final distance: 0.0181 | Success: True
# Episode 661 | Final distance: 0.0104 | Success: True
# Episode 662 | Final distance: 0.0156 | Success: True
# Episode 663 | Final distance: 0.0195 | Success: True
# Episode 664 | Final distance: 0.0175 | Success: True
# Episode 665 | Final distance: 0.0198 | Success: True
# Episode 666 | Final distance: 0.0076 | Success: True
# Episode 667 | Final distance: 0.0118 | Success: True
# Episode 668 | Final distance: 0.0154 | Success: True
# Episode 669 | Final distance: 0.0163 | Success: True
# Episode 670 | Final distance: 0.0166 | Success: True
# Episode 671 | Final distance: 0.0138 | Success: True
# Episode 672 | Final distance: 0.0144 | Success: True
# Episode 673 | Final distance: 0.0182 | Success: True
# Episode 674 | Final distance: 0.0097 | Success: True
# Episode 675 | Final distance: 0.0180 | Success: True
# Episode 676 | Final distance: 0.0164 | Success: True
# Episode 677 | Final distance: 0.0180 | Success: True
# Episode 678 | Final distance: 0.0068 | Success: True
# Episode 679 | Final distance: 0.0164 | Success: True
# Episode 680 | Final distance: 0.0175 | Success: True
# Episode 681 | Final distance: 0.0103 | Success: True
# Episode 682 | Final distance: 0.0179 | Success: True
# Episode 683 | Final distance: 0.0165 | Success: True
# Episode 684 | Final distance: 0.0144 | Success: True
# Episode 685 | Final distance: 0.0174 | Success: True
# Episode 686 | Final distance: 0.0157 | Success: True
# Episode 687 | Final distance: 0.0194 | Success: True
# Episode 688 | Final distance: 0.0197 | Success: True
# Episode 689 | Final distance: 0.0155 | Success: True
# Episode 690 | Final distance: 0.0134 | Success: True
# Episode 691 | Final distance: 0.0149 | Success: True
# Episode 692 | Final distance: 0.0153 | Success: True
# Episode 693 | Final distance: 0.0171 | Success: True
# Episode 694 | Final distance: 0.0163 | Success: True
# Episode 695 | Final distance: 0.0244 | Success: False
# Episode 696 | Final distance: 0.0173 | Success: True
# Episode 697 | Final distance: 0.0109 | Success: True
# Episode 698 | Final distance: 0.0170 | Success: True
# Episode 699 | Final distance: 0.0170 | Success: True
# Episode 700 | Final distance: 0.0192 | Success: True
# Episode 701 | Final distance: 0.0183 | Success: True
# Episode 702 | Final distance: 0.0166 | Success: True
# Episode 703 | Final distance: 0.0160 | Success: True
# Episode 704 | Final distance: 0.0180 | Success: True
# Episode 705 | Final distance: 0.0182 | Success: True
# Episode 706 | Final distance: 0.0181 | Success: True
# Episode 707 | Final distance: 0.0188 | Success: True
# Episode 708 | Final distance: 0.0128 | Success: True
# Episode 709 | Final distance: 0.0115 | Success: True
# Episode 710 | Final distance: 0.0084 | Success: True
# Episode 711 | Final distance: 0.0124 | Success: True
# Episode 712 | Final distance: 0.0126 | Success: True
# Episode 713 | Final distance: 0.0150 | Success: True
# Episode 714 | Final distance: 0.0188 | Success: True
# Episode 715 | Final distance: 0.0150 | Success: True
# Episode 716 | Final distance: 0.0069 | Success: True
# Episode 717 | Final distance: 0.0144 | Success: True
# Episode 718 | Final distance: 0.0163 | Success: True
# Episode 719 | Final distance: 0.0193 | Success: True
# Episode 720 | Final distance: 0.0122 | Success: True
# Episode 721 | Final distance: 0.0127 | Success: True
# Episode 722 | Final distance: 0.0149 | Success: True
# Episode 723 | Final distance: 0.0097 | Success: True
# Episode 724 | Final distance: 0.0070 | Success: True
# Episode 725 | Final distance: 0.0178 | Success: True
# Episode 726 | Final distance: 0.0133 | Success: True
# Episode 727 | Final distance: 0.0103 | Success: True
# Episode 728 | Final distance: 0.0159 | Success: True
# Episode 729 | Final distance: 0.0088 | Success: True
# Episode 730 | Final distance: 0.0114 | Success: True
# Episode 731 | Final distance: 0.0195 | Success: True
# Episode 732 | Final distance: 0.0056 | Success: True
# Episode 733 | Final distance: 0.0161 | Success: True
# Episode 734 | Final distance: 0.0181 | Success: True
# Episode 735 | Final distance: 0.0113 | Success: True
# Episode 736 | Final distance: 0.0137 | Success: True
# Episode 737 | Final distance: 0.0233 | Success: False
# Episode 738 | Final distance: 0.0158 | Success: True
# Episode 739 | Final distance: 0.0157 | Success: True
# Episode 740 | Final distance: 0.0172 | Success: True
# Episode 741 | Final distance: 0.0177 | Success: True
# Episode 742 | Final distance: 0.0187 | Success: True
# Episode 743 | Final distance: 0.0149 | Success: True
# Episode 744 | Final distance: 0.0184 | Success: True
# Episode 745 | Final distance: 0.0061 | Success: True
# Episode 746 | Final distance: 0.0188 | Success: True
# Episode 747 | Final distance: 0.0194 | Success: True
# Episode 748 | Final distance: 0.0168 | Success: True
# Episode 749 | Final distance: 0.0170 | Success: True
# Episode 750 | Final distance: 0.0195 | Success: True
# Episode 751 | Final distance: 0.0195 | Success: True
# Episode 752 | Final distance: 0.0118 | Success: True
# Episode 753 | Final distance: 0.0151 | Success: True
# Episode 754 | Final distance: 0.0108 | Success: True
# Episode 755 | Final distance: 0.0176 | Success: True
# Episode 756 | Final distance: 0.0153 | Success: True
# Episode 757 | Final distance: 0.0181 | Success: True
# Episode 758 | Final distance: 0.0189 | Success: True
# Episode 759 | Final distance: 0.0168 | Success: True
# Episode 760 | Final distance: 0.0098 | Success: True
# Episode 761 | Final distance: 0.0190 | Success: True
# Episode 762 | Final distance: 0.0200 | Success: True
# Episode 763 | Final distance: 0.0166 | Success: True
# Episode 764 | Final distance: 0.0173 | Success: True
# Episode 765 | Final distance: 0.0173 | Success: True
# Episode 766 | Final distance: 0.0191 | Success: True
# Episode 767 | Final distance: 0.0200 | Success: True
# Episode 768 | Final distance: 0.0129 | Success: True
# Episode 769 | Final distance: 0.0084 | Success: True
# Episode 770 | Final distance: 0.0162 | Success: True
# Episode 771 | Final distance: 0.0101 | Success: True
# Episode 772 | Final distance: 0.0137 | Success: True
# Episode 773 | Final distance: 0.0157 | Success: True
# Episode 774 | Final distance: 0.0170 | Success: True
# Episode 775 | Final distance: 0.0142 | Success: True
# Episode 776 | Final distance: 0.0199 | Success: True
# Episode 777 | Final distance: 0.0154 | Success: True
# Episode 778 | Final distance: 0.0118 | Success: True
# Episode 779 | Final distance: 0.0156 | Success: True
# Episode 780 | Final distance: 0.0187 | Success: True
# Episode 781 | Final distance: 0.0133 | Success: True
# Episode 782 | Final distance: 0.0288 | Success: False
# Episode 783 | Final distance: 0.0191 | Success: True
# Episode 784 | Final distance: 0.0182 | Success: True
# Episode 785 | Final distance: 0.0133 | Success: True
# Episode 786 | Final distance: 0.0100 | Success: True
# Episode 787 | Final distance: 0.0143 | Success: True
# Episode 788 | Final distance: 0.0191 | Success: True
# Episode 789 | Final distance: 0.0176 | Success: True
# Episode 790 | Final distance: 0.0137 | Success: True
# Episode 791 | Final distance: 0.0160 | Success: True
# Episode 792 | Final distance: 0.0158 | Success: True
# Episode 793 | Final distance: 0.0117 | Success: True
# Episode 794 | Final distance: 0.0127 | Success: True
# Episode 795 | Final distance: 0.0189 | Success: True
# Episode 796 | Final distance: 0.0094 | Success: True
# Episode 797 | Final distance: 0.0144 | Success: True
# Episode 798 | Final distance: 0.0128 | Success: True
# Episode 799 | Final distance: 0.0262 | Success: False
# Episode 800 | Final distance: 0.0174 | Success: True
# Episode 801 | Final distance: 0.0158 | Success: True
# Episode 802 | Final distance: 0.0104 | Success: True
# Episode 803 | Final distance: 0.0051 | Success: True
# Episode 804 | Final distance: 0.0159 | Success: True
# Episode 805 | Final distance: 0.0184 | Success: True
# Episode 806 | Final distance: 0.0105 | Success: True
# Episode 807 | Final distance: 0.0192 | Success: True
# Episode 808 | Final distance: 0.0120 | Success: True
# Episode 809 | Final distance: 0.0172 | Success: True
# Episode 810 | Final distance: 0.0210 | Success: False
# Episode 811 | Final distance: 0.0113 | Success: True
# Episode 812 | Final distance: 0.0179 | Success: True
# Episode 813 | Final distance: 0.0198 | Success: True
# Episode 814 | Final distance: 0.0144 | Success: True
# Episode 815 | Final distance: 0.0190 | Success: True
# Episode 816 | Final distance: 0.0115 | Success: True
# Episode 817 | Final distance: 0.0171 | Success: True
# Episode 818 | Final distance: 0.0190 | Success: True
# Episode 819 | Final distance: 0.0171 | Success: True
# Episode 820 | Final distance: 0.0151 | Success: True
# Episode 821 | Final distance: 0.0118 | Success: True
# Episode 822 | Final distance: 0.0073 | Success: True
# Episode 823 | Final distance: 0.0076 | Success: True
# Episode 824 | Final distance: 0.0166 | Success: True
# Episode 825 | Final distance: 0.0139 | Success: True
# Episode 826 | Final distance: 0.0174 | Success: True
# Episode 827 | Final distance: 0.0077 | Success: True
# Episode 828 | Final distance: 0.0143 | Success: True
# Episode 829 | Final distance: 0.0186 | Success: True
# Episode 830 | Final distance: 0.0325 | Success: False
# Episode 831 | Final distance: 0.0168 | Success: True
# Episode 832 | Final distance: 0.0193 | Success: True
# Episode 833 | Final distance: 0.0143 | Success: True
# Episode 834 | Final distance: 0.0095 | Success: True
# Episode 835 | Final distance: 0.0171 | Success: True
# Episode 836 | Final distance: 0.0126 | Success: True
# Episode 837 | Final distance: 0.0074 | Success: True
# Episode 838 | Final distance: 0.0149 | Success: True
# Episode 839 | Final distance: 0.0164 | Success: True
# Episode 840 | Final distance: 0.0199 | Success: True
# Episode 841 | Final distance: 0.0166 | Success: True
# Episode 842 | Final distance: 0.0168 | Success: True
# Episode 843 | Final distance: 0.0171 | Success: True
# Episode 844 | Final distance: 0.0119 | Success: True
# Episode 845 | Final distance: 0.0101 | Success: True
# Episode 846 | Final distance: 0.0180 | Success: True
# Episode 847 | Final distance: 0.0163 | Success: True
# Episode 848 | Final distance: 0.0074 | Success: True
# Episode 849 | Final distance: 0.0129 | Success: True
# Episode 850 | Final distance: 0.0151 | Success: True
# Episode 851 | Final distance: 0.0144 | Success: True
# Episode 852 | Final distance: 0.0144 | Success: True
# Episode 853 | Final distance: 0.0175 | Success: True
# Episode 854 | Final distance: 0.0105 | Success: True
# Episode 855 | Final distance: 0.0165 | Success: True
# Episode 856 | Final distance: 0.0193 | Success: True
# Episode 857 | Final distance: 0.0142 | Success: True
# Episode 858 | Final distance: 0.0107 | Success: True
# Episode 859 | Final distance: 0.0184 | Success: True
# Episode 860 | Final distance: 0.0163 | Success: True
# Episode 861 | Final distance: 0.0080 | Success: True
# Episode 862 | Final distance: 0.0118 | Success: True
# Episode 863 | Final distance: 0.0143 | Success: True
# Episode 864 | Final distance: 0.0181 | Success: True
# Episode 865 | Final distance: 0.0187 | Success: True
# Episode 866 | Final distance: 0.0171 | Success: True
# Episode 867 | Final distance: 0.0120 | Success: True
# Episode 868 | Final distance: 0.0189 | Success: True
# Episode 869 | Final distance: 0.0149 | Success: True
# Episode 870 | Final distance: 0.0083 | Success: True
# Episode 871 | Final distance: 0.0188 | Success: True
# Episode 872 | Final distance: 0.0101 | Success: True
# Episode 873 | Final distance: 0.0192 | Success: True
# Episode 874 | Final distance: 0.0102 | Success: True
# Episode 875 | Final distance: 0.0101 | Success: True
# Episode 876 | Final distance: 0.0126 | Success: True
# Episode 877 | Final distance: 0.0213 | Success: False
# Episode 878 | Final distance: 0.0083 | Success: True
# Episode 879 | Final distance: 0.0115 | Success: True
# Episode 880 | Final distance: 0.0170 | Success: True
# Episode 881 | Final distance: 0.0157 | Success: True
# Episode 882 | Final distance: 0.0188 | Success: True
# Episode 883 | Final distance: 0.0187 | Success: True
# Episode 884 | Final distance: 0.0122 | Success: True
# Episode 885 | Final distance: 0.0109 | Success: True
# Episode 886 | Final distance: 0.0218 | Success: False
# Episode 887 | Final distance: 0.0181 | Success: True
# Episode 888 | Final distance: 0.0028 | Success: True
# Episode 889 | Final distance: 0.0125 | Success: True
# Episode 890 | Final distance: 0.0159 | Success: True
# Episode 891 | Final distance: 0.0184 | Success: True
# Episode 892 | Final distance: 0.0121 | Success: True
# Episode 893 | Final distance: 0.0161 | Success: True
# Episode 894 | Final distance: 0.0173 | Success: True
# Episode 895 | Final distance: 0.0111 | Success: True
# Episode 896 | Final distance: 0.0117 | Success: True
# Episode 897 | Final distance: 0.0161 | Success: True
# Episode 898 | Final distance: 0.0164 | Success: True
# Episode 899 | Final distance: 0.0047 | Success: True
# Episode 900 | Final distance: 0.0183 | Success: True
# Episode 901 | Final distance: 0.0177 | Success: True
# Episode 902 | Final distance: 0.0158 | Success: True
# Episode 903 | Final distance: 0.0123 | Success: True
# Episode 904 | Final distance: 0.0136 | Success: True
# Episode 905 | Final distance: 0.0107 | Success: True
# Episode 906 | Final distance: 0.0196 | Success: True
# Episode 907 | Final distance: 0.0144 | Success: True
# Episode 908 | Final distance: 0.0180 | Success: True
# Episode 909 | Final distance: 0.0200 | Success: True
# Episode 910 | Final distance: 0.0132 | Success: True
# Episode 911 | Final distance: 0.0079 | Success: True
# Episode 912 | Final distance: 0.0159 | Success: True
# Episode 913 | Final distance: 0.0189 | Success: True
# Episode 914 | Final distance: 0.0199 | Success: True
# Episode 915 | Final distance: 0.0187 | Success: True
# Episode 916 | Final distance: 0.0198 | Success: True
# Episode 917 | Final distance: 0.0145 | Success: True
# Episode 918 | Final distance: 0.0183 | Success: True
# Episode 919 | Final distance: 0.0193 | Success: True
# Episode 920 | Final distance: 0.0102 | Success: True
# Episode 921 | Final distance: 0.0151 | Success: True
# Episode 922 | Final distance: 0.0010 | Success: True
# Episode 923 | Final distance: 0.0155 | Success: True
# Episode 924 | Final distance: 0.0142 | Success: True
# Episode 925 | Final distance: 0.0112 | Success: True
# Episode 926 | Final distance: 0.0138 | Success: True
# Episode 927 | Final distance: 0.0104 | Success: True
# Episode 928 | Final distance: 0.0186 | Success: True
# Episode 929 | Final distance: 0.0089 | Success: True
# Episode 930 | Final distance: 0.0154 | Success: True
# Episode 931 | Final distance: 0.0186 | Success: True
# Episode 932 | Final distance: 0.0134 | Success: True
# Episode 933 | Final distance: 0.0156 | Success: True
# Episode 934 | Final distance: 0.0167 | Success: True
# Episode 935 | Final distance: 0.0147 | Success: True
# Episode 936 | Final distance: 0.0140 | Success: True
# Episode 937 | Final distance: 0.0105 | Success: True
# Episode 938 | Final distance: 0.0188 | Success: True
# Episode 939 | Final distance: 0.0156 | Success: True
# Episode 940 | Final distance: 0.0186 | Success: True
# Episode 941 | Final distance: 0.0139 | Success: True
# Episode 942 | Final distance: 0.0194 | Success: True
# Episode 943 | Final distance: 0.0193 | Success: True
# Episode 944 | Final distance: 0.0163 | Success: True
# Episode 945 | Final distance: 0.0154 | Success: True
# Episode 946 | Final distance: 0.0167 | Success: True
# Episode 947 | Final distance: 0.0172 | Success: True
# Episode 948 | Final distance: 0.0112 | Success: True
# Episode 949 | Final distance: 0.0199 | Success: True
# Episode 950 | Final distance: 0.0164 | Success: True
# Episode 951 | Final distance: 0.0100 | Success: True
# Episode 952 | Final distance: 0.0186 | Success: True
# Episode 953 | Final distance: 0.0159 | Success: True
# Episode 954 | Final distance: 0.0121 | Success: True
# Episode 955 | Final distance: 0.0165 | Success: True
# Episode 956 | Final distance: 0.0087 | Success: True
# Episode 957 | Final distance: 0.0096 | Success: True
# Episode 958 | Final distance: 0.0192 | Success: True
# Episode 959 | Final distance: 0.0101 | Success: True
# Episode 960 | Final distance: 0.0106 | Success: True
# Episode 961 | Final distance: 0.0163 | Success: True
# Episode 962 | Final distance: 0.0153 | Success: True
# Episode 963 | Final distance: 0.0110 | Success: True
# Episode 964 | Final distance: 0.0087 | Success: True
# Episode 965 | Final distance: 0.0097 | Success: True
# Episode 966 | Final distance: 0.0193 | Success: True
# Episode 967 | Final distance: 0.0097 | Success: True
# Episode 968 | Final distance: 0.0153 | Success: True
# Episode 969 | Final distance: 0.0185 | Success: True
# Episode 970 | Final distance: 0.0192 | Success: True
# Episode 971 | Final distance: 0.0143 | Success: True
# Episode 972 | Final distance: 0.0156 | Success: True
# Episode 973 | Final distance: 0.0139 | Success: True
# Episode 974 | Final distance: 0.0138 | Success: True
# Episode 975 | Final distance: 0.0177 | Success: True
# Episode 976 | Final distance: 0.0074 | Success: True
# Episode 977 | Final distance: 0.0160 | Success: True
# Episode 978 | Final distance: 0.0157 | Success: True
# Episode 979 | Final distance: 0.0091 | Success: True
# Episode 980 | Final distance: 0.0156 | Success: True
# Episode 981 | Final distance: 0.0158 | Success: True
# Episode 982 | Final distance: 0.0141 | Success: True
# Episode 983 | Final distance: 0.0195 | Success: True
# Episode 984 | Final distance: 0.0136 | Success: True
# Episode 985 | Final distance: 0.0119 | Success: True
# Episode 986 | Final distance: 0.0197 | Success: True
# Episode 987 | Final distance: 0.0198 | Success: True
# Episode 988 | Final distance: 0.0075 | Success: True
# Episode 989 | Final distance: 0.0183 | Success: True
# Episode 990 | Final distance: 0.0070 | Success: True
# Episode 991 | Final distance: 0.0138 | Success: True
# Episode 992 | Final distance: 0.0137 | Success: True
# Episode 993 | Final distance: 0.0220 | Success: False
# Episode 994 | Final distance: 0.0183 | Success: True
# Episode 995 | Final distance: 0.0085 | Success: True
# Episode 996 | Final distance: 0.0175 | Success: True
# Episode 997 | Final distance: 0.0082 | Success: True
# Episode 998 | Final distance: 0.0166 | Success: True
# Episode 999 | Final distance: 0.0117 | Success: True
# Episode 1000 | Final distance: 0.0172 | Success: True
# Success rate: 965/1001 | Avg final distance: 0.0154

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from environment import TrackingEnv
from ppo import PPOAgent, PolicyNet, ValueNet


def load_ppo_agent(checkpoint_path, state_dim, action_dim):
    agent = PPOAgent(state_dim, action_dim)
    checkpoint = torch.load(checkpoint_path, map_location=torch.device('cpu'))
    agent.actor.load_state_dict(checkpoint['actor_state_dict'])
    agent.critic.load_state_dict(checkpoint['critic_state_dict'])
    agent.eval()
    return agent


def test_ppo_agent(agent, env=None, num_episodes=1001, tolerance=0.02, save_dir="ppo_test_results"):
    if env is None:
        env = TrackingEnv()

    success_count = 0
    final_distances = []

    for ep in range(num_episodes):
        state, _ = env.reset()
        state = torch.tensor(state, dtype=torch.float32)
        done = False
        trajectory = []
        target_trajectory = []

        while not done:
            trajectory.append(state[:2].detach().numpy())
            target_trajectory.append(state[2:4].detach().numpy())
            with torch.no_grad():
                mu, sigma = agent.actor(state, training=False)  # No noise at test time
                action = mu  # Greedy action (no sampling)
            next_state, _, done, truncated, _, _ = env.step(action.numpy())
            next_state = torch.tensor(next_state, dtype=torch.float32)

            if torch.norm(next_state[:2] - next_state[2:4]) < tolerance or truncated:
                done = True

            state = next_state

        final_distance = torch.norm(state[:2] - state[2:4]).item()
        final_distances.append(final_distance)
        success = final_distance < tolerance
        if success:
            success_count += 1

        print(f"[Episode {ep}] Final distance: {final_distance:.4f} | Success: {success}")

        if ep % 100 == 0:
            trajectory = np.array(trajectory)
            target_trajectory = np.array(target_trajectory)
            plt.figure(figsize=(5, 5))
            plt.plot(trajectory[:, 0], trajectory[:, 1], label="Agent", color='blue')
            plt.plot(target_trajectory[:, 0], target_trajectory[:, 1], label="Target", color='red')
            plt.scatter(*trajectory[0], color='green', label='Start', s=100)
            plt.scatter(*target_trajectory[-1], color='red', label='Target End', s=100)
            plt.title(f"Episode {ep} | Success: {success}")
            plt.xlabel("X")
            plt.ylabel("Y")
            plt.legend()
            plt.grid()
            plt.axis('equal')
            plt.show()

    env.close()
    print(f"\nSuccess rate: {success_count}/{num_episodes}")
    print(f"Average final distance: {np.mean(final_distances):.4f}")


if __name__ == "__main__":
    checkpoint_path = "runs/ppo_run_static_noise20250412_182030/checkpoint_ep10000.pth"
    env = TrackingEnv()
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]

    agent = load_ppo_agent(checkpoint_path, state_dim, action_dim)
    test_ppo_agent(agent, env=env)
# Out:
# [Episode 0] Final distance: 0.0184 | Success: True
# [Episode 1] Final distance: 0.0147 | Success: True
# [Episode 2] Final distance: 0.0191 | Success: True
# [Episode 3] Final distance: 0.0171 | Success: True
# [Episode 4] Final distance: 0.0175 | Success: True
# [Episode 5] Final distance: 0.0148 | Success: True
# [Episode 6] Final distance: 0.0168 | Success: True
# [Episode 7] Final distance: 0.0193 | Success: True
# [Episode 8] Final distance: 0.0166 | Success: True
# [Episode 9] Final distance: 0.0174 | Success: True
# [Episode 10] Final distance: 0.0152 | Success: True
# [Episode 11] Final distance: 0.0192 | Success: True
# [Episode 12] Final distance: 0.0185 | Success: True
# [Episode 13] Final distance: 0.0183 | Success: True
# [Episode 14] Final distance: 0.0171 | Success: True
# [Episode 15] Final distance: 0.0167 | Success: True
# [Episode 16] Final distance: 0.0139 | Success: True
# [Episode 17] Final distance: 0.0199 | Success: True
# [Episode 18] Final distance: 0.0189 | Success: True
# [Episode 19] Final distance: 0.0194 | Success: True
# [Episode 20] Final distance: 0.0185 | Success: True
# [Episode 21] Final distance: 0.0125 | Success: True
# [Episode 22] Final distance: 0.0162 | Success: True
# [Episode 23] Final distance: 0.0200 | Success: True
# [Episode 24] Final distance: 0.0191 | Success: True
# [Episode 25] Final distance: 0.0189 | Success: True
# [Episode 26] Final distance: 0.0182 | Success: True
# [Episode 27] Final distance: 0.0176 | Success: True
# [Episode 28] Final distance: 0.0194 | Success: True
# [Episode 29] Final distance: 0.0184 | Success: True
# [Episode 30] Final distance: 0.0169 | Success: True
# [Episode 31] Final distance: 0.0192 | Success: True
# [Episode 32] Final distance: 0.0197 | Success: True
# [Episode 33] Final distance: 0.0148 | Success: True
# [Episode 34] Final distance: 0.0196 | Success: True
# [Episode 35] Final distance: 0.0170 | Success: True
# [Episode 36] Final distance: 0.0187 | Success: True
# [Episode 37] Final distance: 0.0139 | Success: True
# [Episode 38] Final distance: 0.0149 | Success: True
# [Episode 39] Final distance: 0.0168 | Success: True
# [Episode 40] Final distance: 0.0163 | Success: True
# [Episode 41] Final distance: 0.0155 | Success: True
# [Episode 42] Final distance: 0.0175 | Success: True
# [Episode 43] Final distance: 0.0191 | Success: True
# [Episode 44] Final distance: 0.0175 | Success: True
# [Episode 45] Final distance: 0.0149 | Success: True
# [Episode 46] Final distance: 0.0152 | Success: True
# [Episode 47] Final distance: 0.0150 | Success: True
# [Episode 48] Final distance: 0.0139 | Success: True
# [Episode 49] Final distance: 0.0199 | Success: True
# [Episode 50] Final distance: 0.0177 | Success: True
# [Episode 51] Final distance: 0.0190 | Success: True
# [Episode 52] Final distance: 0.0149 | Success: True
# [Episode 53] Final distance: 0.0133 | Success: True
# [Episode 54] Final distance: 0.0169 | Success: True
# [Episode 55] Final distance: 0.0186 | Success: True
# [Episode 56] Final distance: 0.0129 | Success: True
# [Episode 57] Final distance: 0.0211 | Success: False
# [Episode 58] Final distance: 0.0184 | Success: True
# [Episode 59] Final distance: 0.0196 | Success: True
# [Episode 60] Final distance: 0.0197 | Success: True
# [Episode 61] Final distance: 0.0197 | Success: True
# [Episode 62] Final distance: 0.0195 | Success: True
# [Episode 63] Final distance: 0.0190 | Success: True
# [Episode 64] Final distance: 0.0155 | Success: True
# [Episode 65] Final distance: 0.0181 | Success: True
# [Episode 66] Final distance: 0.0197 | Success: True
# [Episode 67] Final distance: 0.0154 | Success: True
# [Episode 68] Final distance: 0.0152 | Success: True
# [Episode 69] Final distance: 0.0184 | Success: True
# [Episode 70] Final distance: 0.0166 | Success: True
# [Episode 71] Final distance: 0.0179 | Success: True
# [Episode 72] Final distance: 0.0192 | Success: True
# [Episode 73] Final distance: 0.0134 | Success: True
# [Episode 74] Final distance: 0.0190 | Success: True
# [Episode 75] Final distance: 0.0175 | Success: True
# [Episode 76] Final distance: 0.0157 | Success: True
# [Episode 77] Final distance: 0.0188 | Success: True
# [Episode 78] Final distance: 0.0158 | Success: True
# [Episode 79] Final distance: 0.0180 | Success: True
# [Episode 80] Final distance: 0.0161 | Success: True
# [Episode 81] Final distance: 0.0180 | Success: True
# [Episode 82] Final distance: 0.0148 | Success: True
# [Episode 83] Final distance: 0.0131 | Success: True
# [Episode 84] Final distance: 0.0151 | Success: True
# [Episode 85] Final distance: 0.0197 | Success: True
# [Episode 86] Final distance: 0.0156 | Success: True
# [Episode 87] Final distance: 0.0156 | Success: True
# [Episode 88] Final distance: 0.0127 | Success: True
# [Episode 89] Final distance: 0.0111 | Success: True
# [Episode 90] Final distance: 0.0183 | Success: True
# [Episode 91] Final distance: 0.0178 | Success: True
# [Episode 92] Final distance: 0.0160 | Success: True
# [Episode 93] Final distance: 0.0160 | Success: True
# [Episode 94] Final distance: 0.0172 | Success: True
# [Episode 95] Final distance: 0.0172 | Success: True
# [Episode 96] Final distance: 0.0194 | Success: True
# [Episode 97] Final distance: 0.0196 | Success: True
# [Episode 98] Final distance: 0.0168 | Success: True
# [Episode 99] Final distance: 0.0177 | Success: True
# [Episode 100] Final distance: 0.0190 | Success: True
# [Episode 101] Final distance: 0.0126 | Success: True
# [Episode 102] Final distance: 0.0188 | Success: True
# [Episode 103] Final distance: 0.0185 | Success: True
# [Episode 104] Final distance: 0.0184 | Success: True
# [Episode 105] Final distance: 0.0147 | Success: True
# [Episode 106] Final distance: 0.0182 | Success: True
# [Episode 107] Final distance: 0.0178 | Success: True
# [Episode 108] Final distance: 0.0143 | Success: True
# [Episode 109] Final distance: 0.0174 | Success: True
# [Episode 110] Final distance: 0.0195 | Success: True
# [Episode 111] Final distance: 0.0183 | Success: True
# [Episode 112] Final distance: 0.0151 | Success: True
# [Episode 113] Final distance: 0.0160 | Success: True
# [Episode 114] Final distance: 0.0177 | Success: True
# [Episode 115] Final distance: 0.0153 | Success: True
# [Episode 116] Final distance: 0.0152 | Success: True
# [Episode 117] Final distance: 0.0198 | Success: True
# [Episode 118] Final distance: 0.0200 | Success: True
# [Episode 119] Final distance: 0.0156 | Success: True
# [Episode 120] Final distance: 0.0192 | Success: True
# [Episode 121] Final distance: 0.0156 | Success: True
# [Episode 122] Final distance: 0.0173 | Success: True
# [Episode 123] Final distance: 0.0182 | Success: True
# [Episode 124] Final distance: 0.0183 | Success: True
# [Episode 125] Final distance: 0.0191 | Success: True
# [Episode 126] Final distance: 0.0171 | Success: True
# [Episode 127] Final distance: 0.0176 | Success: True
# [Episode 128] Final distance: 0.0155 | Success: True
# [Episode 129] Final distance: 0.0180 | Success: True
# [Episode 130] Final distance: 0.0167 | Success: True
# [Episode 131] Final distance: 0.0139 | Success: True
# [Episode 132] Final distance: 0.0189 | Success: True
# [Episode 133] Final distance: 0.0195 | Success: True
# [Episode 134] Final distance: 0.0191 | Success: True
# [Episode 135] Final distance: 0.0198 | Success: True
# [Episode 136] Final distance: 0.0130 | Success: True
# [Episode 137] Final distance: 0.0179 | Success: True
# [Episode 138] Final distance: 0.0172 | Success: True
# [Episode 139] Final distance: 0.0126 | Success: True
# [Episode 140] Final distance: 0.0184 | Success: True
# [Episode 141] Final distance: 0.0183 | Success: True
# [Episode 142] Final distance: 0.0145 | Success: True
# [Episode 143] Final distance: 0.0184 | Success: True
# [Episode 144] Final distance: 0.0161 | Success: True
# [Episode 145] Final distance: 0.0143 | Success: True
# [Episode 146] Final distance: 0.0184 | Success: True
# [Episode 147] Final distance: 0.0196 | Success: True
# [Episode 148] Final distance: 0.0160 | Success: True
# [Episode 149] Final distance: 0.0142 | Success: True
# [Episode 150] Final distance: 0.0143 | Success: True
# [Episode 151] Final distance: 0.0186 | Success: True
# [Episode 152] Final distance: 0.0189 | Success: True
# [Episode 153] Final distance: 0.0159 | Success: True
# [Episode 154] Final distance: 0.0171 | Success: True
# [Episode 155] Final distance: 0.0189 | Success: True
# [Episode 156] Final distance: 0.0151 | Success: True
# [Episode 157] Final distance: 0.0184 | Success: True
# [Episode 158] Final distance: 0.0170 | Success: True
# [Episode 159] Final distance: 0.0135 | Success: True
# [Episode 160] Final distance: 0.0189 | Success: True
# [Episode 161] Final distance: 0.0155 | Success: True
# [Episode 162] Final distance: 0.0171 | Success: True
# [Episode 163] Final distance: 0.0185 | Success: True
# [Episode 164] Final distance: 0.0145 | Success: True
# [Episode 165] Final distance: 0.0171 | Success: True
# [Episode 166] Final distance: 0.0191 | Success: True
# [Episode 167] Final distance: 0.0134 | Success: True
# [Episode 168] Final distance: 0.0198 | Success: True
# [Episode 169] Final distance: 0.0190 | Success: True
# [Episode 170] Final distance: 0.0168 | Success: True
# [Episode 171] Final distance: 0.0178 | Success: True
# [Episode 172] Final distance: 0.0166 | Success: True
# [Episode 173] Final distance: 0.0129 | Success: True
# [Episode 174] Final distance: 0.0146 | Success: True
# [Episode 175] Final distance: 0.0159 | Success: True
# [Episode 176] Final distance: 0.0251 | Success: False
# [Episode 177] Final distance: 0.0148 | Success: True
# [Episode 178] Final distance: 0.0180 | Success: True
# [Episode 179] Final distance: 0.0156 | Success: True
# [Episode 180] Final distance: 0.0195 | Success: True
# [Episode 181] Final distance: 0.0177 | Success: True
# [Episode 182] Final distance: 0.0199 | Success: True
# [Episode 183] Final distance: 0.0191 | Success: True
# [Episode 184] Final distance: 0.0155 | Success: True
# [Episode 185] Final distance: 0.0167 | Success: True
# [Episode 186] Final distance: 0.0170 | Success: True
# [Episode 187] Final distance: 0.0198 | Success: True
# [Episode 188] Final distance: 0.0139 | Success: True
# [Episode 189] Final distance: 0.0161 | Success: True
# [Episode 190] Final distance: 0.0190 | Success: True
# [Episode 191] Final distance: 0.0193 | Success: True
# [Episode 192] Final distance: 0.0176 | Success: True
# [Episode 193] Final distance: 0.0198 | Success: True
# [Episode 194] Final distance: 0.0161 | Success: True
# [Episode 195] Final distance: 0.0190 | Success: True
# [Episode 196] Final distance: 0.0140 | Success: True
# [Episode 197] Final distance: 0.0179 | Success: True
# [Episode 198] Final distance: 0.0192 | Success: True
# [Episode 199] Final distance: 0.0171 | Success: True
# [Episode 200] Final distance: 0.0167 | Success: True
# [Episode 201] Final distance: 0.0155 | Success: True
# [Episode 202] Final distance: 0.0194 | Success: True
# [Episode 203] Final distance: 0.0189 | Success: True
# [Episode 204] Final distance: 0.0193 | Success: True
# [Episode 205] Final distance: 0.0198 | Success: True
# [Episode 206] Final distance: 0.0161 | Success: True
# [Episode 207] Final distance: 0.0132 | Success: True
# [Episode 208] Final distance: 0.0173 | Success: True
# [Episode 209] Final distance: 0.0189 | Success: True
# [Episode 210] Final distance: 0.0193 | Success: True
# [Episode 211] Final distance: 0.0178 | Success: True
# [Episode 212] Final distance: 0.0186 | Success: True
# [Episode 213] Final distance: 0.0147 | Success: True
# [Episode 214] Final distance: 0.0181 | Success: True
# [Episode 215] Final distance: 0.0194 | Success: True
# [Episode 216] Final distance: 0.0185 | Success: True
# [Episode 217] Final distance: 0.0173 | Success: True
# [Episode 218] Final distance: 0.0193 | Success: True
# [Episode 219] Final distance: 0.0198 | Success: True
# [Episode 220] Final distance: 0.0193 | Success: True
# [Episode 221] Final distance: 0.0198 | Success: True
# [Episode 222] Final distance: 0.0153 | Success: True
# [Episode 223] Final distance: 0.0176 | Success: True
# [Episode 224] Final distance: 0.0195 | Success: True
# [Episode 225] Final distance: 0.0193 | Success: True
# [Episode 226] Final distance: 0.0200 | Success: True
# [Episode 227] Final distance: 0.0184 | Success: True
# [Episode 228] Final distance: 0.0173 | Success: True
# [Episode 229] Final distance: 0.0200 | Success: True
# [Episode 230] Final distance: 0.0153 | Success: True
# [Episode 231] Final distance: 0.0169 | Success: True
# [Episode 232] Final distance: 0.0121 | Success: True
# [Episode 233] Final distance: 0.0162 | Success: True
# [Episode 234] Final distance: 0.0183 | Success: True
# [Episode 235] Final distance: 0.0188 | Success: True
# [Episode 236] Final distance: 0.0190 | Success: True
# [Episode 237] Final distance: 0.0171 | Success: True
# [Episode 238] Final distance: 0.0193 | Success: True
# [Episode 239] Final distance: 0.0131 | Success: True
# [Episode 240] Final distance: 0.0193 | Success: True
# [Episode 241] Final distance: 0.0189 | Success: True
# [Episode 242] Final distance: 0.0161 | Success: True
# [Episode 243] Final distance: 0.0186 | Success: True
# [Episode 244] Final distance: 0.0182 | Success: True
# [Episode 245] Final distance: 0.0154 | Success: True
# [Episode 246] Final distance: 0.0186 | Success: True
# [Episode 247] Final distance: 0.0188 | Success: True
# [Episode 248] Final distance: 0.0141 | Success: True
# [Episode 249] Final distance: 0.0191 | Success: True
# [Episode 250] Final distance: 0.0191 | Success: True
# [Episode 251] Final distance: 0.0160 | Success: True
# [Episode 252] Final distance: 0.0171 | Success: True
# [Episode 253] Final distance: 0.0188 | Success: True
# [Episode 254] Final distance: 0.0183 | Success: True
# [Episode 255] Final distance: 0.0149 | Success: True
# [Episode 256] Final distance: 0.0151 | Success: True
# [Episode 257] Final distance: 0.0198 | Success: True
# [Episode 258] Final distance: 0.0172 | Success: True
# [Episode 259] Final distance: 0.0157 | Success: True
# [Episode 260] Final distance: 0.0186 | Success: True
# [Episode 261] Final distance: 0.0137 | Success: True
# [Episode 262] Final distance: 0.0187 | Success: True
# [Episode 263] Final distance: 0.0195 | Success: True
# [Episode 264] Final distance: 0.0197 | Success: True
# [Episode 265] Final distance: 0.0203 | Success: False
# [Episode 266] Final distance: 0.0154 | Success: True
# [Episode 267] Final distance: 0.0199 | Success: True
# [Episode 268] Final distance: 0.0154 | Success: True
# [Episode 269] Final distance: 0.0147 | Success: True
# [Episode 270] Final distance: 0.0184 | Success: True
# [Episode 271] Final distance: 0.0186 | Success: True
# [Episode 272] Final distance: 0.0156 | Success: True
# [Episode 273] Final distance: 0.0181 | Success: True
# [Episode 274] Final distance: 0.0187 | Success: True
# [Episode 275] Final distance: 0.0181 | Success: True
# [Episode 276] Final distance: 0.0128 | Success: True
# [Episode 277] Final distance: 0.0190 | Success: True
# [Episode 278] Final distance: 0.0186 | Success: True
# [Episode 279] Final distance: 0.0152 | Success: True
# [Episode 280] Final distance: 0.0190 | Success: True
# [Episode 281] Final distance: 0.0141 | Success: True
# [Episode 282] Final distance: 0.0151 | Success: True
# [Episode 283] Final distance: 0.0179 | Success: True
# [Episode 284] Final distance: 0.0159 | Success: True
# [Episode 285] Final distance: 0.0190 | Success: True
# [Episode 286] Final distance: 0.0192 | Success: True
# [Episode 287] Final distance: 0.0177 | Success: True
# [Episode 288] Final distance: 0.0156 | Success: True
# [Episode 289] Final distance: 0.0198 | Success: True
# [Episode 290] Final distance: 0.0200 | Success: True
# [Episode 291] Final distance: 0.0115 | Success: True
# [Episode 292] Final distance: 0.0180 | Success: True
# [Episode 293] Final distance: 0.0194 | Success: True
# [Episode 294] Final distance: 0.0186 | Success: True
# [Episode 295] Final distance: 0.0156 | Success: True
# [Episode 296] Final distance: 0.0172 | Success: True
# [Episode 297] Final distance: 0.0193 | Success: True
# [Episode 298] Final distance: 0.0189 | Success: True
# [Episode 299] Final distance: 0.0168 | Success: True
# [Episode 300] Final distance: 0.0169 | Success: True
# [Episode 301] Final distance: 0.0179 | Success: True
# [Episode 302] Final distance: 0.0176 | Success: True
# [Episode 303] Final distance: 0.0170 | Success: True
# [Episode 304] Final distance: 0.0193 | Success: True
# [Episode 305] Final distance: 0.0186 | Success: True
# [Episode 306] Final distance: 0.0186 | Success: True
# [Episode 307] Final distance: 0.0191 | Success: True
# [Episode 308] Final distance: 0.0169 | Success: True
# [Episode 309] Final distance: 0.0183 | Success: True
# [Episode 310] Final distance: 0.0194 | Success: True
# [Episode 311] Final distance: 0.0196 | Success: True
# [Episode 312] Final distance: 0.0218 | Success: False
# [Episode 313] Final distance: 0.0160 | Success: True
# [Episode 314] Final distance: 0.0196 | Success: True
# [Episode 315] Final distance: 0.0197 | Success: True
# [Episode 316] Final distance: 0.0191 | Success: True
# [Episode 317] Final distance: 0.0162 | Success: True
# [Episode 318] Final distance: 0.0163 | Success: True
# [Episode 319] Final distance: 0.0175 | Success: True
# [Episode 320] Final distance: 0.0193 | Success: True
# [Episode 321] Final distance: 0.0182 | Success: True
# [Episode 322] Final distance: 0.0198 | Success: True
# [Episode 323] Final distance: 0.0187 | Success: True
# [Episode 324] Final distance: 0.0163 | Success: True
# [Episode 325] Final distance: 0.0172 | Success: True
# [Episode 326] Final distance: 0.0193 | Success: True
# [Episode 327] Final distance: 0.0195 | Success: True
# [Episode 328] Final distance: 0.0187 | Success: True
# [Episode 329] Final distance: 0.0160 | Success: True
# [Episode 330] Final distance: 0.0158 | Success: True
# [Episode 331] Final distance: 0.0157 | Success: True
# [Episode 332] Final distance: 0.0157 | Success: True
# [Episode 333] Final distance: 0.0159 | Success: True
# [Episode 334] Final distance: 0.0177 | Success: True
# [Episode 335] Final distance: 0.0141 | Success: True
# [Episode 336] Final distance: 0.0147 | Success: True
# [Episode 337] Final distance: 0.0185 | Success: True
# [Episode 338] Final distance: 0.0191 | Success: True
# [Episode 339] Final distance: 0.0177 | Success: True
# [Episode 340] Final distance: 0.0192 | Success: True
# [Episode 341] Final distance: 0.0195 | Success: True
# [Episode 342] Final distance: 0.0150 | Success: True
# [Episode 343] Final distance: 0.0146 | Success: True
# [Episode 344] Final distance: 0.0177 | Success: True
# [Episode 345] Final distance: 0.0144 | Success: True
# [Episode 346] Final distance: 0.0165 | Success: True
# [Episode 347] Final distance: 0.0152 | Success: True
# [Episode 348] Final distance: 0.0189 | Success: True
# [Episode 349] Final distance: 0.0165 | Success: True
# [Episode 350] Final distance: 0.0160 | Success: True
# [Episode 351] Final distance: 0.0192 | Success: True
# [Episode 352] Final distance: 0.0168 | Success: True
# [Episode 353] Final distance: 0.0196 | Success: True
# [Episode 354] Final distance: 0.0155 | Success: True
# [Episode 355] Final distance: 0.0172 | Success: True
# [Episode 356] Final distance: 0.0199 | Success: True
# [Episode 357] Final distance: 0.0156 | Success: True
# [Episode 358] Final distance: 0.0143 | Success: True
# [Episode 359] Final distance: 0.0178 | Success: True
# [Episode 360] Final distance: 0.0194 | Success: True
# [Episode 361] Final distance: 0.0185 | Success: True
# [Episode 362] Final distance: 0.0195 | Success: True
# [Episode 363] Final distance: 0.0187 | Success: True
# [Episode 364] Final distance: 0.0159 | Success: True
# [Episode 365] Final distance: 0.0192 | Success: True
# [Episode 366] Final distance: 0.0172 | Success: True
# [Episode 367] Final distance: 0.0199 | Success: True
# [Episode 368] Final distance: 0.0157 | Success: True
# [Episode 369] Final distance: 0.0218 | Success: False
# [Episode 370] Final distance: 0.0187 | Success: True
# [Episode 371] Final distance: 0.0184 | Success: True
# [Episode 372] Final distance: 0.0137 | Success: True
# [Episode 373] Final distance: 0.0190 | Success: True
# [Episode 374] Final distance: 0.0138 | Success: True
# [Episode 375] Final distance: 0.0180 | Success: True
# [Episode 376] Final distance: 0.0185 | Success: True
# [Episode 377] Final distance: 0.0190 | Success: True
# [Episode 378] Final distance: 0.0153 | Success: True
# [Episode 379] Final distance: 0.0189 | Success: True
# [Episode 380] Final distance: 0.0162 | Success: True
# [Episode 381] Final distance: 0.0177 | Success: True
# [Episode 382] Final distance: 0.0152 | Success: True
# [Episode 383] Final distance: 0.0148 | Success: True
# [Episode 384] Final distance: 0.0187 | Success: True
# [Episode 385] Final distance: 0.0198 | Success: True
# [Episode 386] Final distance: 0.0221 | Success: False
# [Episode 387] Final distance: 0.0128 | Success: True
# [Episode 388] Final distance: 0.0156 | Success: True
# [Episode 389] Final distance: 0.0171 | Success: True
# [Episode 390] Final distance: 0.0157 | Success: True
# [Episode 391] Final distance: 0.0174 | Success: True
# [Episode 392] Final distance: 0.0195 | Success: True
# [Episode 393] Final distance: 0.0131 | Success: True
# [Episode 394] Final distance: 0.0195 | Success: True
# [Episode 395] Final distance: 0.0159 | Success: True
# [Episode 396] Final distance: 0.0194 | Success: True
# [Episode 397] Final distance: 0.0164 | Success: True
# [Episode 398] Final distance: 0.0151 | Success: True
# [Episode 399] Final distance: 0.0126 | Success: True
# [Episode 400] Final distance: 0.0197 | Success: True
# [Episode 401] Final distance: 0.0134 | Success: True
# [Episode 402] Final distance: 0.0188 | Success: True
# [Episode 403] Final distance: 0.0150 | Success: True
# [Episode 404] Final distance: 0.0151 | Success: True
# [Episode 405] Final distance: 0.0184 | Success: True
# [Episode 406] Final distance: 0.0185 | Success: True
# [Episode 407] Final distance: 0.0135 | Success: True
# [Episode 408] Final distance: 0.0192 | Success: True
# [Episode 409] Final distance: 0.0194 | Success: True
# [Episode 410] Final distance: 0.0170 | Success: True
# [Episode 411] Final distance: 0.0162 | Success: True
# [Episode 412] Final distance: 0.0172 | Success: True
# [Episode 413] Final distance: 0.0162 | Success: True
# [Episode 414] Final distance: 0.0182 | Success: True
# [Episode 415] Final distance: 0.0141 | Success: True
# [Episode 416] Final distance: 0.0189 | Success: True
# [Episode 417] Final distance: 0.0200 | Success: True
# [Episode 418] Final distance: 0.0191 | Success: True
# [Episode 419] Final distance: 0.0196 | Success: True
# [Episode 420] Final distance: 0.0178 | Success: True
# [Episode 421] Final distance: 0.0114 | Success: True
# [Episode 422] Final distance: 0.0170 | Success: True
# [Episode 423] Final distance: 0.0139 | Success: True
# [Episode 424] Final distance: 0.0181 | Success: True
# [Episode 425] Final distance: 0.0166 | Success: True
# [Episode 426] Final distance: 0.0199 | Success: True
# [Episode 427] Final distance: 0.0165 | Success: True
# [Episode 428] Final distance: 0.0188 | Success: True
# [Episode 429] Final distance: 0.0146 | Success: True
# [Episode 430] Final distance: 0.0187 | Success: True
# [Episode 431] Final distance: 0.0193 | Success: True
# [Episode 432] Final distance: 0.0173 | Success: True
# [Episode 433] Final distance: 0.0149 | Success: True
# [Episode 434] Final distance: 0.0169 | Success: True
# [Episode 435] Final distance: 0.0198 | Success: True
# [Episode 436] Final distance: 0.0200 | Success: True
# [Episode 437] Final distance: 0.0155 | Success: True
# [Episode 438] Final distance: 0.0161 | Success: True
# [Episode 439] Final distance: 0.0137 | Success: True
# [Episode 440] Final distance: 0.0162 | Success: True
# [Episode 441] Final distance: 0.0196 | Success: True
# [Episode 442] Final distance: 0.0158 | Success: True
# [Episode 443] Final distance: 0.0199 | Success: True
# [Episode 444] Final distance: 0.0186 | Success: True
# [Episode 445] Final distance: 0.0186 | Success: True
# [Episode 446] Final distance: 0.0190 | Success: True
# [Episode 447] Final distance: 0.0189 | Success: True
# [Episode 448] Final distance: 0.0163 | Success: True
# [Episode 449] Final distance: 0.0165 | Success: True
# [Episode 450] Final distance: 0.0141 | Success: True
# [Episode 451] Final distance: 0.0198 | Success: True
# [Episode 452] Final distance: 0.0154 | Success: True
# [Episode 453] Final distance: 0.0168 | Success: True
# [Episode 454] Final distance: 0.0158 | Success: True
# [Episode 455] Final distance: 0.0189 | Success: True
# [Episode 456] Final distance: 0.0186 | Success: True
# [Episode 457] Final distance: 0.0169 | Success: True
# [Episode 458] Final distance: 0.0193 | Success: True
# [Episode 459] Final distance: 0.0195 | Success: True
# [Episode 460] Final distance: 0.0183 | Success: True
# [Episode 461] Final distance: 0.0158 | Success: True
# [Episode 462] Final distance: 0.0152 | Success: True
# [Episode 463] Final distance: 0.0194 | Success: True
# [Episode 464] Final distance: 0.0169 | Success: True
# [Episode 465] Final distance: 0.0162 | Success: True
# [Episode 466] Final distance: 0.0179 | Success: True
# [Episode 467] Final distance: 0.0195 | Success: True
# [Episode 468] Final distance: 0.0192 | Success: True
# [Episode 469] Final distance: 0.0129 | Success: True
# [Episode 470] Final distance: 0.0177 | Success: True
# [Episode 471] Final distance: 0.0167 | Success: True
# [Episode 472] Final distance: 0.0148 | Success: True
# [Episode 473] Final distance: 0.0156 | Success: True
# [Episode 474] Final distance: 0.0162 | Success: True
# [Episode 475] Final distance: 0.0176 | Success: True
# [Episode 476] Final distance: 0.0139 | Success: True
# [Episode 477] Final distance: 0.0178 | Success: True
# [Episode 478] Final distance: 0.0184 | Success: True
# [Episode 479] Final distance: 0.0143 | Success: True
# [Episode 480] Final distance: 0.0168 | Success: True
# [Episode 481] Final distance: 0.0196 | Success: True
# [Episode 482] Final distance: 0.0169 | Success: True
# [Episode 483] Final distance: 0.0143 | Success: True
# [Episode 484] Final distance: 0.0167 | Success: True
# [Episode 485] Final distance: 0.0169 | Success: True
# [Episode 486] Final distance: 0.0167 | Success: True
# [Episode 487] Final distance: 0.0187 | Success: True
# [Episode 488] Final distance: 0.0178 | Success: True
# [Episode 489] Final distance: 0.0166 | Success: True
# [Episode 490] Final distance: 0.0150 | Success: True
# [Episode 491] Final distance: 0.0172 | Success: True
# [Episode 492] Final distance: 0.0138 | Success: True
# [Episode 493] Final distance: 0.0147 | Success: True
# [Episode 494] Final distance: 0.0151 | Success: True
# [Episode 495] Final distance: 0.0177 | Success: True
# [Episode 496] Final distance: 0.0140 | Success: True
# [Episode 497] Final distance: 0.0168 | Success: True
# [Episode 498] Final distance: 0.0155 | Success: True
# [Episode 499] Final distance: 0.0160 | Success: True
# [Episode 500] Final distance: 0.0197 | Success: True
# [Episode 501] Final distance: 0.0195 | Success: True
# [Episode 502] Final distance: 0.0146 | Success: True
# [Episode 503] Final distance: 0.0176 | Success: True
# [Episode 504] Final distance: 0.0199 | Success: True
# [Episode 505] Final distance: 0.0200 | Success: True
# [Episode 506] Final distance: 0.0167 | Success: True
# [Episode 507] Final distance: 0.0188 | Success: True
# [Episode 508] Final distance: 0.0152 | Success: True
# [Episode 509] Final distance: 0.0186 | Success: True
# [Episode 510] Final distance: 0.0163 | Success: True
# [Episode 511] Final distance: 0.0169 | Success: True
# [Episode 512] Final distance: 0.0196 | Success: True
# [Episode 513] Final distance: 0.0186 | Success: True
# [Episode 514] Final distance: 0.0146 | Success: True
# [Episode 515] Final distance: 0.0128 | Success: True
# [Episode 516] Final distance: 0.0157 | Success: True
# [Episode 517] Final distance: 0.0191 | Success: True
# [Episode 518] Final distance: 0.0174 | Success: True
# [Episode 519] Final distance: 0.0182 | Success: True
# [Episode 520] Final distance: 0.0179 | Success: True
# [Episode 521] Final distance: 0.0195 | Success: True
# [Episode 522] Final distance: 0.0165 | Success: True
# [Episode 523] Final distance: 0.0191 | Success: True
# [Episode 524] Final distance: 0.0194 | Success: True
# [Episode 525] Final distance: 0.0195 | Success: True
# [Episode 526] Final distance: 0.0192 | Success: True
# [Episode 527] Final distance: 0.0134 | Success: True
# [Episode 528] Final distance: 0.0184 | Success: True
# [Episode 529] Final distance: 0.0192 | Success: True
# [Episode 530] Final distance: 0.0182 | Success: True
# [Episode 531] Final distance: 0.0161 | Success: True
# [Episode 532] Final distance: 0.0162 | Success: True
# [Episode 533] Final distance: 0.0166 | Success: True
# [Episode 534] Final distance: 0.0197 | Success: True
# [Episode 535] Final distance: 0.0190 | Success: True
# [Episode 536] Final distance: 0.0179 | Success: True
# [Episode 537] Final distance: 0.0154 | Success: True
# [Episode 538] Final distance: 0.0154 | Success: True
# [Episode 539] Final distance: 0.0175 | Success: True
# [Episode 540] Final distance: 0.0182 | Success: True
# [Episode 541] Final distance: 0.0173 | Success: True
# [Episode 542] Final distance: 0.0199 | Success: True
# [Episode 543] Final distance: 0.0238 | Success: False
# [Episode 544] Final distance: 0.0122 | Success: True
# [Episode 545] Final distance: 0.0191 | Success: True
# [Episode 546] Final distance: 0.0197 | Success: True
# [Episode 547] Final distance: 0.0141 | Success: True
# [Episode 548] Final distance: 0.0164 | Success: True
# [Episode 549] Final distance: 0.0152 | Success: True
# [Episode 550] Final distance: 0.0182 | Success: True
# [Episode 551] Final distance: 0.0191 | Success: True
# [Episode 552] Final distance: 0.0186 | Success: True
# [Episode 553] Final distance: 0.0157 | Success: True
# [Episode 554] Final distance: 0.0199 | Success: True
# [Episode 555] Final distance: 0.0195 | Success: True
# [Episode 556] Final distance: 0.0196 | Success: True
# [Episode 557] Final distance: 0.0199 | Success: True
# [Episode 558] Final distance: 0.0196 | Success: True
# [Episode 559] Final distance: 0.0179 | Success: True
# [Episode 560] Final distance: 0.0191 | Success: True
# [Episode 561] Final distance: 0.0185 | Success: True
# [Episode 562] Final distance: 0.0170 | Success: True
# [Episode 563] Final distance: 0.0230 | Success: False
# [Episode 564] Final distance: 0.0134 | Success: True
# [Episode 565] Final distance: 0.0209 | Success: False
# [Episode 566] Final distance: 0.0187 | Success: True
# [Episode 567] Final distance: 0.0138 | Success: True
# [Episode 568] Final distance: 0.0181 | Success: True
# [Episode 569] Final distance: 0.0155 | Success: True
# [Episode 570] Final distance: 0.0176 | Success: True
# [Episode 571] Final distance: 0.0189 | Success: True
# [Episode 572] Final distance: 0.0171 | Success: True
# [Episode 573] Final distance: 0.0157 | Success: True
# [Episode 574] Final distance: 0.0193 | Success: True
# [Episode 575] Final distance: 0.0160 | Success: True
# [Episode 576] Final distance: 0.0157 | Success: True
# [Episode 577] Final distance: 0.0180 | Success: True
# [Episode 578] Final distance: 0.0178 | Success: True
# [Episode 579] Final distance: 0.0189 | Success: True
# [Episode 580] Final distance: 0.0171 | Success: True
# [Episode 581] Final distance: 0.0191 | Success: True
# [Episode 582] Final distance: 0.0167 | Success: True
# [Episode 583] Final distance: 0.0184 | Success: True
# [Episode 584] Final distance: 0.0180 | Success: True
# [Episode 585] Final distance: 0.0153 | Success: True
# [Episode 586] Final distance: 0.0177 | Success: True
# [Episode 587] Final distance: 0.0199 | Success: True
# [Episode 588] Final distance: 0.0187 | Success: True
# [Episode 589] Final distance: 0.0177 | Success: True
# [Episode 590] Final distance: 0.0199 | Success: True
# [Episode 591] Final distance: 0.0190 | Success: True
# [Episode 592] Final distance: 0.0188 | Success: True
# [Episode 593] Final distance: 0.0172 | Success: True
# [Episode 594] Final distance: 0.0198 | Success: True
# [Episode 595] Final distance: 0.0200 | Success: True
# [Episode 596] Final distance: 0.0188 | Success: True
# [Episode 597] Final distance: 0.0164 | Success: True
# [Episode 598] Final distance: 0.0165 | Success: True
# [Episode 599] Final distance: 0.0179 | Success: True
# [Episode 600] Final distance: 0.0183 | Success: True
# [Episode 601] Final distance: 0.0186 | Success: True
# [Episode 602] Final distance: 0.0196 | Success: True
# [Episode 603] Final distance: 0.0169 | Success: True
# [Episode 604] Final distance: 0.0178 | Success: True
# [Episode 605] Final distance: 0.0139 | Success: True
# [Episode 606] Final distance: 0.0180 | Success: True
# [Episode 607] Final distance: 0.0174 | Success: True
# [Episode 608] Final distance: 0.0174 | Success: True
# [Episode 609] Final distance: 0.0194 | Success: True
# [Episode 610] Final distance: 0.0146 | Success: True
# [Episode 611] Final distance: 0.0127 | Success: True
# [Episode 612] Final distance: 0.0160 | Success: True
# [Episode 613] Final distance: 0.0174 | Success: True
# [Episode 614] Final distance: 0.0183 | Success: True
# [Episode 615] Final distance: 0.0191 | Success: True
# [Episode 616] Final distance: 0.0166 | Success: True
# [Episode 617] Final distance: 0.0157 | Success: True
# [Episode 618] Final distance: 0.0141 | Success: True
# [Episode 619] Final distance: 0.0035 | Success: True
# [Episode 620] Final distance: 0.0174 | Success: True
# [Episode 621] Final distance: 0.0193 | Success: True
# [Episode 622] Final distance: 0.0151 | Success: True
# [Episode 623] Final distance: 0.0178 | Success: True
# [Episode 624] Final distance: 0.0196 | Success: True
# [Episode 625] Final distance: 0.0162 | Success: True
# [Episode 626] Final distance: 0.0140 | Success: True
# [Episode 627] Final distance: 0.0180 | Success: True
# [Episode 628] Final distance: 0.0162 | Success: True
# [Episode 629] Final distance: 0.0149 | Success: True
# [Episode 630] Final distance: 0.0181 | Success: True
# [Episode 631] Final distance: 0.0154 | Success: True
# [Episode 632] Final distance: 0.0180 | Success: True
# [Episode 633] Final distance: 0.0160 | Success: True
# [Episode 634] Final distance: 0.0153 | Success: True
# [Episode 635] Final distance: 0.0198 | Success: True
# [Episode 636] Final distance: 0.0197 | Success: True
# [Episode 637] Final distance: 0.0199 | Success: True
# [Episode 638] Final distance: 0.0193 | Success: True
# [Episode 639] Final distance: 0.0154 | Success: True
# [Episode 640] Final distance: 0.0195 | Success: True
# [Episode 641] Final distance: 0.0159 | Success: True
# [Episode 642] Final distance: 0.0165 | Success: True
# [Episode 643] Final distance: 0.0152 | Success: True
# [Episode 644] Final distance: 0.0200 | Success: True
# [Episode 645] Final distance: 0.0175 | Success: True
# [Episode 646] Final distance: 0.0158 | Success: True
# [Episode 647] Final distance: 0.0180 | Success: True
# [Episode 648] Final distance: 0.0198 | Success: True
# [Episode 649] Final distance: 0.0193 | Success: True
# [Episode 650] Final distance: 0.0194 | Success: True
# [Episode 651] Final distance: 0.0185 | Success: True
# [Episode 652] Final distance: 0.0197 | Success: True
# [Episode 653] Final distance: 0.0181 | Success: True
# [Episode 654] Final distance: 0.0169 | Success: True
# [Episode 655] Final distance: 0.0164 | Success: True
# [Episode 656] Final distance: 0.0203 | Success: False
# [Episode 657] Final distance: 0.0181 | Success: True
# [Episode 658] Final distance: 0.0130 | Success: True
# [Episode 659] Final distance: 0.0190 | Success: True
# [Episode 660] Final distance: 0.0122 | Success: True
# [Episode 661] Final distance: 0.0177 | Success: True
# [Episode 662] Final distance: 0.0137 | Success: True
# [Episode 663] Final distance: 0.0150 | Success: True
# [Episode 664] Final distance: 0.0197 | Success: True
# [Episode 665] Final distance: 0.0197 | Success: True
# [Episode 666] Final distance: 0.0165 | Success: True
# [Episode 667] Final distance: 0.0179 | Success: True
# [Episode 668] Final distance: 0.0162 | Success: True
# [Episode 669] Final distance: 0.0139 | Success: True
# [Episode 670] Final distance: 0.0160 | Success: True
# [Episode 671] Final distance: 0.0185 | Success: True
# [Episode 672] Final distance: 0.0156 | Success: True
# [Episode 673] Final distance: 0.0190 | Success: True
# [Episode 674] Final distance: 0.0186 | Success: True
# [Episode 675] Final distance: 0.0133 | Success: True
# [Episode 676] Final distance: 0.0179 | Success: True
# [Episode 677] Final distance: 0.0183 | Success: True
# [Episode 678] Final distance: 0.0189 | Success: True
# [Episode 679] Final distance: 0.0183 | Success: True
# [Episode 680] Final distance: 0.0212 | Success: False
# [Episode 681] Final distance: 0.0167 | Success: True
# [Episode 682] Final distance: 0.0151 | Success: True
# [Episode 683] Final distance: 0.0172 | Success: True
# [Episode 684] Final distance: 0.0191 | Success: True
# [Episode 685] Final distance: 0.0192 | Success: True
# [Episode 686] Final distance: 0.0179 | Success: True
# [Episode 687] Final distance: 0.0140 | Success: True
# [Episode 688] Final distance: 0.0128 | Success: True
# [Episode 689] Final distance: 0.0186 | Success: True
# [Episode 690] Final distance: 0.0175 | Success: True
# [Episode 691] Final distance: 0.0184 | Success: True
# [Episode 692] Final distance: 0.0195 | Success: True
# [Episode 693] Final distance: 0.0183 | Success: True
# [Episode 694] Final distance: 0.0186 | Success: True
# [Episode 695] Final distance: 0.0160 | Success: True
# [Episode 696] Final distance: 0.0153 | Success: True
# [Episode 697] Final distance: 0.0199 | Success: True
# [Episode 698] Final distance: 0.0162 | Success: True
# [Episode 699] Final distance: 0.0197 | Success: True
# [Episode 700] Final distance: 0.0163 | Success: True
# [Episode 701] Final distance: 0.0186 | Success: True
# [Episode 702] Final distance: 0.0182 | Success: True
# [Episode 703] Final distance: 0.0168 | Success: True
# [Episode 704] Final distance: 0.0194 | Success: True
# [Episode 705] Final distance: 0.0199 | Success: True
# [Episode 706] Final distance: 0.0182 | Success: True
# [Episode 707] Final distance: 0.0164 | Success: True
# [Episode 708] Final distance: 0.0169 | Success: True
# [Episode 709] Final distance: 0.0196 | Success: True
# [Episode 710] Final distance: 0.0181 | Success: True
# [Episode 711] Final distance: 0.0136 | Success: True
# [Episode 712] Final distance: 0.0157 | Success: True
# [Episode 713] Final distance: 0.0195 | Success: True
# [Episode 714] Final distance: 0.0178 | Success: True
# [Episode 715] Final distance: 0.0180 | Success: True
# [Episode 716] Final distance: 0.0183 | Success: True
# [Episode 717] Final distance: 0.0194 | Success: True
# [Episode 718] Final distance: 0.0210 | Success: False
# [Episode 719] Final distance: 0.0191 | Success: True
# [Episode 720] Final distance: 0.0145 | Success: True
# [Episode 721] Final distance: 0.0162 | Success: True
# [Episode 722] Final distance: 0.0140 | Success: True
# [Episode 723] Final distance: 0.0171 | Success: True
# [Episode 724] Final distance: 0.0194 | Success: True
# [Episode 725] Final distance: 0.0187 | Success: True
# [Episode 726] Final distance: 0.0135 | Success: True
# [Episode 727] Final distance: 0.0182 | Success: True
# [Episode 728] Final distance: 0.0171 | Success: True
# [Episode 729] Final distance: 0.0168 | Success: True
# [Episode 730] Final distance: 0.0186 | Success: True
# [Episode 731] Final distance: 0.0182 | Success: True
# [Episode 732] Final distance: 0.0187 | Success: True
# [Episode 733] Final distance: 0.0158 | Success: True
# [Episode 734] Final distance: 0.0196 | Success: True
# [Episode 735] Final distance: 0.0198 | Success: True
# [Episode 736] Final distance: 0.0180 | Success: True
# [Episode 737] Final distance: 0.0177 | Success: True
# [Episode 738] Final distance: 0.0182 | Success: True
# [Episode 739] Final distance: 0.0164 | Success: True
# [Episode 740] Final distance: 0.0162 | Success: True
# [Episode 741] Final distance: 0.0198 | Success: True
# [Episode 742] Final distance: 0.0169 | Success: True
# [Episode 743] Final distance: 0.0122 | Success: True
# [Episode 744] Final distance: 0.0187 | Success: True
# [Episode 745] Final distance: 0.0159 | Success: True
# [Episode 746] Final distance: 0.0158 | Success: True
# [Episode 747] Final distance: 0.0184 | Success: True
# [Episode 748] Final distance: 0.0172 | Success: True
# [Episode 749] Final distance: 0.0186 | Success: True
# [Episode 750] Final distance: 0.0168 | Success: True
# [Episode 751] Final distance: 0.0184 | Success: True
# [Episode 752] Final distance: 0.0176 | Success: True
# [Episode 753] Final distance: 0.0191 | Success: True
# [Episode 754] Final distance: 0.0155 | Success: True
# [Episode 755] Final distance: 0.0146 | Success: True
# [Episode 756] Final distance: 0.0131 | Success: True
# [Episode 757] Final distance: 0.0193 | Success: True
# [Episode 758] Final distance: 0.0133 | Success: True
# [Episode 759] Final distance: 0.0192 | Success: True
# [Episode 760] Final distance: 0.0170 | Success: True
# [Episode 761] Final distance: 0.0131 | Success: True
# [Episode 762] Final distance: 0.0180 | Success: True
# [Episode 763] Final distance: 0.0168 | Success: True
# [Episode 764] Final distance: 0.0184 | Success: True
# [Episode 765] Final distance: 0.0165 | Success: True
# [Episode 766] Final distance: 0.0185 | Success: True
# [Episode 767] Final distance: 0.0146 | Success: True
# [Episode 768] Final distance: 0.0193 | Success: True
# [Episode 769] Final distance: 0.0138 | Success: True
# [Episode 770] Final distance: 0.0164 | Success: True
# [Episode 771] Final distance: 0.0199 | Success: True
# [Episode 772] Final distance: 0.0155 | Success: True
# [Episode 773] Final distance: 0.0200 | Success: True
# [Episode 774] Final distance: 0.0191 | Success: True
# [Episode 775] Final distance: 0.0200 | Success: True
# [Episode 776] Final distance: 0.0196 | Success: True
# [Episode 777] Final distance: 0.0164 | Success: True
# [Episode 778] Final distance: 0.0132 | Success: True
# [Episode 779] Final distance: 0.0169 | Success: True
# [Episode 780] Final distance: 0.0153 | Success: True
# [Episode 781] Final distance: 0.0194 | Success: True
# [Episode 782] Final distance: 0.0192 | Success: True
# [Episode 783] Final distance: 0.0131 | Success: True
# [Episode 784] Final distance: 0.0142 | Success: True
# [Episode 785] Final distance: 0.0174 | Success: True
# [Episode 786] Final distance: 0.0193 | Success: True
# [Episode 787] Final distance: 0.0198 | Success: True
# [Episode 788] Final distance: 0.0193 | Success: True
# [Episode 789] Final distance: 0.0195 | Success: True
# [Episode 790] Final distance: 0.0197 | Success: True
# [Episode 791] Final distance: 0.0169 | Success: True
# [Episode 792] Final distance: 0.0186 | Success: True
# [Episode 793] Final distance: 0.0158 | Success: True
# [Episode 794] Final distance: 0.0197 | Success: True
# [Episode 795] Final distance: 0.0197 | Success: True
# [Episode 796] Final distance: 0.0123 | Success: True
# [Episode 797] Final distance: 0.0178 | Success: True
# [Episode 798] Final distance: 0.0165 | Success: True
# [Episode 799] Final distance: 0.0166 | Success: True
# [Episode 800] Final distance: 0.0121 | Success: True
# [Episode 801] Final distance: 0.0196 | Success: True
# [Episode 802] Final distance: 0.0153 | Success: True
# [Episode 803] Final distance: 0.0128 | Success: True
# [Episode 804] Final distance: 0.0180 | Success: True
# [Episode 805] Final distance: 0.0187 | Success: True
# [Episode 806] Final distance: 0.0193 | Success: True
# [Episode 807] Final distance: 0.0171 | Success: True
# [Episode 808] Final distance: 0.0195 | Success: True
# [Episode 809] Final distance: 0.0176 | Success: True
# [Episode 810] Final distance: 0.0150 | Success: True
# [Episode 811] Final distance: 0.0172 | Success: True
# [Episode 812] Final distance: 0.0195 | Success: True
# [Episode 813] Final distance: 0.0197 | Success: True
# [Episode 814] Final distance: 0.0147 | Success: True
# [Episode 815] Final distance: 0.0138 | Success: True
# [Episode 816] Final distance: 0.0166 | Success: True
# [Episode 817] Final distance: 0.0141 | Success: True
# [Episode 818] Final distance: 0.0159 | Success: True
# [Episode 819] Final distance: 0.0185 | Success: True
# [Episode 820] Final distance: 0.0189 | Success: True
# [Episode 821] Final distance: 0.0180 | Success: True
# [Episode 822] Final distance: 0.0176 | Success: True
# [Episode 823] Final distance: 0.0187 | Success: True
# [Episode 824] Final distance: 0.0185 | Success: True
# [Episode 825] Final distance: 0.0137 | Success: True
# [Episode 826] Final distance: 0.0136 | Success: True
# [Episode 827] Final distance: 0.0198 | Success: True
# [Episode 828] Final distance: 0.0197 | Success: True
# [Episode 829] Final distance: 0.0164 | Success: True
# [Episode 830] Final distance: 0.0200 | Success: True
# [Episode 831] Final distance: 0.0214 | Success: False
# [Episode 832] Final distance: 0.0164 | Success: True
# [Episode 833] Final distance: 0.0174 | Success: True
# [Episode 834] Final distance: 0.0197 | Success: True
# [Episode 835] Final distance: 0.0191 | Success: True
# [Episode 836] Final distance: 0.0193 | Success: True
# [Episode 837] Final distance: 0.0167 | Success: True
# [Episode 838] Final distance: 0.0142 | Success: True
# [Episode 839] Final distance: 0.0165 | Success: True
# [Episode 840] Final distance: 0.0193 | Success: True
# [Episode 841] Final distance: 0.0140 | Success: True
# [Episode 842] Final distance: 0.0199 | Success: True
# [Episode 843] Final distance: 0.0183 | Success: True
# [Episode 844] Final distance: 0.0194 | Success: True
# [Episode 845] Final distance: 0.0168 | Success: True
# [Episode 846] Final distance: 0.0187 | Success: True
# [Episode 847] Final distance: 0.0208 | Success: False
# [Episode 848] Final distance: 0.0194 | Success: True
# [Episode 849] Final distance: 0.0141 | Success: True
# [Episode 850] Final distance: 0.0181 | Success: True
# [Episode 851] Final distance: 0.0168 | Success: True
# [Episode 852] Final distance: 0.0189 | Success: True
# [Episode 853] Final distance: 0.0192 | Success: True
# [Episode 854] Final distance: 0.0131 | Success: True
# [Episode 855] Final distance: 0.0199 | Success: True
# [Episode 856] Final distance: 0.0176 | Success: True
# [Episode 857] Final distance: 0.0190 | Success: True
# [Episode 858] Final distance: 0.0195 | Success: True
# [Episode 859] Final distance: 0.0192 | Success: True
# [Episode 860] Final distance: 0.0135 | Success: True
# [Episode 861] Final distance: 0.0191 | Success: True
# [Episode 862] Final distance: 0.0147 | Success: True
# [Episode 863] Final distance: 0.0174 | Success: True
# [Episode 864] Final distance: 0.0139 | Success: True
# [Episode 865] Final distance: 0.0180 | Success: True
# [Episode 866] Final distance: 0.0181 | Success: True
# [Episode 867] Final distance: 0.0195 | Success: True
# [Episode 868] Final distance: 0.0176 | Success: True
# [Episode 869] Final distance: 0.0179 | Success: True
# [Episode 870] Final distance: 0.0183 | Success: True
# [Episode 871] Final distance: 0.0167 | Success: True
# [Episode 872] Final distance: 0.0170 | Success: True
# [Episode 873] Final distance: 0.0185 | Success: True
# [Episode 874] Final distance: 0.0167 | Success: True
# [Episode 875] Final distance: 0.0198 | Success: True
# [Episode 876] Final distance: 0.0198 | Success: True
# [Episode 877] Final distance: 0.0158 | Success: True
# [Episode 878] Final distance: 0.0181 | Success: True
# [Episode 879] Final distance: 0.0125 | Success: True
# [Episode 880] Final distance: 0.0129 | Success: True
# [Episode 881] Final distance: 0.0171 | Success: True
# [Episode 882] Final distance: 0.0188 | Success: True
# [Episode 883] Final distance: 0.0138 | Success: True
# [Episode 884] Final distance: 0.0196 | Success: True
# [Episode 885] Final distance: 0.0166 | Success: True
# [Episode 886] Final distance: 0.0174 | Success: True
# [Episode 887] Final distance: 0.0173 | Success: True
# [Episode 888] Final distance: 0.0179 | Success: True
# [Episode 889] Final distance: 0.0140 | Success: True
# [Episode 890] Final distance: 0.0191 | Success: True
# [Episode 891] Final distance: 0.0196 | Success: True
# [Episode 892] Final distance: 0.0188 | Success: True
# [Episode 893] Final distance: 0.0198 | Success: True
# [Episode 894] Final distance: 0.0165 | Success: True
# [Episode 895] Final distance: 0.0139 | Success: True
# [Episode 896] Final distance: 0.0155 | Success: True
# [Episode 897] Final distance: 0.0197 | Success: True
# [Episode 898] Final distance: 0.0165 | Success: True
# [Episode 899] Final distance: 0.0182 | Success: True
# [Episode 900] Final distance: 0.0173 | Success: True
# [Episode 901] Final distance: 0.0191 | Success: True
# [Episode 902] Final distance: 0.0168 | Success: True
# [Episode 903] Final distance: 0.0168 | Success: True
# [Episode 904] Final distance: 0.0178 | Success: True
# [Episode 905] Final distance: 0.0129 | Success: True
# [Episode 906] Final distance: 0.0190 | Success: True
# [Episode 907] Final distance: 0.0173 | Success: True
# [Episode 908] Final distance: 0.0193 | Success: True
# [Episode 909] Final distance: 0.0134 | Success: True
# [Episode 910] Final distance: 0.0152 | Success: True
# [Episode 911] Final distance: 0.0189 | Success: True
# [Episode 912] Final distance: 0.0205 | Success: False
# [Episode 913] Final distance: 0.0186 | Success: True
# [Episode 914] Final distance: 0.0198 | Success: True
# [Episode 915] Final distance: 0.0185 | Success: True
# [Episode 916] Final distance: 0.0181 | Success: True
# [Episode 917] Final distance: 0.0192 | Success: True
# [Episode 918] Final distance: 0.0169 | Success: True
# [Episode 919] Final distance: 0.0133 | Success: True
# [Episode 920] Final distance: 0.0166 | Success: True
# [Episode 921] Final distance: 0.0179 | Success: True
# [Episode 922] Final distance: 0.0145 | Success: True
# [Episode 923] Final distance: 0.0160 | Success: True
# [Episode 924] Final distance: 0.0187 | Success: True
# [Episode 925] Final distance: 0.0120 | Success: True
# [Episode 926] Final distance: 0.0199 | Success: True
# [Episode 927] Final distance: 0.0200 | Success: True
# [Episode 928] Final distance: 0.0189 | Success: True
# [Episode 929] Final distance: 0.0185 | Success: True
# [Episode 930] Final distance: 0.0170 | Success: True
# [Episode 931] Final distance: 0.0135 | Success: True
# [Episode 932] Final distance: 0.0121 | Success: True
# [Episode 933] Final distance: 0.0191 | Success: True
# [Episode 934] Final distance: 0.0197 | Success: True
# [Episode 935] Final distance: 0.0177 | Success: True
# [Episode 936] Final distance: 0.0155 | Success: True
# [Episode 937] Final distance: 0.0168 | Success: True
# [Episode 938] Final distance: 0.0161 | Success: True
# [Episode 939] Final distance: 0.0182 | Success: True
# [Episode 940] Final distance: 0.0172 | Success: True
# [Episode 941] Final distance: 0.0194 | Success: True
# [Episode 942] Final distance: 0.0173 | Success: True
# [Episode 943] Final distance: 0.0192 | Success: True
# [Episode 944] Final distance: 0.0157 | Success: True
# [Episode 945] Final distance: 0.0173 | Success: True
# [Episode 946] Final distance: 0.0179 | Success: True
# [Episode 947] Final distance: 0.0159 | Success: True
# [Episode 948] Final distance: 0.0169 | Success: True
# [Episode 949] Final distance: 0.0128 | Success: True
# [Episode 950] Final distance: 0.0185 | Success: True
# [Episode 951] Final distance: 0.0178 | Success: True
# [Episode 952] Final distance: 0.0157 | Success: True
# [Episode 953] Final distance: 0.0190 | Success: True
# [Episode 954] Final distance: 0.0190 | Success: True
# [Episode 955] Final distance: 0.0190 | Success: True
# [Episode 956] Final distance: 0.0167 | Success: True
# [Episode 957] Final distance: 0.0158 | Success: True
# [Episode 958] Final distance: 0.0148 | Success: True
# [Episode 959] Final distance: 0.0183 | Success: True
# [Episode 960] Final distance: 0.0182 | Success: True
# [Episode 961] Final distance: 0.0159 | Success: True
# [Episode 962] Final distance: 0.0150 | Success: True
# [Episode 963] Final distance: 0.0196 | Success: True
# [Episode 964] Final distance: 0.0173 | Success: True
# [Episode 965] Final distance: 0.0155 | Success: True
# [Episode 966] Final distance: 0.0191 | Success: True
# [Episode 967] Final distance: 0.0159 | Success: True
# [Episode 968] Final distance: 0.0175 | Success: True
# [Episode 969] Final distance: 0.0154 | Success: True
# [Episode 970] Final distance: 0.0190 | Success: True
# [Episode 971] Final distance: 0.0200 | Success: True
# [Episode 972] Final distance: 0.0166 | Success: True
# [Episode 973] Final distance: 0.0170 | Success: True
# [Episode 974] Final distance: 0.0190 | Success: True
# [Episode 975] Final distance: 0.0179 | Success: True
# [Episode 976] Final distance: 0.0192 | Success: True
# [Episode 977] Final distance: 0.0168 | Success: True
# [Episode 978] Final distance: 0.0151 | Success: True
# [Episode 979] Final distance: 0.0157 | Success: True
# [Episode 980] Final distance: 0.0197 | Success: True
# [Episode 981] Final distance: 0.0199 | Success: True
# [Episode 982] Final distance: 0.0175 | Success: True
# [Episode 983] Final distance: 0.0138 | Success: True
# [Episode 984] Final distance: 0.0137 | Success: True
# [Episode 985] Final distance: 0.0187 | Success: True
# [Episode 986] Final distance: 0.0175 | Success: True
# [Episode 987] Final distance: 0.0189 | Success: True
# [Episode 988] Final distance: 0.0149 | Success: True
# [Episode 989] Final distance: 0.0158 | Success: True
# [Episode 990] Final distance: 0.0182 | Success: True
# [Episode 991] Final distance: 0.0155 | Success: True
# [Episode 992] Final distance: 0.0158 | Success: True
# [Episode 993] Final distance: 0.0160 | Success: True
# [Episode 994] Final distance: 0.0163 | Success: True
# [Episode 995] Final distance: 0.0164 | Success: True
# [Episode 996] Final distance: 0.0181 | Success: True
# [Episode 997] Final distance: 0.0158 | Success: True
# [Episode 998] Final distance: 0.0191 | Success: True
# [Episode 999] Final distance: 0.0160 | Success: True
# [Episode 1000] Final distance: 0.0180 | Success: True
# Success rate: 986/1001
# Average final distance: 0.0173

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from environment import TrackingEnv
from ppo import PPOAgent, PolicyNet, ValueNet


def load_ppo_agent(checkpoint_path, state_dim, action_dim):
    agent = PPOAgent(state_dim, action_dim)
    checkpoint = torch.load(checkpoint_path, map_location=torch.device('cpu'))
    agent.actor.load_state_dict(checkpoint['actor_state_dict'])
    agent.critic.load_state_dict(checkpoint['critic_state_dict'])
    agent.eval()
    return agent


def test_ppo_agent(agent, env=None, num_episodes=1001, tolerance=0.02):
    if env is None:
        env = TrackingEnv()

    success_count = 0
    final_distances = []

    for ep in range(num_episodes):
        state, _ = env.reset()
        state = torch.tensor(state, dtype=torch.float32)
        done = False
        trajectory = []
        target_trajectory = []

        while not done:
            trajectory.append(state[:2].detach().numpy())
            target_trajectory.append(state[2:4].detach().numpy())
            with torch.no_grad():
                mu, sigma = agent.actor(state, training=True)  # No noise at test time
                action = mu  # Greedy action (no sampling)
            next_state, _, done, truncated, _, _ = env.step(action.numpy())
            next_state = torch.tensor(next_state, dtype=torch.float32)

            if torch.norm(next_state[:2] - next_state[2:4]) < tolerance or truncated:
                done = True

            state = next_state

        final_distance = torch.norm(state[:2] - state[2:4]).item()
        final_distances.append(final_distance)
        success = final_distance < tolerance
        if success:
            success_count += 1

        print(f"[Episode {ep}] Final distance: {final_distance:.4f} | Success: {success}")

        if ep % 100 == 0:
            trajectory = np.array(trajectory)
            target_trajectory = np.array(target_trajectory)
            plt.figure(figsize=(5, 5))
            plt.plot(trajectory[:, 0], trajectory[:, 1], marker='o', label="Traiettoria")
            plt.scatter(*state[2:4], color='red', label='Target', s=100)
            plt.scatter(trajectory[0, 0], trajectory[0, 1], color='green', label='Start', s=100)
            plt.title(f"Test episodio {ep}, successo: {success}")
            plt.xlabel("X")
            plt.ylabel("Y")
            plt.legend()
            plt.grid()
            plt.axis('equal')
            plt.show()

    env.close()
    print(f"\nSuccess rate: {success_count}/{num_episodes}")
    print(f"Average final distance: {np.mean(final_distances):.4f}")


if __name__ == "__main__":
    checkpoint_path = "runs/ppo_run_noise20250413_165209/checkpoint_ep10000.pth"
    env = TrackingEnv()
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]

    agent = load_ppo_agent(checkpoint_path, state_dim, action_dim)
    test_ppo_agent(agent, env=env)
# Out:
# [Episode 0] Final distance: 0.0190 | Success: True
# [Episode 1] Final distance: 0.0168 | Success: True
# [Episode 2] Final distance: 0.0093 | Success: True
# [Episode 3] Final distance: 0.0185 | Success: True
# [Episode 4] Final distance: 0.0194 | Success: True
# [Episode 5] Final distance: 0.0146 | Success: True
# [Episode 6] Final distance: 0.0188 | Success: True
# [Episode 7] Final distance: 0.0168 | Success: True
# [Episode 8] Final distance: 0.0165 | Success: True
# [Episode 9] Final distance: 0.0200 | Success: True
# [Episode 10] Final distance: 0.0181 | Success: True
# [Episode 11] Final distance: 0.0172 | Success: True
# [Episode 12] Final distance: 0.0184 | Success: True
# [Episode 13] Final distance: 0.0172 | Success: True
# [Episode 14] Final distance: 0.0191 | Success: True
# [Episode 15] Final distance: 0.0171 | Success: True
# [Episode 16] Final distance: 0.0174 | Success: True
# [Episode 17] Final distance: 0.0170 | Success: True
# [Episode 18] Final distance: 0.0164 | Success: True
# [Episode 19] Final distance: 0.0177 | Success: True
# [Episode 20] Final distance: 0.0185 | Success: True
# [Episode 21] Final distance: 0.0200 | Success: True
# [Episode 22] Final distance: 0.0156 | Success: True
# [Episode 23] Final distance: 0.0177 | Success: True
# [Episode 24] Final distance: 0.0200 | Success: True
# [Episode 25] Final distance: 0.0165 | Success: True
# [Episode 26] Final distance: 0.0183 | Success: True
# [Episode 27] Final distance: 0.0141 | Success: True
# [Episode 28] Final distance: 0.0194 | Success: True
# [Episode 29] Final distance: 0.0165 | Success: True
# [Episode 30] Final distance: 0.0179 | Success: True
# [Episode 31] Final distance: 0.0163 | Success: True
# [Episode 32] Final distance: 0.0134 | Success: True
# [Episode 33] Final distance: 0.0199 | Success: True
# [Episode 34] Final distance: 0.0198 | Success: True
# [Episode 35] Final distance: 0.0200 | Success: True
# [Episode 36] Final distance: 0.0195 | Success: True
# [Episode 37] Final distance: 0.0198 | Success: True
# [Episode 38] Final distance: 0.0164 | Success: True
# [Episode 39] Final distance: 0.0185 | Success: True
# [Episode 40] Final distance: 0.0193 | Success: True
# [Episode 41] Final distance: 0.0194 | Success: True
# [Episode 42] Final distance: 0.0173 | Success: True
# [Episode 43] Final distance: 0.0180 | Success: True
# [Episode 44] Final distance: 0.0143 | Success: True
# [Episode 45] Final distance: 0.0184 | Success: True
# [Episode 46] Final distance: 0.0171 | Success: True
# [Episode 47] Final distance: 0.0182 | Success: True
# [Episode 48] Final distance: 0.0186 | Success: True
# [Episode 49] Final distance: 0.0182 | Success: True
# [Episode 50] Final distance: 0.0184 | Success: True
# [Episode 51] Final distance: 0.0165 | Success: True
# [Episode 52] Final distance: 0.0199 | Success: True
# [Episode 53] Final distance: 0.0182 | Success: True
# [Episode 54] Final distance: 0.0155 | Success: True
# [Episode 55] Final distance: 0.0190 | Success: True
# [Episode 56] Final distance: 0.0169 | Success: True
# [Episode 57] Final distance: 0.0163 | Success: True
# [Episode 58] Final distance: 0.0199 | Success: True
# [Episode 59] Final distance: 0.0173 | Success: True
# [Episode 60] Final distance: 0.0169 | Success: True
# [Episode 61] Final distance: 0.0183 | Success: True
# [Episode 62] Final distance: 0.0184 | Success: True
# [Episode 63] Final distance: 0.0187 | Success: True
# [Episode 64] Final distance: 0.0200 | Success: True
# [Episode 65] Final distance: 0.0171 | Success: True
# [Episode 66] Final distance: 0.0180 | Success: True
# [Episode 67] Final distance: 0.0139 | Success: True
# [Episode 68] Final distance: 0.0160 | Success: True
# [Episode 69] Final distance: 0.0190 | Success: True
# [Episode 70] Final distance: 0.0199 | Success: True
# [Episode 71] Final distance: 0.0191 | Success: True
# [Episode 72] Final distance: 0.0171 | Success: True
# [Episode 73] Final distance: 0.0188 | Success: True
# [Episode 74] Final distance: 0.0197 | Success: True
# [Episode 75] Final distance: 0.0190 | Success: True
# [Episode 76] Final distance: 0.0186 | Success: True
# [Episode 77] Final distance: 0.0190 | Success: True
# [Episode 78] Final distance: 0.0186 | Success: True
# [Episode 79] Final distance: 0.0196 | Success: True
# [Episode 80] Final distance: 0.0155 | Success: True
# [Episode 81] Final distance: 0.0191 | Success: True
# [Episode 82] Final distance: 0.0172 | Success: True
# [Episode 83] Final distance: 0.0190 | Success: True
# [Episode 84] Final distance: 0.0156 | Success: True
# [Episode 85] Final distance: 0.0187 | Success: True
# [Episode 86] Final distance: 0.0190 | Success: True
# [Episode 87] Final distance: 0.0176 | Success: True
# [Episode 88] Final distance: 0.0198 | Success: True
# [Episode 89] Final distance: 0.0174 | Success: True
# [Episode 90] Final distance: 0.0144 | Success: True
# [Episode 91] Final distance: 0.0186 | Success: True
# [Episode 92] Final distance: 0.0196 | Success: True
# [Episode 93] Final distance: 0.0135 | Success: True
# [Episode 94] Final distance: 0.0175 | Success: True
# [Episode 95] Final distance: 0.0194 | Success: True
# [Episode 96] Final distance: 0.0188 | Success: True
# [Episode 97] Final distance: 0.0200 | Success: True
# [Episode 98] Final distance: 0.0185 | Success: True
# [Episode 99] Final distance: 0.0184 | Success: True
# [Episode 100] Final distance: 0.0148 | Success: True
# [Episode 101] Final distance: 0.0140 | Success: True
# [Episode 102] Final distance: 0.0185 | Success: True
# [Episode 103] Final distance: 0.0183 | Success: True
# [Episode 104] Final distance: 0.0160 | Success: True
# [Episode 105] Final distance: 0.0194 | Success: True
# [Episode 106] Final distance: 0.0183 | Success: True
# [Episode 107] Final distance: 0.0193 | Success: True
# [Episode 108] Final distance: 0.0163 | Success: True
# [Episode 109] Final distance: 0.0362 | Success: False
# [Episode 110] Final distance: 0.0192 | Success: True
# [Episode 111] Final distance: 0.0186 | Success: True
# [Episode 112] Final distance: 0.0195 | Success: True
# [Episode 113] Final distance: 0.0175 | Success: True
# [Episode 114] Final distance: 0.0165 | Success: True
# [Episode 115] Final distance: 0.0184 | Success: True
# [Episode 116] Final distance: 0.0171 | Success: True
# [Episode 117] Final distance: 0.0171 | Success: True
# [Episode 118] Final distance: 0.0194 | Success: True
# [Episode 119] Final distance: 0.0153 | Success: True
# [Episode 120] Final distance: 0.0197 | Success: True
# [Episode 121] Final distance: 0.0198 | Success: True
# [Episode 122] Final distance: 0.0170 | Success: True
# [Episode 123] Final distance: 0.0191 | Success: True
# [Episode 124] Final distance: 0.0178 | Success: True
# [Episode 125] Final distance: 0.0185 | Success: True
# [Episode 126] Final distance: 0.0177 | Success: True
# [Episode 127] Final distance: 0.0198 | Success: True
# [Episode 128] Final distance: 0.0266 | Success: False
# [Episode 129] Final distance: 0.0183 | Success: True
# [Episode 130] Final distance: 0.0197 | Success: True
# [Episode 131] Final distance: 0.0191 | Success: True
# [Episode 132] Final distance: 0.0184 | Success: True
# [Episode 133] Final distance: 0.0185 | Success: True
# [Episode 134] Final distance: 0.0189 | Success: True
# [Episode 135] Final distance: 0.0189 | Success: True
# [Episode 136] Final distance: 0.0182 | Success: True
# [Episode 137] Final distance: 0.0188 | Success: True
# [Episode 138] Final distance: 0.0151 | Success: True
# [Episode 139] Final distance: 0.0445 | Success: False
# [Episode 140] Final distance: 0.0199 | Success: True
# [Episode 141] Final distance: 0.0197 | Success: True
# [Episode 142] Final distance: 0.0196 | Success: True
# [Episode 143] Final distance: 0.0306 | Success: False
# [Episode 144] Final distance: 0.0305 | Success: False
# [Episode 145] Final distance: 0.0200 | Success: True
# [Episode 146] Final distance: 0.0162 | Success: True
# [Episode 147] Final distance: 0.0171 | Success: True
# [Episode 148] Final distance: 0.0191 | Success: True
# [Episode 149] Final distance: 0.0127 | Success: True
# [Episode 150] Final distance: 0.0182 | Success: True
# [Episode 151] Final distance: 0.0190 | Success: True
# [Episode 152] Final distance: 0.0157 | Success: True
# [Episode 153] Final distance: 0.0196 | Success: True
# [Episode 154] Final distance: 0.0135 | Success: True
# [Episode 155] Final distance: 0.0174 | Success: True
# [Episode 156] Final distance: 0.0193 | Success: True
# [Episode 157] Final distance: 0.0163 | Success: True
# [Episode 158] Final distance: 0.0199 | Success: True
# [Episode 159] Final distance: 0.0135 | Success: True
# [Episode 160] Final distance: 0.0178 | Success: True
# [Episode 161] Final distance: 0.0137 | Success: True
# [Episode 162] Final distance: 0.0174 | Success: True
# [Episode 163] Final distance: 0.0179 | Success: True
# [Episode 164] Final distance: 0.0186 | Success: True
# [Episode 165] Final distance: 0.0190 | Success: True
# [Episode 166] Final distance: 0.0183 | Success: True
# [Episode 167] Final distance: 0.0158 | Success: True
# [Episode 168] Final distance: 0.0199 | Success: True
# [Episode 169] Final distance: 0.0177 | Success: True
# [Episode 170] Final distance: 0.0175 | Success: True
# [Episode 171] Final distance: 0.0173 | Success: True
# [Episode 172] Final distance: 0.0186 | Success: True
# [Episode 173] Final distance: 0.0303 | Success: False
# [Episode 174] Final distance: 0.0179 | Success: True
# [Episode 175] Final distance: 0.0164 | Success: True
# [Episode 176] Final distance: 0.0170 | Success: True
# [Episode 177] Final distance: 0.0424 | Success: False
# [Episode 178] Final distance: 0.0190 | Success: True
# [Episode 179] Final distance: 0.0196 | Success: True
# [Episode 180] Final distance: 0.0199 | Success: True
# [Episode 181] Final distance: 0.0199 | Success: True
# [Episode 182] Final distance: 0.0168 | Success: True
# [Episode 183] Final distance: 0.0135 | Success: True
# [Episode 184] Final distance: 0.0191 | Success: True
# [Episode 185] Final distance: 0.0135 | Success: True
# [Episode 186] Final distance: 0.0174 | Success: True
# [Episode 187] Final distance: 0.0200 | Success: True
# [Episode 188] Final distance: 0.0183 | Success: True
# [Episode 189] Final distance: 0.0186 | Success: True
# [Episode 190] Final distance: 0.0195 | Success: True
# [Episode 191] Final distance: 0.0172 | Success: True
# [Episode 192] Final distance: 0.0173 | Success: True
# [Episode 193] Final distance: 0.0179 | Success: True
# [Episode 194] Final distance: 0.0170 | Success: True
# [Episode 195] Final distance: 0.0182 | Success: True
# [Episode 196] Final distance: 0.0187 | Success: True
# [Episode 197] Final distance: 0.0182 | Success: True
# [Episode 198] Final distance: 0.0142 | Success: True
# [Episode 199] Final distance: 0.0160 | Success: True
# [Episode 200] Final distance: 0.0188 | Success: True
# [Episode 201] Final distance: 0.0155 | Success: True
# [Episode 202] Final distance: 0.0200 | Success: True
# [Episode 203] Final distance: 0.0196 | Success: True
# [Episode 204] Final distance: 0.0192 | Success: True
# [Episode 205] Final distance: 0.0194 | Success: True
# [Episode 206] Final distance: 0.0193 | Success: True
# [Episode 207] Final distance: 0.0197 | Success: True
# [Episode 208] Final distance: 0.0132 | Success: True
# [Episode 209] Final distance: 0.0183 | Success: True
# [Episode 210] Final distance: 0.0194 | Success: True
# [Episode 211] Final distance: 0.0198 | Success: True
# [Episode 212] Final distance: 0.0167 | Success: True
# [Episode 213] Final distance: 0.0192 | Success: True
# [Episode 214] Final distance: 0.0137 | Success: True
# [Episode 215] Final distance: 0.0177 | Success: True
# [Episode 216] Final distance: 0.0134 | Success: True
# [Episode 217] Final distance: 0.0186 | Success: True
# [Episode 218] Final distance: 0.0192 | Success: True
# [Episode 219] Final distance: 0.0178 | Success: True
# [Episode 220] Final distance: 0.0197 | Success: True
# [Episode 221] Final distance: 0.0159 | Success: True
# [Episode 222] Final distance: 0.0136 | Success: True
# [Episode 223] Final distance: 0.0193 | Success: True
# [Episode 224] Final distance: 0.0182 | Success: True
# [Episode 225] Final distance: 0.0197 | Success: True
# [Episode 226] Final distance: 0.0182 | Success: True
# [Episode 227] Final distance: 0.0146 | Success: True
# [Episode 228] Final distance: 0.0196 | Success: True
# [Episode 229] Final distance: 0.0187 | Success: True
# [Episode 230] Final distance: 0.0117 | Success: True
# [Episode 231] Final distance: 0.0189 | Success: True
# [Episode 232] Final distance: 0.0188 | Success: True
# [Episode 233] Final distance: 0.0196 | Success: True
# [Episode 234] Final distance: 0.0156 | Success: True
# [Episode 235] Final distance: 0.0179 | Success: True
# [Episode 236] Final distance: 0.0163 | Success: True
# [Episode 237] Final distance: 0.0188 | Success: True
# [Episode 238] Final distance: 0.0199 | Success: True
# [Episode 239] Final distance: 0.0171 | Success: True
# [Episode 240] Final distance: 0.0198 | Success: True
# [Episode 241] Final distance: 0.0195 | Success: True
# [Episode 242] Final distance: 0.0184 | Success: True
# [Episode 243] Final distance: 0.0194 | Success: True
# [Episode 244] Final distance: 0.0183 | Success: True
# [Episode 245] Final distance: 0.0196 | Success: True
# [Episode 246] Final distance: 0.0147 | Success: True
# [Episode 247] Final distance: 0.0187 | Success: True
# [Episode 248] Final distance: 0.0169 | Success: True
# [Episode 249] Final distance: 0.0152 | Success: True
# [Episode 250] Final distance: 0.0196 | Success: True
# [Episode 251] Final distance: 0.0186 | Success: True
# [Episode 252] Final distance: 0.0197 | Success: True
# [Episode 253] Final distance: 0.0194 | Success: True
# [Episode 254] Final distance: 0.0188 | Success: True
# [Episode 255] Final distance: 0.0193 | Success: True
# [Episode 256] Final distance: 0.0197 | Success: True
# [Episode 257] Final distance: 0.0158 | Success: True
# [Episode 258] Final distance: 0.0196 | Success: True
# [Episode 259] Final distance: 0.0185 | Success: True
# [Episode 260] Final distance: 0.0152 | Success: True
# [Episode 261] Final distance: 0.0171 | Success: True
# [Episode 262] Final distance: 0.0177 | Success: True
# [Episode 263] Final distance: 0.0182 | Success: True
# [Episode 264] Final distance: 0.0193 | Success: True
# [Episode 265] Final distance: 0.0164 | Success: True
# [Episode 266] Final distance: 0.0367 | Success: False
# [Episode 267] Final distance: 0.0182 | Success: True
# [Episode 268] Final distance: 0.0198 | Success: True
# [Episode 269] Final distance: 0.0195 | Success: True
# [Episode 270] Final distance: 0.0161 | Success: True
# [Episode 271] Final distance: 0.0189 | Success: True
# [Episode 272] Final distance: 0.0203 | Success: False
# [Episode 273] Final distance: 0.0153 | Success: True
# [Episode 274] Final distance: 0.0193 | Success: True
# [Episode 275] Final distance: 0.0188 | Success: True
# [Episode 276] Final distance: 0.0167 | Success: True
# [Episode 277] Final distance: 0.0176 | Success: True
# [Episode 278] Final distance: 0.0192 | Success: True
# [Episode 279] Final distance: 0.0188 | Success: True
# [Episode 280] Final distance: 0.0187 | Success: True
# [Episode 281] Final distance: 0.0197 | Success: True
# [Episode 282] Final distance: 0.0197 | Success: True
# [Episode 283] Final distance: 0.0154 | Success: True
# [Episode 284] Final distance: 0.0184 | Success: True
# [Episode 285] Final distance: 0.0193 | Success: True
# [Episode 286] Final distance: 0.0184 | Success: True
# [Episode 287] Final distance: 0.0132 | Success: True
# [Episode 288] Final distance: 0.0185 | Success: True
# [Episode 289] Final distance: 0.0196 | Success: True
# [Episode 290] Final distance: 0.0186 | Success: True
# [Episode 291] Final distance: 0.0185 | Success: True
# [Episode 292] Final distance: 0.0192 | Success: True
# [Episode 293] Final distance: 0.0190 | Success: True
# [Episode 294] Final distance: 0.0189 | Success: True
# [Episode 295] Final distance: 0.0198 | Success: True
# [Episode 296] Final distance: 0.0189 | Success: True
# [Episode 297] Final distance: 0.0191 | Success: True
# [Episode 298] Final distance: 0.0193 | Success: True
# [Episode 299] Final distance: 0.0198 | Success: True
# [Episode 300] Final distance: 0.0183 | Success: True
# [Episode 301] Final distance: 0.0200 | Success: True
# [Episode 302] Final distance: 0.0141 | Success: True
# [Episode 303] Final distance: 0.0155 | Success: True
# [Episode 304] Final distance: 0.0194 | Success: True
# [Episode 305] Final distance: 0.0177 | Success: True
# [Episode 306] Final distance: 0.0185 | Success: True
# [Episode 307] Final distance: 0.0192 | Success: True
# [Episode 308] Final distance: 0.0133 | Success: True
# [Episode 309] Final distance: 0.0150 | Success: True
# [Episode 310] Final distance: 0.0199 | Success: True
# [Episode 311] Final distance: 0.0198 | Success: True
# [Episode 312] Final distance: 0.0168 | Success: True
# [Episode 313] Final distance: 0.0152 | Success: True
# [Episode 314] Final distance: 0.0185 | Success: True
# [Episode 315] Final distance: 0.0195 | Success: True
# [Episode 316] Final distance: 0.0162 | Success: True
# [Episode 317] Final distance: 0.0199 | Success: True
# [Episode 318] Final distance: 0.0183 | Success: True
# [Episode 319] Final distance: 0.0360 | Success: False
# [Episode 320] Final distance: 0.0189 | Success: True
# [Episode 321] Final distance: 0.0184 | Success: True
# [Episode 322] Final distance: 0.0159 | Success: True
# [Episode 323] Final distance: 0.0192 | Success: True
# [Episode 324] Final distance: 0.0177 | Success: True
# [Episode 325] Final distance: 0.0196 | Success: True
# [Episode 326] Final distance: 0.0189 | Success: True
# [Episode 327] Final distance: 0.0184 | Success: True
# [Episode 328] Final distance: 0.0199 | Success: True
# [Episode 329] Final distance: 0.0158 | Success: True
# [Episode 330] Final distance: 0.0186 | Success: True
# [Episode 331] Final distance: 0.0179 | Success: True
# [Episode 332] Final distance: 0.0169 | Success: True
# [Episode 333] Final distance: 0.0196 | Success: True
# [Episode 334] Final distance: 0.0183 | Success: True
# [Episode 335] Final distance: 0.0153 | Success: True
# [Episode 336] Final distance: 0.0198 | Success: True
# [Episode 337] Final distance: 0.0196 | Success: True
# [Episode 338] Final distance: 0.0166 | Success: True
# [Episode 339] Final distance: 0.0167 | Success: True
# [Episode 340] Final distance: 0.0190 | Success: True
# [Episode 341] Final distance: 0.0184 | Success: True
# [Episode 342] Final distance: 0.0188 | Success: True
# [Episode 343] Final distance: 0.0199 | Success: True
# [Episode 344] Final distance: 0.0188 | Success: True
# [Episode 345] Final distance: 0.0174 | Success: True
# [Episode 346] Final distance: 0.0198 | Success: True
# [Episode 347] Final distance: 0.0182 | Success: True
# [Episode 348] Final distance: 0.0192 | Success: True
# [Episode 349] Final distance: 0.0165 | Success: True
# [Episode 350] Final distance: 0.0131 | Success: True
# [Episode 351] Final distance: 0.0184 | Success: True
# [Episode 352] Final distance: 0.0276 | Success: False
# [Episode 353] Final distance: 0.0160 | Success: True
# [Episode 354] Final distance: 0.0179 | Success: True
# [Episode 355] Final distance: 0.0184 | Success: True
# [Episode 356] Final distance: 0.0186 | Success: True
# [Episode 357] Final distance: 0.0178 | Success: True
# [Episode 358] Final distance: 0.0196 | Success: True
# [Episode 359] Final distance: 0.0165 | Success: True
# [Episode 360] Final distance: 0.0149 | Success: True
# [Episode 361] Final distance: 0.0188 | Success: True
# [Episode 362] Final distance: 0.0114 | Success: True
# [Episode 363] Final distance: 0.0191 | Success: True
# [Episode 364] Final distance: 0.0192 | Success: True
# [Episode 365] Final distance: 0.0198 | Success: True
# [Episode 366] Final distance: 0.0188 | Success: True
# [Episode 367] Final distance: 0.0254 | Success: False
# [Episode 368] Final distance: 0.0174 | Success: True
# [Episode 369] Final distance: 0.0189 | Success: True
# [Episode 370] Final distance: 0.0186 | Success: True
# [Episode 371] Final distance: 0.0161 | Success: True
# [Episode 372] Final distance: 0.0157 | Success: True
# [Episode 373] Final distance: 0.0199 | Success: True
# [Episode 374] Final distance: 0.0192 | Success: True
# [Episode 375] Final distance: 0.0173 | Success: True
# [Episode 376] Final distance: 0.0131 | Success: True
# [Episode 377] Final distance: 0.0281 | Success: False
# [Episode 378] Final distance: 0.0189 | Success: True
# [Episode 379] Final distance: 0.0198 | Success: True
# [Episode 380] Final distance: 0.0171 | Success: True
# [Episode 381] Final distance: 0.0171 | Success: True
# [Episode 382] Final distance: 0.0184 | Success: True
# [Episode 383] Final distance: 0.0197 | Success: True
# [Episode 384] Final distance: 0.0185 | Success: True
# [Episode 385] Final distance: 0.0182 | Success: True
# [Episode 386] Final distance: 0.0158 | Success: True
# [Episode 387] Final distance: 0.0195 | Success: True
# [Episode 388] Final distance: 0.0198 | Success: True
# [Episode 389] Final distance: 0.0189 | Success: True
# [Episode 390] Final distance: 0.0195 | Success: True
# [Episode 391] Final distance: 0.0175 | Success: True
# [Episode 392] Final distance: 0.0195 | Success: True
# [Episode 393] Final distance: 0.0170 | Success: True
# [Episode 394] Final distance: 0.0195 | Success: True
# [Episode 395] Final distance: 0.0183 | Success: True
# [Episode 396] Final distance: 0.0162 | Success: True
# [Episode 397] Final distance: 0.0192 | Success: True
# [Episode 398] Final distance: 0.0190 | Success: True
# [Episode 399] Final distance: 0.0161 | Success: True
# [Episode 400] Final distance: 0.0194 | Success: True
# [Episode 401] Final distance: 0.0186 | Success: True
# [Episode 402] Final distance: 0.0183 | Success: True
# [Episode 403] Final distance: 0.0184 | Success: True
# [Episode 404] Final distance: 0.0169 | Success: True
# [Episode 405] Final distance: 0.0174 | Success: True
# [Episode 406] Final distance: 0.0183 | Success: True
# [Episode 407] Final distance: 0.0153 | Success: True
# [Episode 408] Final distance: 0.0184 | Success: True
# [Episode 409] Final distance: 0.0147 | Success: True
# [Episode 410] Final distance: 0.0164 | Success: True
# [Episode 411] Final distance: 0.0162 | Success: True
# [Episode 412] Final distance: 0.0174 | Success: True
# [Episode 413] Final distance: 0.0174 | Success: True
# [Episode 414] Final distance: 0.0187 | Success: True
# [Episode 415] Final distance: 0.0183 | Success: True
# [Episode 416] Final distance: 0.0179 | Success: True
# [Episode 417] Final distance: 0.0197 | Success: True
# [Episode 418] Final distance: 0.0131 | Success: True
# [Episode 419] Final distance: 0.0195 | Success: True
# [Episode 420] Final distance: 0.0252 | Success: False
# [Episode 421] Final distance: 0.0263 | Success: False
# [Episode 422] Final distance: 0.0177 | Success: True
# [Episode 423] Final distance: 0.0186 | Success: True
# [Episode 424] Final distance: 0.0198 | Success: True
# [Episode 425] Final distance: 0.0186 | Success: True
# [Episode 426] Final distance: 0.0176 | Success: True
# [Episode 427] Final distance: 0.0163 | Success: True
# [Episode 428] Final distance: 0.0428 | Success: False
# [Episode 429] Final distance: 0.0197 | Success: True
# [Episode 430] Final distance: 0.0172 | Success: True
# [Episode 431] Final distance: 0.0183 | Success: True
# [Episode 432] Final distance: 0.0155 | Success: True
# [Episode 433] Final distance: 0.0166 | Success: True
# [Episode 434] Final distance: 0.0192 | Success: True
# [Episode 435] Final distance: 0.0174 | Success: True
# [Episode 436] Final distance: 0.0161 | Success: True
# [Episode 437] Final distance: 0.0199 | Success: True
# [Episode 438] Final distance: 0.0179 | Success: True
# [Episode 439] Final distance: 0.0163 | Success: True
# [Episode 440] Final distance: 0.0168 | Success: True
# [Episode 441] Final distance: 0.0169 | Success: True
# [Episode 442] Final distance: 0.0198 | Success: True
# [Episode 443] Final distance: 0.0199 | Success: True
# [Episode 444] Final distance: 0.0184 | Success: True
# [Episode 445] Final distance: 0.0149 | Success: True
# [Episode 446] Final distance: 0.0394 | Success: False
# [Episode 447] Final distance: 0.0198 | Success: True
# [Episode 448] Final distance: 0.0199 | Success: True
# [Episode 449] Final distance: 0.0195 | Success: True
# [Episode 450] Final distance: 0.0199 | Success: True
# [Episode 451] Final distance: 0.0194 | Success: True
# [Episode 452] Final distance: 0.0165 | Success: True
# [Episode 453] Final distance: 0.0178 | Success: True
# [Episode 454] Final distance: 0.0185 | Success: True
# [Episode 455] Final distance: 0.0199 | Success: True
# [Episode 456] Final distance: 0.0188 | Success: True
# [Episode 457] Final distance: 0.0177 | Success: True
# [Episode 458] Final distance: 0.0189 | Success: True
# [Episode 459] Final distance: 0.0158 | Success: True
# [Episode 460] Final distance: 0.0141 | Success: True
# [Episode 461] Final distance: 0.0188 | Success: True
# [Episode 462] Final distance: 0.0196 | Success: True
# [Episode 463] Final distance: 0.0144 | Success: True
# [Episode 464] Final distance: 0.0195 | Success: True
# [Episode 465] Final distance: 0.0194 | Success: True
# [Episode 466] Final distance: 0.0169 | Success: True
# [Episode 467] Final distance: 0.0195 | Success: True
# [Episode 468] Final distance: 0.0137 | Success: True
# [Episode 469] Final distance: 0.0191 | Success: True
# [Episode 470] Final distance: 0.0196 | Success: True
# [Episode 471] Final distance: 0.0200 | Success: True
# [Episode 472] Final distance: 0.0189 | Success: True
# [Episode 473] Final distance: 0.0158 | Success: True
# [Episode 474] Final distance: 0.0189 | Success: True
# [Episode 475] Final distance: 0.0194 | Success: True
# [Episode 476] Final distance: 0.0185 | Success: True
# [Episode 477] Final distance: 0.0358 | Success: False
# [Episode 478] Final distance: 0.0186 | Success: True
# [Episode 479] Final distance: 0.0193 | Success: True
# [Episode 480] Final distance: 0.0188 | Success: True
# [Episode 481] Final distance: 0.0190 | Success: True
# [Episode 482] Final distance: 0.0196 | Success: True
# [Episode 483] Final distance: 0.0198 | Success: True
# [Episode 484] Final distance: 0.0168 | Success: True
# [Episode 485] Final distance: 0.0369 | Success: False
# [Episode 486] Final distance: 0.0145 | Success: True
# [Episode 487] Final distance: 0.0162 | Success: True
# [Episode 488] Final distance: 0.0163 | Success: True
# [Episode 489] Final distance: 0.0196 | Success: True
# [Episode 490] Final distance: 0.0188 | Success: True
# [Episode 491] Final distance: 0.0190 | Success: True
# [Episode 492] Final distance: 0.0173 | Success: True
# [Episode 493] Final distance: 0.0193 | Success: True
# [Episode 494] Final distance: 0.0180 | Success: True
# [Episode 495] Final distance: 0.0159 | Success: True
# [Episode 496] Final distance: 0.0184 | Success: True
# [Episode 497] Final distance: 0.0198 | Success: True
# [Episode 498] Final distance: 0.0177 | Success: True
# [Episode 499] Final distance: 0.0156 | Success: True
# [Episode 500] Final distance: 0.0172 | Success: True
# [Episode 501] Final distance: 0.0178 | Success: True
# [Episode 502] Final distance: 0.0189 | Success: True
# [Episode 503] Final distance: 0.0169 | Success: True
# [Episode 504] Final distance: 0.0177 | Success: True
# [Episode 505] Final distance: 0.0184 | Success: True
# [Episode 506] Final distance: 0.0290 | Success: False
# [Episode 507] Final distance: 0.0328 | Success: False
# [Episode 508] Final distance: 0.0188 | Success: True
# [Episode 509] Final distance: 0.0194 | Success: True
# [Episode 510] Final distance: 0.0196 | Success: True
# [Episode 511] Final distance: 0.0174 | Success: True
# [Episode 512] Final distance: 0.0189 | Success: True
# [Episode 513] Final distance: 0.0181 | Success: True
# [Episode 514] Final distance: 0.0332 | Success: False
# [Episode 515] Final distance: 0.0190 | Success: True
# [Episode 516] Final distance: 0.0179 | Success: True
# [Episode 517] Final distance: 0.0179 | Success: True
# [Episode 518] Final distance: 0.0198 | Success: True
# [Episode 519] Final distance: 0.0197 | Success: True
# [Episode 520] Final distance: 0.0192 | Success: True
# [Episode 521] Final distance: 0.0174 | Success: True
# [Episode 522] Final distance: 0.0191 | Success: True
# [Episode 523] Final distance: 0.0187 | Success: True
# [Episode 524] Final distance: 0.0196 | Success: True
# [Episode 525] Final distance: 0.0141 | Success: True
# [Episode 526] Final distance: 0.0139 | Success: True
# [Episode 527] Final distance: 0.0172 | Success: True
# [Episode 528] Final distance: 0.0168 | Success: True
# [Episode 529] Final distance: 0.0178 | Success: True
# [Episode 530] Final distance: 0.0151 | Success: True
# [Episode 531] Final distance: 0.0199 | Success: True
# [Episode 532] Final distance: 0.0171 | Success: True
# [Episode 533] Final distance: 0.0146 | Success: True
# [Episode 534] Final distance: 0.0185 | Success: True
# [Episode 535] Final distance: 0.0160 | Success: True
# [Episode 536] Final distance: 0.0186 | Success: True
# [Episode 537] Final distance: 0.0197 | Success: True
# [Episode 538] Final distance: 0.0156 | Success: True
# [Episode 539] Final distance: 0.0184 | Success: True
# [Episode 540] Final distance: 0.0089 | Success: True
# [Episode 541] Final distance: 0.0159 | Success: True
# [Episode 542] Final distance: 0.0145 | Success: True
# [Episode 543] Final distance: 0.0190 | Success: True
# [Episode 544] Final distance: 0.0128 | Success: True
# [Episode 545] Final distance: 0.0187 | Success: True
# [Episode 546] Final distance: 0.0173 | Success: True
# [Episode 547] Final distance: 0.0151 | Success: True
# [Episode 548] Final distance: 0.0194 | Success: True
# [Episode 549] Final distance: 0.0179 | Success: True
# [Episode 550] Final distance: 0.0129 | Success: True
# [Episode 551] Final distance: 0.0186 | Success: True
# [Episode 552] Final distance: 0.0183 | Success: True
# [Episode 553] Final distance: 0.0168 | Success: True
# [Episode 554] Final distance: 0.0193 | Success: True
# [Episode 555] Final distance: 0.0181 | Success: True
# [Episode 556] Final distance: 0.0356 | Success: False
# [Episode 557] Final distance: 0.0192 | Success: True
# [Episode 558] Final distance: 0.0158 | Success: True
# [Episode 559] Final distance: 0.0269 | Success: False
# [Episode 560] Final distance: 0.0178 | Success: True
# [Episode 561] Final distance: 0.0152 | Success: True
# [Episode 562] Final distance: 0.0198 | Success: True
# [Episode 563] Final distance: 0.0152 | Success: True
# [Episode 564] Final distance: 0.0190 | Success: True
# [Episode 565] Final distance: 0.0183 | Success: True
# [Episode 566] Final distance: 0.0162 | Success: True
# [Episode 567] Final distance: 0.0174 | Success: True
# [Episode 568] Final distance: 0.0194 | Success: True
# [Episode 569] Final distance: 0.0188 | Success: True
# [Episode 570] Final distance: 0.0177 | Success: True
# [Episode 571] Final distance: 0.0158 | Success: True
# [Episode 572] Final distance: 0.0198 | Success: True
# [Episode 573] Final distance: 0.0179 | Success: True
# [Episode 574] Final distance: 0.0189 | Success: True
# [Episode 575] Final distance: 0.0154 | Success: True
# [Episode 576] Final distance: 0.0192 | Success: True
# [Episode 577] Final distance: 0.0179 | Success: True
# [Episode 578] Final distance: 0.0160 | Success: True
# [Episode 579] Final distance: 0.0175 | Success: True
# [Episode 580] Final distance: 0.0198 | Success: True
# [Episode 581] Final distance: 0.0161 | Success: True
# [Episode 582] Final distance: 0.0184 | Success: True
# [Episode 583] Final distance: 0.0196 | Success: True
# [Episode 584] Final distance: 0.0170 | Success: True
# [Episode 585] Final distance: 0.0181 | Success: True
# [Episode 586] Final distance: 0.0356 | Success: False
# [Episode 587] Final distance: 0.0192 | Success: True
# [Episode 588] Final distance: 0.0183 | Success: True
# [Episode 589] Final distance: 0.0350 | Success: False
# [Episode 590] Final distance: 0.0186 | Success: True
# [Episode 591] Final distance: 0.0168 | Success: True
# [Episode 592] Final distance: 0.0192 | Success: True
# [Episode 593] Final distance: 0.0199 | Success: True
# [Episode 594] Final distance: 0.0186 | Success: True
# [Episode 595] Final distance: 0.0196 | Success: True
# [Episode 596] Final distance: 0.0196 | Success: True
# [Episode 597] Final distance: 0.0324 | Success: False
# [Episode 598] Final distance: 0.0171 | Success: True
# [Episode 599] Final distance: 0.0186 | Success: True
# [Episode 600] Final distance: 0.0153 | Success: True
# [Episode 601] Final distance: 0.0176 | Success: True
# [Episode 602] Final distance: 0.0198 | Success: True
# [Episode 603] Final distance: 0.0164 | Success: True
# [Episode 604] Final distance: 0.0431 | Success: False
# [Episode 605] Final distance: 0.0126 | Success: True
# [Episode 606] Final distance: 0.0180 | Success: True
# [Episode 607] Final distance: 0.0312 | Success: False
# [Episode 608] Final distance: 0.0153 | Success: True
# [Episode 609] Final distance: 0.0183 | Success: True
# [Episode 610] Final distance: 0.0177 | Success: True
# [Episode 611] Final distance: 0.0180 | Success: True
# [Episode 612] Final distance: 0.0200 | Success: True
# [Episode 613] Final distance: 0.0180 | Success: True
# [Episode 614] Final distance: 0.0437 | Success: False
# [Episode 615] Final distance: 0.0175 | Success: True
# [Episode 616] Final distance: 0.0133 | Success: True
# [Episode 617] Final distance: 0.0180 | Success: True
# [Episode 618] Final distance: 0.0347 | Success: False
# [Episode 619] Final distance: 0.0166 | Success: True
# [Episode 620] Final distance: 0.0195 | Success: True
# [Episode 621] Final distance: 0.0194 | Success: True
# [Episode 622] Final distance: 0.0176 | Success: True
# [Episode 623] Final distance: 0.0172 | Success: True
# [Episode 624] Final distance: 0.0342 | Success: False
# [Episode 625] Final distance: 0.0197 | Success: True
# [Episode 626] Final distance: 0.0144 | Success: True
# [Episode 627] Final distance: 0.0176 | Success: True
# [Episode 628] Final distance: 0.0192 | Success: True
# [Episode 629] Final distance: 0.0194 | Success: True
# [Episode 630] Final distance: 0.0180 | Success: True
# [Episode 631] Final distance: 0.0180 | Success: True
# [Episode 632] Final distance: 0.0181 | Success: True
# [Episode 633] Final distance: 0.0196 | Success: True
# [Episode 634] Final distance: 0.0186 | Success: True
# [Episode 635] Final distance: 0.0196 | Success: True
# [Episode 636] Final distance: 0.0192 | Success: True
# [Episode 637] Final distance: 0.0192 | Success: True
# [Episode 638] Final distance: 0.0178 | Success: True
# [Episode 639] Final distance: 0.0161 | Success: True
# [Episode 640] Final distance: 0.0183 | Success: True
# [Episode 641] Final distance: 0.0200 | Success: True
# [Episode 642] Final distance: 0.0195 | Success: True
# [Episode 643] Final distance: 0.0188 | Success: True
# [Episode 644] Final distance: 0.0177 | Success: True
# [Episode 645] Final distance: 0.0177 | Success: True
# [Episode 646] Final distance: 0.0186 | Success: True
# [Episode 647] Final distance: 0.0196 | Success: True
# [Episode 648] Final distance: 0.0199 | Success: True
# [Episode 649] Final distance: 0.0182 | Success: True
# [Episode 650] Final distance: 0.0182 | Success: True
# [Episode 651] Final distance: 0.0175 | Success: True
# [Episode 652] Final distance: 0.0153 | Success: True
# [Episode 653] Final distance: 0.0184 | Success: True
# [Episode 654] Final distance: 0.0370 | Success: False
# [Episode 655] Final distance: 0.0161 | Success: True
# [Episode 656] Final distance: 0.0196 | Success: True
# [Episode 657] Final distance: 0.0161 | Success: True
# [Episode 658] Final distance: 0.0117 | Success: True
# [Episode 659] Final distance: 0.0179 | Success: True
# [Episode 660] Final distance: 0.0163 | Success: True
# [Episode 661] Final distance: 0.0182 | Success: True
# [Episode 662] Final distance: 0.0187 | Success: True
# [Episode 663] Final distance: 0.0174 | Success: True
# [Episode 664] Final distance: 0.0145 | Success: True
# [Episode 665] Final distance: 0.0167 | Success: True
# [Episode 666] Final distance: 0.0156 | Success: True
# [Episode 667] Final distance: 0.0196 | Success: True
# [Episode 668] Final distance: 0.0154 | Success: True
# [Episode 669] Final distance: 0.0180 | Success: True
# [Episode 670] Final distance: 0.0181 | Success: True
# [Episode 671] Final distance: 0.0180 | Success: True
# [Episode 672] Final distance: 0.0179 | Success: True
# [Episode 673] Final distance: 0.0172 | Success: True
# [Episode 674] Final distance: 0.0199 | Success: True
# [Episode 675] Final distance: 0.0160 | Success: True
# [Episode 676] Final distance: 0.0197 | Success: True
# [Episode 677] Final distance: 0.0200 | Success: True
# [Episode 678] Final distance: 0.0198 | Success: True
# [Episode 679] Final distance: 0.0181 | Success: True
# [Episode 680] Final distance: 0.0145 | Success: True
# [Episode 681] Final distance: 0.0200 | Success: True
# [Episode 682] Final distance: 0.0181 | Success: True
# [Episode 683] Final distance: 0.0177 | Success: True
# [Episode 684] Final distance: 0.0182 | Success: True
# [Episode 685] Final distance: 0.0170 | Success: True
# [Episode 686] Final distance: 0.0178 | Success: True
# [Episode 687] Final distance: 0.0186 | Success: True
# [Episode 688] Final distance: 0.0199 | Success: True
# [Episode 689] Final distance: 0.0159 | Success: True
# [Episode 690] Final distance: 0.0193 | Success: True
# [Episode 691] Final distance: 0.0181 | Success: True
# [Episode 692] Final distance: 0.0196 | Success: True
# [Episode 693] Final distance: 0.0195 | Success: True
# [Episode 694] Final distance: 0.0193 | Success: True
# [Episode 695] Final distance: 0.0200 | Success: True
# [Episode 696] Final distance: 0.0200 | Success: True
# [Episode 697] Final distance: 0.0187 | Success: True
# [Episode 698] Final distance: 0.0199 | Success: True
# [Episode 699] Final distance: 0.0184 | Success: True
# [Episode 700] Final distance: 0.0191 | Success: True
# [Episode 701] Final distance: 0.0180 | Success: True
# [Episode 702] Final distance: 0.0184 | Success: True
# [Episode 703] Final distance: 0.0162 | Success: True
# [Episode 704] Final distance: 0.0149 | Success: True
# [Episode 705] Final distance: 0.0179 | Success: True
# [Episode 706] Final distance: 0.0165 | Success: True
# [Episode 707] Final distance: 0.0198 | Success: True
# [Episode 708] Final distance: 0.0189 | Success: True
# [Episode 709] Final distance: 0.0122 | Success: True
# [Episode 710] Final distance: 0.0166 | Success: True
# [Episode 711] Final distance: 0.0186 | Success: True
# [Episode 712] Final distance: 0.0135 | Success: True
# [Episode 713] Final distance: 0.0187 | Success: True
# [Episode 714] Final distance: 0.0172 | Success: True
# [Episode 715] Final distance: 0.0166 | Success: True
# [Episode 716] Final distance: 0.0165 | Success: True
# [Episode 717] Final distance: 0.0190 | Success: True
# [Episode 718] Final distance: 0.0165 | Success: True
# [Episode 719] Final distance: 0.0178 | Success: True
# [Episode 720] Final distance: 0.0178 | Success: True
# [Episode 721] Final distance: 0.0195 | Success: True
# [Episode 722] Final distance: 0.0196 | Success: True
# [Episode 723] Final distance: 0.0174 | Success: True
# [Episode 724] Final distance: 0.0185 | Success: True
# [Episode 725] Final distance: 0.0173 | Success: True
# [Episode 726] Final distance: 0.0196 | Success: True
# [Episode 727] Final distance: 0.0195 | Success: True
# [Episode 728] Final distance: 0.0158 | Success: True
# [Episode 729] Final distance: 0.0172 | Success: True
# [Episode 730] Final distance: 0.0183 | Success: True
# [Episode 731] Final distance: 0.0198 | Success: True
# [Episode 732] Final distance: 0.0196 | Success: True
# [Episode 733] Final distance: 0.0176 | Success: True
# [Episode 734] Final distance: 0.0189 | Success: True
# [Episode 735] Final distance: 0.0175 | Success: True
# [Episode 736] Final distance: 0.0199 | Success: True
# [Episode 737] Final distance: 0.0156 | Success: True
# [Episode 738] Final distance: 0.0189 | Success: True
# [Episode 739] Final distance: 0.0167 | Success: True
# [Episode 740] Final distance: 0.0191 | Success: True
# [Episode 741] Final distance: 0.0142 | Success: True
# [Episode 742] Final distance: 0.0152 | Success: True
# [Episode 743] Final distance: 0.0199 | Success: True
# [Episode 744] Final distance: 0.0152 | Success: True
# [Episode 745] Final distance: 0.0166 | Success: True
# [Episode 746] Final distance: 0.0151 | Success: True
# [Episode 747] Final distance: 0.0190 | Success: True
# [Episode 748] Final distance: 0.0189 | Success: True
# [Episode 749] Final distance: 0.0199 | Success: True
# [Episode 750] Final distance: 0.0293 | Success: False
# [Episode 751] Final distance: 0.0192 | Success: True
# [Episode 752] Final distance: 0.0193 | Success: True
# [Episode 753] Final distance: 0.0185 | Success: True
# [Episode 754] Final distance: 0.0193 | Success: True
# [Episode 755] Final distance: 0.0170 | Success: True
# [Episode 756] Final distance: 0.0171 | Success: True
# [Episode 757] Final distance: 0.0198 | Success: True
# [Episode 758] Final distance: 0.0176 | Success: True
# [Episode 759] Final distance: 0.0145 | Success: True
# [Episode 760] Final distance: 0.0193 | Success: True
# [Episode 761] Final distance: 0.0183 | Success: True
# [Episode 762] Final distance: 0.0194 | Success: True
# [Episode 763] Final distance: 0.0199 | Success: True
# [Episode 764] Final distance: 0.0153 | Success: True
# [Episode 765] Final distance: 0.0162 | Success: True
# [Episode 766] Final distance: 0.0163 | Success: True
# [Episode 767] Final distance: 0.0171 | Success: True
# [Episode 768] Final distance: 0.0195 | Success: True
# [Episode 769] Final distance: 0.0185 | Success: True
# [Episode 770] Final distance: 0.0183 | Success: True
# [Episode 771] Final distance: 0.0188 | Success: True
# [Episode 772] Final distance: 0.0193 | Success: True
# [Episode 773] Final distance: 0.0194 | Success: True
# [Episode 774] Final distance: 0.0199 | Success: True
# [Episode 775] Final distance: 0.0191 | Success: True
# [Episode 776] Final distance: 0.0186 | Success: True
# [Episode 777] Final distance: 0.0181 | Success: True
# [Episode 778] Final distance: 0.0158 | Success: True
# [Episode 779] Final distance: 0.0146 | Success: True
# [Episode 780] Final distance: 0.0179 | Success: True
# [Episode 781] Final distance: 0.0193 | Success: True
# [Episode 782] Final distance: 0.0193 | Success: True
# [Episode 783] Final distance: 0.0194 | Success: True
# [Episode 784] Final distance: 0.0188 | Success: True
# [Episode 785] Final distance: 0.0176 | Success: True
# [Episode 786] Final distance: 0.0193 | Success: True
# [Episode 787] Final distance: 0.0176 | Success: True
# [Episode 788] Final distance: 0.0193 | Success: True
# [Episode 789] Final distance: 0.0195 | Success: True
# [Episode 790] Final distance: 0.0172 | Success: True
# [Episode 791] Final distance: 0.0334 | Success: False
# [Episode 792] Final distance: 0.0165 | Success: True
# [Episode 793] Final distance: 0.0174 | Success: True
# [Episode 794] Final distance: 0.0200 | Success: True
# [Episode 795] Final distance: 0.0197 | Success: True
# [Episode 796] Final distance: 0.0198 | Success: True
# [Episode 797] Final distance: 0.0154 | Success: True
# [Episode 798] Final distance: 0.0182 | Success: True
# [Episode 799] Final distance: 0.0138 | Success: True
# [Episode 800] Final distance: 0.0175 | Success: True
# [Episode 801] Final distance: 0.0192 | Success: True
# [Episode 802] Final distance: 0.0111 | Success: True
# [Episode 803] Final distance: 0.0199 | Success: True
# [Episode 804] Final distance: 0.0188 | Success: True
# [Episode 805] Final distance: 0.0194 | Success: True
# [Episode 806] Final distance: 0.0174 | Success: True
# [Episode 807] Final distance: 0.0171 | Success: True
# [Episode 808] Final distance: 0.0183 | Success: True
# [Episode 809] Final distance: 0.0145 | Success: True
# [Episode 810] Final distance: 0.0190 | Success: True
# [Episode 811] Final distance: 0.0199 | Success: True
# [Episode 812] Final distance: 0.0175 | Success: True
# [Episode 813] Final distance: 0.0160 | Success: True
# [Episode 814] Final distance: 0.0165 | Success: True
# [Episode 815] Final distance: 0.0178 | Success: True
# [Episode 816] Final distance: 0.0190 | Success: True
# [Episode 817] Final distance: 0.0188 | Success: True
# [Episode 818] Final distance: 0.0157 | Success: True
# [Episode 819] Final distance: 0.0183 | Success: True
# [Episode 820] Final distance: 0.0192 | Success: True
# [Episode 821] Final distance: 0.0178 | Success: True
# [Episode 822] Final distance: 0.0187 | Success: True
# [Episode 823] Final distance: 0.0176 | Success: True
# [Episode 824] Final distance: 0.0323 | Success: False
# [Episode 825] Final distance: 0.0278 | Success: False
# [Episode 826] Final distance: 0.0166 | Success: True
# [Episode 827] Final distance: 0.0194 | Success: True
# [Episode 828] Final distance: 0.0198 | Success: True
# [Episode 829] Final distance: 0.0187 | Success: True
# [Episode 830] Final distance: 0.0169 | Success: True
# [Episode 831] Final distance: 0.0325 | Success: False
# [Episode 832] Final distance: 0.0180 | Success: True
# [Episode 833] Final distance: 0.0196 | Success: True
# [Episode 834] Final distance: 0.0196 | Success: True
# [Episode 835] Final distance: 0.0193 | Success: True
# [Episode 836] Final distance: 0.0157 | Success: True
# [Episode 837] Final distance: 0.0193 | Success: True
# [Episode 838] Final distance: 0.0188 | Success: True
# [Episode 839] Final distance: 0.0196 | Success: True
# [Episode 840] Final distance: 0.0148 | Success: True
# [Episode 841] Final distance: 0.0195 | Success: True
# [Episode 842] Final distance: 0.0124 | Success: True
# [Episode 843] Final distance: 0.0179 | Success: True
# [Episode 844] Final distance: 0.0178 | Success: True
# [Episode 845] Final distance: 0.0123 | Success: True
# [Episode 846] Final distance: 0.0187 | Success: True
# [Episode 847] Final distance: 0.0146 | Success: True
# [Episode 848] Final distance: 0.0198 | Success: True
# [Episode 849] Final distance: 0.0191 | Success: True
# [Episode 850] Final distance: 0.0178 | Success: True
# [Episode 851] Final distance: 0.0198 | Success: True
# [Episode 852] Final distance: 0.0142 | Success: True
# [Episode 853] Final distance: 0.0192 | Success: True
# [Episode 854] Final distance: 0.0197 | Success: True
# [Episode 855] Final distance: 0.0152 | Success: True
# [Episode 856] Final distance: 0.0189 | Success: True
# [Episode 857] Final distance: 0.0139 | Success: True
# [Episode 858] Final distance: 0.0189 | Success: True
# [Episode 859] Final distance: 0.0179 | Success: True
# [Episode 860] Final distance: 0.0187 | Success: True
# [Episode 861] Final distance: 0.0177 | Success: True
# [Episode 862] Final distance: 0.0161 | Success: True
# [Episode 863] Final distance: 0.0188 | Success: True
# [Episode 864] Final distance: 0.0180 | Success: True
# [Episode 865] Final distance: 0.0381 | Success: False
# [Episode 866] Final distance: 0.0190 | Success: True
# [Episode 867] Final distance: 0.0157 | Success: True
# [Episode 868] Final distance: 0.0130 | Success: True
# [Episode 869] Final distance: 0.0146 | Success: True
# [Episode 870] Final distance: 0.0161 | Success: True
# [Episode 871] Final distance: 0.0244 | Success: False
# [Episode 872] Final distance: 0.0184 | Success: True
# [Episode 873] Final distance: 0.0181 | Success: True
# [Episode 874] Final distance: 0.0179 | Success: True
# [Episode 875] Final distance: 0.0198 | Success: True
# [Episode 876] Final distance: 0.0194 | Success: True
# [Episode 877] Final distance: 0.0198 | Success: True
# [Episode 878] Final distance: 0.0180 | Success: True
# [Episode 879] Final distance: 0.0199 | Success: True
# [Episode 880] Final distance: 0.0193 | Success: True
# [Episode 881] Final distance: 0.0190 | Success: True
# [Episode 882] Final distance: 0.0168 | Success: True
# [Episode 883] Final distance: 0.0173 | Success: True
# [Episode 884] Final distance: 0.0198 | Success: True
# [Episode 885] Final distance: 0.0200 | Success: True
# [Episode 886] Final distance: 0.0107 | Success: True
# [Episode 887] Final distance: 0.0186 | Success: True
# [Episode 888] Final distance: 0.0192 | Success: True
# [Episode 889] Final distance: 0.0132 | Success: True
# [Episode 890] Final distance: 0.0191 | Success: True
# [Episode 891] Final distance: 0.0172 | Success: True
# [Episode 892] Final distance: 0.0164 | Success: True
# [Episode 893] Final distance: 0.0195 | Success: True
# [Episode 894] Final distance: 0.0172 | Success: True
# [Episode 895] Final distance: 0.0190 | Success: True
# [Episode 896] Final distance: 0.0198 | Success: True
# [Episode 897] Final distance: 0.0189 | Success: True
# [Episode 898] Final distance: 0.0151 | Success: True
# [Episode 899] Final distance: 0.0164 | Success: True
# [Episode 900] Final distance: 0.0193 | Success: True
# [Episode 901] Final distance: 0.0199 | Success: True
# [Episode 902] Final distance: 0.0180 | Success: True
# [Episode 903] Final distance: 0.0181 | Success: True
# [Episode 904] Final distance: 0.0198 | Success: True
# [Episode 905] Final distance: 0.0274 | Success: False
# [Episode 906] Final distance: 0.0262 | Success: False
# [Episode 907] Final distance: 0.0196 | Success: True
# [Episode 908] Final distance: 0.0132 | Success: True
# [Episode 909] Final distance: 0.0196 | Success: True
# [Episode 910] Final distance: 0.0197 | Success: True
# [Episode 911] Final distance: 0.0155 | Success: True
# [Episode 912] Final distance: 0.0189 | Success: True
# [Episode 913] Final distance: 0.0199 | Success: True
# [Episode 914] Final distance: 0.0186 | Success: True
# [Episode 915] Final distance: 0.0122 | Success: True
# [Episode 916] Final distance: 0.0151 | Success: True
# [Episode 917] Final distance: 0.0188 | Success: True
# [Episode 918] Final distance: 0.0149 | Success: True
# [Episode 919] Final distance: 0.0197 | Success: True
# [Episode 920] Final distance: 0.0183 | Success: True
# [Episode 921] Final distance: 0.0196 | Success: True
# [Episode 922] Final distance: 0.0191 | Success: True
# [Episode 923] Final distance: 0.0192 | Success: True
# [Episode 924] Final distance: 0.0163 | Success: True
# [Episode 925] Final distance: 0.0187 | Success: True
# [Episode 926] Final distance: 0.0185 | Success: True
# [Episode 927] Final distance: 0.0178 | Success: True
# [Episode 928] Final distance: 0.0172 | Success: True
# [Episode 929] Final distance: 0.0155 | Success: True
# [Episode 930] Final distance: 0.0197 | Success: True
# [Episode 931] Final distance: 0.0174 | Success: True
# [Episode 932] Final distance: 0.0171 | Success: True
# [Episode 933] Final distance: 0.0155 | Success: True
# [Episode 934] Final distance: 0.0191 | Success: True
# [Episode 935] Final distance: 0.0183 | Success: True
# [Episode 936] Final distance: 0.0199 | Success: True
# [Episode 937] Final distance: 0.0301 | Success: False
# [Episode 938] Final distance: 0.0168 | Success: True
# [Episode 939] Final distance: 0.0196 | Success: True
# [Episode 940] Final distance: 0.0177 | Success: True
# [Episode 941] Final distance: 0.0157 | Success: True
# [Episode 942] Final distance: 0.0177 | Success: True
# [Episode 943] Final distance: 0.0193 | Success: True
# [Episode 944] Final distance: 0.0195 | Success: True
# [Episode 945] Final distance: 0.0188 | Success: True
# [Episode 946] Final distance: 0.0119 | Success: True
# [Episode 947] Final distance: 0.0166 | Success: True
# [Episode 948] Final distance: 0.0311 | Success: False
# [Episode 949] Final distance: 0.0195 | Success: True
# [Episode 950] Final distance: 0.0200 | Success: True
# [Episode 951] Final distance: 0.0177 | Success: True
# [Episode 952] Final distance: 0.0188 | Success: True
# [Episode 953] Final distance: 0.0166 | Success: True
# [Episode 954] Final distance: 0.0173 | Success: True
# [Episode 955] Final distance: 0.0166 | Success: True
# [Episode 956] Final distance: 0.0430 | Success: False
# [Episode 957] Final distance: 0.0160 | Success: True
# [Episode 958] Final distance: 0.0153 | Success: True
# [Episode 959] Final distance: 0.0196 | Success: True
# [Episode 960] Final distance: 0.0138 | Success: True
# [Episode 961] Final distance: 0.0176 | Success: True
# [Episode 962] Final distance: 0.0197 | Success: True
# [Episode 963] Final distance: 0.0330 | Success: False
# [Episode 964] Final distance: 0.0199 | Success: True
# [Episode 965] Final distance: 0.0149 | Success: True
# [Episode 966] Final distance: 0.0171 | Success: True
# [Episode 967] Final distance: 0.0194 | Success: True
# [Episode 968] Final distance: 0.0188 | Success: True
# [Episode 969] Final distance: 0.0165 | Success: True
# [Episode 970] Final distance: 0.0171 | Success: True
# [Episode 971] Final distance: 0.0188 | Success: True
# [Episode 972] Final distance: 0.0196 | Success: True
# [Episode 973] Final distance: 0.0185 | Success: True
# [Episode 974] Final distance: 0.0173 | Success: True
# [Episode 975] Final distance: 0.0191 | Success: True
# [Episode 976] Final distance: 0.0188 | Success: True
# [Episode 977] Final distance: 0.0194 | Success: True
# [Episode 978] Final distance: 0.0211 | Success: False
# [Episode 979] Final distance: 0.0184 | Success: True
# [Episode 980] Final distance: 0.0190 | Success: True
# [Episode 981] Final distance: 0.0179 | Success: True
# [Episode 982] Final distance: 0.0195 | Success: True
# [Episode 983] Final distance: 0.0195 | Success: True
# [Episode 984] Final distance: 0.0198 | Success: True
# [Episode 985] Final distance: 0.0195 | Success: True
# [Episode 986] Final distance: 0.0191 | Success: True
# [Episode 987] Final distance: 0.0161 | Success: True
# [Episode 988] Final distance: 0.0185 | Success: True
# [Episode 989] Final distance: 0.0182 | Success: True
# [Episode 990] Final distance: 0.0188 | Success: True
# [Episode 991] Final distance: 0.0169 | Success: True
# [Episode 992] Final distance: 0.0198 | Success: True
# [Episode 993] Final distance: 0.0173 | Success: True
# [Episode 994] Final distance: 0.0180 | Success: True
# [Episode 995] Final distance: 0.0194 | Success: True
# [Episode 996] Final distance: 0.0198 | Success: True
# [Episode 997] Final distance: 0.0284 | Success: False
# [Episode 998] Final distance: 0.0352 | Success: False
# [Episode 999] Final distance: 0.0199 | Success: True
# [Episode 1000] Final distance: 0.0188 | Success: True
# Success rate: 952/1001
# Average final distance: 0.0186
